# %%
import sys

sys.path.append('..')
import os
import torch
import pandas as pd
import numpy as np
from deep_logic.models.relu_nn import XReluNN
from deep_logic.models.psi_nn import PsiNetwork
from deep_logic.models.tree import XDecisionTreeClassifier
from deep_logic.utils.base import set_seed
from deep_logic.utils.metrics import F1Score
from deep_logic.models.general_nn import XGeneralNN
from deep_logic.utils.datasets import ConceptToTaskDataset
from deep_logic.utils.data import get_splits_train_val_test
from deep_logic.logic.base import test_multi_class_explanation

results_dir = 'results/cub'
if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %% [markdown]
# ## Define loss, metrics and saved metrics

# %%
loss = torch.nn.CrossEntropyLoss()
metric = F1Score()

methods = []
splits = []
explanations = []
explanations_inv = []
model_accuracies = []
explanation_accuracies = []
explanation_accuracies_inv = []
elapsed_times = []
elapsed_times_inv = []

# %% [markdown]
# ## Loading CUB data

# %%
dataset = ConceptToTaskDataset("../data/CUB_200_2011/")
concept_names = dataset.attribute_names
print("Concept names", concept_names)
n_features = dataset.n_attributes
print("Number of features", n_features)
# Out:
# Concept names ['has_bill_shape_dagger' 'has_bill_shape_hooked_seabird'
#  'has_bill_shape_allpurpose' 'has_bill_shape_cone' 'has_wing_color_brown'
#  'has_wing_color_grey' 'has_wing_color_yellow' 'has_wing_color_black'
#  'has_wing_color_white' 'has_wing_color_buff' 'has_upperparts_color_brown'
#  'has_upperparts_color_grey' 'has_upperparts_color_yellow'
#  'has_upperparts_color_black' 'has_upperparts_color_white'
#  'has_upperparts_color_buff' 'has_underparts_color_brown'
#  'has_underparts_color_grey' 'has_underparts_color_yellow'
#  'has_underparts_color_black' 'has_underparts_color_white'
#  'has_underparts_color_buff' 'has_breast_pattern_solid'
#  'has_breast_pattern_striped' 'has_breast_pattern_multicolored'
#  'has_back_color_brown' 'has_back_color_grey' 'has_back_color_yellow'
#  'has_back_color_black' 'has_back_color_white' 'has_back_color_buff'
#  'has_tail_shape_notched_tail' 'has_upper_tail_color_brown'
#  'has_upper_tail_color_grey' 'has_upper_tail_color_black'
#  'has_upper_tail_color_white' 'has_upper_tail_color_buff'
#  'has_head_pattern_plain' 'has_head_pattern_capped'
#  'has_breast_color_brown' 'has_breast_color_grey'
#  'has_breast_color_yellow' 'has_breast_color_black'
#  'has_breast_color_white' 'has_breast_color_buff' 'has_throat_color_grey'
#  'has_throat_color_yellow' 'has_throat_color_black'
#  'has_throat_color_white' 'has_eye_color_black'
#  'has_bill_length_about_the_same_as_head'
#  'has_bill_length_shorter_than_head' 'has_forehead_color_blue'
#  'has_forehead_color_brown' 'has_forehead_color_grey'
#  'has_forehead_color_yellow' 'has_forehead_color_black'
#  'has_forehead_color_white' 'has_forehead_color_red'
#  'has_under_tail_color_brown' 'has_under_tail_color_grey'
#  'has_under_tail_color_yellow' 'has_under_tail_color_black'
#  'has_under_tail_color_white' 'has_under_tail_color_buff'
#  'has_nape_color_blue' 'has_nape_color_brown' 'has_nape_color_grey'
#  'has_nape_color_yellow' 'has_nape_color_black' 'has_nape_color_white'
#  'has_nape_color_buff' 'has_belly_color_grey' 'has_belly_color_yellow'
#  'has_belly_color_black' 'has_belly_color_white' 'has_belly_color_buff'
#  'has_wing_shape_roundedwings' 'has_size_small_5__9_in'
#  'has_size_medium_9__16_in' 'has_size_very_small_3__5_in'
#  'has_shape_perchinglike' 'has_back_pattern_solid'
#  'has_back_pattern_striped' 'has_back_pattern_multicolored'
#  'has_tail_pattern_solid' 'has_tail_pattern_multicolored'
#  'has_belly_pattern_solid' 'has_primary_color_brown'
#  'has_primary_color_grey' 'has_primary_color_yellow'
#  'has_primary_color_black' 'has_primary_color_white'
#  'has_primary_color_buff' 'has_leg_color_grey' 'has_leg_color_black'
#  'has_leg_color_buff' 'has_bill_color_grey' 'has_bill_color_black'
#  'has_crown_color_blue' 'has_crown_color_brown' 'has_crown_color_grey'
#  'has_crown_color_yellow' 'has_crown_color_black' 'has_crown_color_white'
#  'has_wing_pattern_solid' 'has_wing_pattern_striped'
#  'has_wing_pattern_multicolored']
# Class names ['001.Black_footed_Albatross', '002.Laysan_Albatross']
# Number of features 108

# %% [markdown]
# ## Training Hyperparameters

# %%
epochs = 200
l_r = 0.001
lr_scheduler = True
top_k_explanations = 1
simplify = True
seeds = [*range(10)]
print("Seeds", seeds)
# Out:
# Seeds [0, 1]

# %% [markdown]
# ## Decision Tree

# %%
for seed in seeds:
    print("Seed", seed)
    set_seed(seed)

    train_data, val_data, test_data = get_splits_train_val_test(dataset)
    print(train_data.indices)

    device = torch.device("cpu")

    print("Training Tree Classifier...")
    model = XDecisionTreeClassifier(n_classes=dataset.n_classes, n_features=n_features)

    results = model.fit(train_data, val_data, metric=metric, save=False)
    print(results)

    accuracy = model.evaluate(test_data)
    print("Test model accuracy", accuracy)

    formulas, times = [], []
    for i, class_to_explain in enumerate(dataset.classes):
        formula, elapsed_time = model.get_global_explanation(i, concept_names,
                                                             return_time=True)
        formulas.append(formula), times.append(elapsed_time)
        print(f"{class_to_explain} <-> {formula}")
        print("Elapsed time", elapsed_time)

    methods.append("Tree")
    splits.append(seed)
    explanations.append(formulas[0])
    explanations_inv.append(formulas[1])
    model_accuracies.append(accuracy)
    explanation_accuracies.append(accuracy)
    explanation_accuracies_inv.append(accuracy)
    elapsed_times.append(np.mean(times))
    elapsed_times_inv.append(np.mean(times))

results_tree = pd.DataFrame({
    'method': methods,
    'split': splits,
    'explanation': explanations,
    'explanation_inv': explanations_inv,
    'model_accuracy': model_accuracies,
    'explanation_accuracy': explanation_accuracies,
    'explanation_accuracy_inv': explanation_accuracies_inv,
    'elapsed_time': elapsed_times,
    'elapsed_time_inv': elapsed_times_inv,
})
results_tree.to_csv(os.path.join(results_dir, 'results_tree.csv'))
print(results_tree)
# Out:
# Seed 0
# [    0     2     3 ... 11784 11785 11787]
# Training Tree Classifier...
# Train_acc: 100.0, Val_acc: 89.1
#    tot_loss  train_accs  val_accs  best_epoch
# 0         0       100.0  89.09869           0
# Test model accuracy 90.36348267117498
# 001.Black_footed_Albatross <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black <= 0.74 & has_under_tail_color_white <= 0.60 & has_bill_color_black <= 0.02 & has_back_color_white <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black <= 0.74 & has_under_tail_color_white <= 0.60 & has_bill_color_black > 0.02 & has_wing_pattern_solid <= 0.99 & has_tail_pattern_solid <= 0.93 & has_nape_color_black > 0.01 & has_belly_color_buff > 0.00 & has_eye_color_black > 0.71 & has_crown_color_black > 0.07 & has_belly_color_buff > 0.00 & has_belly_color_yellow > 0.00 & has_underparts_color_white > 0.07 & has_throat_color_grey > 0.00 & has_back_color_yellow > 0.02 & has_primary_color_grey > 0.04) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black <= 0.74 & has_under_tail_color_white <= 0.60 & has_bill_color_black > 0.02 & has_wing_pattern_solid <= 0.99 & has_tail_pattern_solid > 0.93 & has_underparts_color_white <= 0.28 & has_under_tail_color_buff <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black <= 0.74 & has_under_tail_color_white <= 0.60 & has_bill_color_black > 0.02 & has_wing_pattern_solid > 0.99 & has_belly_color_black > 0.05 & has_primary_color_white <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white > 0.57 & has_breast_pattern_multicolored <= 0.15 & has_back_color_yellow <= 0.45 & has_bill_shape_cone <= 0.91 & has_leg_color_grey <= 0.67 & has_crown_color_white > 0.05 & has_leg_color_black <= 0.70 & has_bill_color_black <= 0.98 & has_bill_length_shorter_than_head <= 0.15 & has_size_medium_9__16_in > 0.33 & has_wing_pattern_multicolored <= 0.39 & has_back_pattern_solid > 0.01 & has_upper_tail_color_grey > 0.48 & has_bill_shape_dagger > 0.00 & has_wing_pattern_solid > 0.67 & has_upperparts_color_brown > 0.00 & has_nape_color_white <= 0.69)
# Elapsed time 0.013001203536987305
# 002.Laysan_Albatross <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black <= 0.61 & has_breast_pattern_multicolored <= 0.98 & has_forehead_color_red <= 0.82 & has_upperparts_color_buff <= 0.75 & has_breast_color_grey <= 0.97 & has_under_tail_color_brown <= 0.99 & has_primary_color_grey <= 0.97 & has_crown_color_blue <= 0.95 & has_back_color_brown <= 0.94 & has_bill_length_shorter_than_head > 0.00 & has_breast_color_buff <= 0.99 & has_belly_color_buff <= 0.96 & has_tail_pattern_multicolored <= 1.00 & has_upper_tail_color_brown <= 1.00 & has_under_tail_color_grey <= 0.98 & has_back_color_grey <= 1.00 & has_wing_pattern_solid <= 1.00 & has_leg_color_black <= 1.00 & has_tail_shape_notched_tail <= 1.00 & has_head_pattern_plain <= 0.99 & has_primary_color_brown <= 0.97 & has_eye_color_black > 0.20 & has_belly_pattern_solid > 0.00 & has_bill_shape_allpurpose <= 0.97 & has_breast_color_white > 0.73 & has_leg_color_grey > 0.11 & has_bill_color_black > 0.07 & has_breast_pattern_solid > 0.56 & has_bill_length_about_the_same_as_head <= 0.98 & has_upperparts_color_brown <= 0.71 & has_bill_length_about_the_same_as_head > 0.00 & has_breast_color_yellow > 0.00 & has_underparts_color_yellow > 0.00 & has_upperparts_color_black > 0.00 & has_crown_color_blue > 0.00 & has_belly_color_buff > 0.00 & has_breast_color_grey > 0.01 & has_bill_shape_cone > 0.01 & has_upper_tail_color_black > 0.01 & has_forehead_color_yellow > 0.02 & has_nape_color_buff <= 0.10) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird > 0.41 & has_forehead_color_black <= 0.95 & has_head_pattern_plain <= 0.75) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black <= 0.74 & has_under_tail_color_white <= 0.60 & has_bill_color_black > 0.02 & has_wing_pattern_solid > 0.99 & has_belly_color_black <= 0.05 & has_upper_tail_color_brown > 0.00)
# Elapsed time 0.012978792190551758
# 003.Sooty_Albatross <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black <= 0.61 & has_breast_pattern_multicolored <= 0.98 & has_forehead_color_red <= 0.82 & has_upperparts_color_buff <= 0.75 & has_breast_color_grey <= 0.97 & has_under_tail_color_brown <= 0.99 & has_primary_color_grey <= 0.97 & has_crown_color_blue <= 0.95 & has_back_color_brown <= 0.94 & has_bill_length_shorter_than_head > 0.00 & has_breast_color_buff <= 0.99 & has_belly_color_buff <= 0.96 & has_tail_pattern_multicolored <= 1.00 & has_upper_tail_color_brown <= 1.00 & has_under_tail_color_grey <= 0.98 & has_back_color_grey <= 1.00 & has_wing_pattern_solid <= 1.00 & has_leg_color_black <= 1.00 & has_tail_shape_notched_tail <= 1.00 & has_head_pattern_plain <= 0.99 & has_primary_color_brown <= 0.97 & has_eye_color_black > 0.20 & has_belly_pattern_solid > 0.00 & has_bill_shape_allpurpose <= 0.97 & has_breast_color_white > 0.73 & has_leg_color_grey > 0.11 & has_bill_color_black > 0.07 & has_breast_pattern_solid > 0.56 & has_bill_length_about_the_same_as_head <= 0.98 & has_upperparts_color_brown <= 0.71 & has_bill_length_about_the_same_as_head <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black <= 0.74 & has_under_tail_color_white <= 0.60 & has_bill_color_black > 0.02 & has_wing_pattern_solid <= 0.99 & has_tail_pattern_solid <= 0.93 & has_nape_color_black <= 0.01 & has_nape_color_grey <= 0.00 & has_under_tail_color_white <= 0.00 & has_under_tail_color_black <= 1.00 & has_forehead_color_blue <= 0.00 & has_crown_color_grey <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black <= 0.74 & has_under_tail_color_white <= 0.60 & has_bill_color_black > 0.02 & has_wing_pattern_solid <= 0.99 & has_tail_pattern_solid > 0.93 & has_underparts_color_white <= 0.28 & has_under_tail_color_buff > 0.00 & has_under_tail_color_brown <= 0.01) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black <= 0.74 & has_under_tail_color_white <= 0.60 & has_bill_color_black > 0.02 & has_wing_pattern_solid > 0.99 & has_belly_color_black <= 0.05 & has_upper_tail_color_brown <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white > 0.57 & has_breast_pattern_multicolored <= 0.15 & has_back_color_yello ...
# Elapsed time 0.01399993896484375
# 004.Groove_billed_Ani <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black > 0.61 & has_nape_color_blue <= 0.23 & has_upperparts_color_grey <= 0.12 & has_bill_length_shorter_than_head > 0.01 & has_back_color_brown <= 0.27 & has_wing_pattern_solid > 0.01 & has_bill_shape_allpurpose <= 0.82 & has_wing_shape_roundedwings <= 0.67 & has_shape_perchinglike <= 0.01) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black > 0.61 & has_nape_color_blue <= 0.23 & has_upperparts_color_grey <= 0.12 & has_bill_length_shorter_than_head > 0.01 & has_back_color_brown <= 0.27 & has_wing_pattern_solid > 0.01 & has_bill_shape_allpurpose <= 0.82 & has_wing_shape_roundedwings <= 0.67 & has_shape_perchinglike > 0.01 & has_leg_color_grey > 0.00 & has_forehead_color_blue <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black > 0.92 & has_leg_color_black > 0.56 & has_wing_shape_roundedwings > 0.38 & has_head_pattern_plain > 0.89 & has_shape_perchinglike <= 0.98 & has_nape_color_black > 1.00 & has_wing_shape_roundedwings <= 1.00 & has_nape_color_black > 1.00 & has_bill_length_shorter_than_head <= 0.00)
# Elapsed time 0.012997865676879883
# 005.Crested_Auklet <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black > 0.74 & has_wing_color_grey <= 0.63 & has_under_tail_color_grey <= 0.11 & has_bill_length_about_the_same_as_head <= 1.00 & has_underparts_color_grey > 0.00 & has_throat_color_black <= 0.83 & has_nape_color_yellow <= 0.00 & has_bill_shape_allpurpose <= 0.00 & has_back_color_black <= 1.00 & has_size_small_5__9_in <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black > 0.74 & has_wing_color_grey <= 0.63 & has_under_tail_color_grey <= 0.11 & has_bill_length_about_the_same_as_head <= 1.00 & has_underparts_color_grey > 0.00 & has_throat_color_black > 0.83 & has_belly_color_white <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black > 0.74 & has_wing_color_grey <= 0.63 & has_under_tail_color_grey <= 0.11 & has_bill_length_about_the_same_as_head <= 1.00 & has_underparts_color_grey > 0.00 & has_throat_color_black > 0.83 & has_belly_color_white > 0.00 & has_throat_color_black <= 0.99 & has_breast_color_brown <= 0.01) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black > 0.92 & has_leg_color_black > 0.56 & has_wing_shape_roundedwings > 0.38 & has_head_pattern_plain <= 0.89 & has_wing_shape_roundedwings <= 0.88)
# Elapsed time 0.010000467300415039
# 006.Least_Auklet <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black <= 0.61 & has_breast_pattern_multicolored <= 0.98 & has_forehead_color_red <= 0.82 & has_upperparts_color_buff <= 0.75 & has_breast_color_grey <= 0.97 & has_under_tail_color_brown <= 0.99 & has_primary_color_grey <= 0.97 & has_crown_color_blue <= 0.95 & has_back_color_brown <= 0.94 & has_bill_length_shorter_than_head > 0.00 & has_breast_color_buff <= 0.99 & has_belly_color_buff <= 0.96 & has_tail_pattern_multicolored <= 1.00 & has_upper_tail_color_brown <= 1.00 & has_under_tail_color_grey <= 0.98 & has_back_color_grey <= 1.00 & has_wing_pattern_solid <= 1.00 & has_leg_color_black <= 1.00 & has_tail_shape_notched_tail <= 1.00 & has_head_pattern_plain <= 0.99 & has_primary_color_brown <= 0.97 & has_eye_color_black <= 0.20 & has_wing_color_black > 0.50) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black > 0.61 & has_nape_color_blue <= 0.23 & has_upperparts_color_grey <= 0.12 & has_bill_length_shorter_than_head > 0.01 & has_back_color_brown <= 0.27 & has_wing_pattern_solid > 0.01 & has_bill_shape_allpurpose <= 0.82 & has_wing_shape_roundedwings > 0.67 & has_bill_length_shorter_than_head <= 1.00 & has_nape_color_black <= 1.00 & has_forehead_color_grey > 0.00 & has_leg_color_grey > 0.00 & has_breast_pattern_solid <= 0.81) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black > 0.74 & has_wing_color_grey <= 0.63 & has_under_tail_color_grey <= 0.11 & has_bill_length_about_the_same_as_head <= 1.00 & has_underparts_color_grey > 0.00 & has_throat_color_black <= 0.83 & has_nape_color_yellow <= 0.00 & has_bill_shape_allpurpose > 0.00)
# Elapsed time 0.009999513626098633
# 007.Parakeet_Auklet <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black > 0.74 & has_wing_color_grey <= 0.63 & has_under_tail_color_grey <= 0.11 & has_bill_length_about_the_same_as_head <= 1.00 & has_underparts_color_grey <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black > 0.74 & has_wing_color_grey <= 0.63 & has_under_tail_color_grey <= 0.11 & has_bill_length_about_the_same_as_head <= 1.00 & has_underparts_color_grey > 0.00 & has_throat_color_black > 0.83 & has_belly_color_white > 0.00 & has_throat_color_black > 0.99)
# Elapsed time 0.013001680374145508
# 008.Rhinoceros_Auklet <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black > 0.74 & has_wing_color_grey <= 0.63 & has_under_tail_color_grey <= 0.11 & has_bill_length_about_the_same_as_head <= 1.00 & has_underparts_color_grey > 0.00 & has_throat_color_black <= 0.83 & has_nape_color_yellow <= 0.00 & has_bill_shape_allpurpose <= 0.00 & has_back_color_black <= 1.00 & has_size_small_5__9_in > 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in > 0.51 & has_crown_color_grey <= 0.51 & has_bill_shape_dagger <= 0.56 & has_crown_color_brown <= 0.75 & has_belly_pattern_solid > 0.01 & has_breast_color_brown <= 0.35 & has_breast_color_black <= 0.92 & has_primary_color_black > 0.74 & has_wing_color_grey <= 0.63 & has_under_tail_color_grey <= 0.11 & has_bill_length_about_the_same_as_head <= 1.00 & has_underparts_color_grey > 0.00 & has_throat_color_black <= 0.83 & has_nape_color_yellow <= 0.00 & has_bill_shape_allpurpose <= 0.00 & has_back_color_black > 1.00)
# Elapsed time 0.012998104095458984
# 009.Brewer_Blackbird <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black <= 0.61 & has_breast_pattern_multicolored <= 0.98 & has_forehead_color_red <= 0.82 & has_upperparts_color_buff <= 0.75 & has_breast_color_grey <= 0.97 & has_under_tail_color_brown <= 0.99 & has_primary_color_grey <= 0.97 & has_crown_color_blue <= 0.95 & has_back_color_brown <= 0.94 & has_bill_length_shorter_than_head > 0.00 & has_breast_color_buff <= 0.99 & has_belly_color_buff <= 0.96 & has_tail_pattern_multicolored <= 1.00 & has_upper_tail_color_brown <= 1.00 & has_under_tail_color_grey <= 0.98 & has_back_color_grey <= 1.00 & has_wing_pattern_solid <= 1.00 & has_leg_color_black <= 1.00 & has_tail_shape_notched_tail <= 1.00 & has_head_pattern_plain <= 0.99 & has_primary_color_brown <= 0.97 & has_eye_color_black > 0.20 & has_belly_pattern_solid > 0.00 & has_bill_shape_allpurpose > 0.97 & has_wing_pattern_striped <= 0.92 & has_primary_color_white <= 0.64 & has_upperparts_color_black > 0.00 & has_wing_color_black > 0.11 & has_primary_color_yellow <= 0.45 & has_breast_color_black > 0.00 & has_size_small_5__9_in > 0.99 & has_size_very_small_3__5_in <= 0.00 & has_breast_color_yellow > 0.00 & has_upperparts_color_black > 0.00 & has_back_pattern_multicolored > 0.00 & has_wing_shape_roundedwings > 0.66 & has_underparts_color_buff > 0.00 & has_nape_color_brown > 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black > 0.61 & has_nape_color_blue <= 0.23 & has_upperparts_color_grey <= 0.12 & has_bill_length_shorter_than_head > 0.01 & has_back_color_brown <= 0.27 & has_wing_pattern_solid > 0.01 & has_bill_shape_allpurpose <= 0.82 & has_wing_shape_roundedwings <= 0.67 & has_shape_perchinglike > 0.01 & has_leg_color_grey <= 0.00 & has_wing_pattern_multicolored <= 0.00 & has_wing_color_black <= 1.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black > 0.61 & has_nape_color_blue <= 0.23 & has_upperparts_color_grey <= 0.12 & has_bill_length_shorter_than_head > 0.01 & has_back_color_brown <= 0.27 & has_wing_pattern_solid > 0.01 & has_bill_shape_allpurpose <= 0.82 & has_wing_shape_roundedwings > 0.67 & has_bill_length_shorter_than_head > 1.00 & has_wing_pattern_multicolored <= 0.00 & has_bi ...
# Elapsed time 0.014000177383422852
# 010.Red_winged_Blackbird <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black <= 0.61 & has_breast_pattern_multicolored <= 0.98 & has_forehead_color_red <= 0.82 & has_upperparts_color_buff <= 0.75 & has_breast_color_grey <= 0.97 & has_under_tail_color_brown <= 0.99 & has_primary_color_grey <= 0.97 & has_crown_color_blue <= 0.95 & has_back_color_brown <= 0.94 & has_bill_length_shorter_than_head > 0.00 & has_breast_color_buff <= 0.99 & has_belly_color_buff <= 0.96 & has_tail_pattern_multicolored <= 1.00 & has_upper_tail_color_brown <= 1.00 & has_under_tail_color_grey <= 0.98 & has_back_color_grey <= 1.00 & has_wing_pattern_solid <= 1.00 & has_leg_color_black <= 1.00 & has_tail_shape_notched_tail <= 1.00 & has_head_pattern_plain > 0.99 & has_breast_pattern_multicolored <= 0.00 & has_size_medium_9__16_in > 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black > 0.61 & has_nape_color_blue <= 0.23 & has_upperparts_color_grey <= 0.12 & has_bill_length_shorter_than_head > 0.01 & has_back_color_brown <= 0.27 & has_wing_pattern_solid <= 0.01 & has_upper_tail_color_white <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black > 0.61 & has_nape_color_blue <= 0.23 & has_upperparts_color_grey <= 0.12 & has_bill_length_shorter_than_head > 0.01 & has_back_color_brown <= 0.27 & has_wing_pattern_solid > 0.01 & has_bill_shape_allpurpose <= 0.82 & has_wing_shape_roundedwings > 0.67 & has_bill_length_shorter_than_head <= 1.00 & has_nape_color_black <= 1.00 & has_forehead_color_grey > 0.00 & has_leg_color_grey <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white > 0.57 & has_breast_pattern_multicolored <= 0.15 & has_back_color_yellow <= 0.45 & has_bill_shape_cone <= 0.91 & has_leg_color_grey <= 0.67 & has_crown_color_white <= 0.05 & has_nape_color_black > 0.12 & has_bill_color_black > 0.99 & has_shape_perchinglike > 0.50)
# Elapsed time 0.015001058578491211
# 011.Rusty_Blackbird <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black > 0.61 & has_nape_color_blue <= 0.23 & has_upperparts_color_grey <= 0.12 & has_bill_length_shorter_than_head > 0.01 & has_back_color_brown <= 0.27 & has_wing_pattern_solid > 0.01 & has_bill_shape_allpurpose <= 0.82 & has_wing_shape_roundedwings <= 0.67 & has_shape_perchinglike > 0.01 & has_leg_color_grey <= 0.00 & has_wing_pattern_multicolored <= 0.00 & has_wing_color_black > 1.00 & has_breast_pattern_multicolored > 0.00 & has_primary_color_black <= 1.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black > 0.61 & has_nape_color_blue <= 0.23 & has_upperparts_color_grey <= 0.12 & has_bill_length_shorter_than_head > 0.01 & has_back_color_brown <= 0.27 & has_wing_pattern_solid > 0.01 & has_bill_shape_allpurpose > 0.82 & has_wing_shape_roundedwings > 0.01 & has_shape_perchinglike <= 0.04 & has_wing_shape_roundedwings > 0.84 & has_bill_shape_allpurpose <= 1.00 & has_bill_shape_allpurpose <= 0.99 & has_back_color_white <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black > 0.61 & has_nape_color_blue <= 0.23 & has_upperparts_color_grey <= 0.12 & has_bill_length_shorter_than_head > 0.01 & has_back_color_brown <= 0.27 & has_wing_pattern_solid > 0.01 & has_bill_shape_allpurpose > 0.82 & has_wing_shape_roundedwings > 0.01 & has_shape_perchinglike > 0.04 & has_back_color_white > 0.00 & has_back_color_white <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black > 0.61 & has_nape_color_blue <= 0.23 & has_upperparts_color_grey <= 0.12 & has_bill_length_shorter_than_head > 0.01 & has_ba ...
# Elapsed time 0.01699995994567871
# 012.Yellow_headed_Blackbird <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black <= 0.61 & has_breast_pattern_multicolored <= 0.98 & has_forehead_color_red <= 0.82 & has_upperparts_color_buff <= 0.75 & has_breast_color_grey <= 0.97 & has_under_tail_color_brown <= 0.99 & has_primary_color_grey <= 0.97 & has_crown_color_blue <= 0.95 & has_back_color_brown <= 0.94 & has_bill_length_shorter_than_head > 0.00 & has_breast_color_buff <= 0.99 & has_belly_color_buff <= 0.96 & has_tail_pattern_multicolored <= 1.00 & has_upper_tail_color_brown <= 1.00 & has_under_tail_color_grey <= 0.98 & has_back_color_grey <= 1.00 & has_wing_pattern_solid <= 1.00 & has_leg_color_black <= 1.00 & has_tail_shape_notched_tail <= 1.00 & has_head_pattern_plain <= 0.99 & has_primary_color_brown <= 0.97 & has_eye_color_black > 0.20 & has_belly_pattern_solid > 0.00 & has_bill_shape_allpurpose <= 0.97 & has_breast_color_white > 0.73 & has_leg_color_grey > 0.11 & has_bill_color_black > 0.07 & has_breast_pattern_solid > 0.56 & has_bill_length_about_the_same_as_head <= 0.98 & has_upperparts_color_brown <= 0.71 & has_bill_length_about_the_same_as_head > 0.00 & has_breast_color_yellow > 0.00 & has_underparts_color_yellow > 0.00 & has_upperparts_color_black > 0.00 & has_crown_color_blue <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow > 0.84 & has_upperparts_color_white <= 0.64 & has_bill_length_about_the_same_as_head <= 0.71 & has_forehead_color_grey <= 0.92 & has_back_color_grey <= 0.98 & has_primary_color_yellow > 0.15 & has_wing_pattern_multicolored <= 0.99 & has_nape_color_black <= 0.97 & has_belly_color_black <= 0.23 & has_crown_color_black <= 0.43 & has_back_pattern_solid <= 0.99 & has_wing_color_white <= 0.76 & has_belly_color_white <= 0.50 & has_bill_color_black > 0.03 & has_head_pattern_capped <= 0.01 & has_head_pattern_plain > 0.00 & has_wing_shape_roundedwings <= 0.99 & has_nape_color_yellow <= 0.96 & has_under_tail_color_white > 0.00 & has_nape_color_yellow > 0.00 & has_back_pattern_striped > 0.00 & has_under_tail_color_black > 0.02 & has_upper_tail_color_white > 0.00 & has_upperparts_color_grey > 0.24 & has_forehead_color_white > 0.00 & has_bill_shape_hooked_seabird <= 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow > 0.84 & has_upperparts_color_white <= 0.64 & has_bill_length_about_the_same_as_head <= 0.71 & has_forehead_color_grey <= 0.92 & has_back_color_grey <= 0.98 & has_primary_color_yellow > 0.15 & has_wing_pattern_multicolored <= 0.99 & has_nape_color_black <= 0.97 & has_belly_color_black > 0.23) | (has_back_pattern_striped > 0.36 & has_head_pattern_capped <= 0.16 & has_forehead_color_white <= 0.44 & has_primary_color_white <= 0.58 & has_bill_length_about_the_same_as_head <= 0.23 & has_under_tail_color_black <= 0.58 & has_forehead_color_black <= 0.43 & has_wing_color_white <= 0.25 & has_back_color_yellow <= 0.95 & has ...
# Elapsed time 0.01199960708618164
# 013.Bobolink <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black > 0.61 & has_nape_color_blue <= 0.23 & has_upperparts_color_grey <= 0.12 & has_bill_length_shorter_than_head > 0.01 & has_back_color_brown <= 0.27 & has_wing_pattern_solid > 0.01 & has_bill_shape_allpurpose <= 0.82 & has_wing_shape_roundedwings <= 0.67 & has_shape_perchinglike > 0.01 & has_leg_color_grey <= 0.00 & has_wing_pattern_multicolored > 0.00) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white > 0.57 & has_breast_pattern_multicolored <= 0.15 & has_back_color_yellow <= 0.45 & has_bill_shape_cone > 0.91)
# Elapsed time 0.012000083923339844
# 014.Indigo_Bunting <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black <= 0.61 & has_breast_pattern_multicolored <= 0.98 & has_forehead_color_red <= 0.82 & has_upperparts_color_buff <= 0.75 & has_breast_color_grey <= 0.97 & has_under_tail_color_brown <= 0.99 & has_primary_color_grey <= 0.97 & has_crown_color_blue <= 0.95 & has_back_color_brown <= 0.94 & has_bill_length_shorter_than_head > 0.00 & has_breast_color_buff <= 0.99 & has_belly_color_buff <= 0.96 & has_tail_pattern_multicolored <= 1.00 & has_upper_tail_color_brown <= 1.00 & has_under_tail_color_grey <= 0.98 & has_back_color_grey <= 1.00 & has_wing_pattern_solid <= 1.00 & has_leg_color_black <= 1.00 & has_tail_shape_notched_tail <= 1.00 & has_head_pattern_plain <= 0.99 & has_primary_color_brown <= 0.97 & has_eye_color_black > 0.20 & has_belly_pattern_solid > 0.00 & has_bill_shape_allpurpose <= 0.97 & has_breast_color_white <= 0.73 & has_wing_color_white <= 0.72 & has_throat_color_white <= 0.76 & has_underparts_color_brown <= 0.29 & has_upperparts_color_buff > 0.00 & has_breast_color_black > 0.00 & has_primary_color_white <= 0.61 & has_belly_color_buff <= 0.72 & has_bill_shape_cone <= 0.21 & has_throat_color_white > 0.00 & has_bill_length_shorter_than_head > 0.04 & has_nape_color_grey <= 0.59 & has_breast_pattern_solid > 0.66 & has_nape_color_brown <= 0.04 & has_under_tail_color_white <= 0.06 & has_belly_color_yellow > 0.01 & has_bill_shape_allpurpose <= 0.95 & has_forehead_color_blue > 0.09 & has_nape_color_blue > 0.20 & has_breast_color_yellow > 0.06 & has_back_pattern_solid <= 0.39) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black <= 0.61 & has_breast_pattern_multicolored <= 0.98 & has_forehead_color_red <= 0.82 & has_upperparts_color_buff <= 0.75 & has_breast_color_grey <= 0.97 & has_under_tail_color_brown <= 0.99 & has_primary_color_grey <= 0.97 & has_crown_color_blue <= 0.95 & has_back_color_brown <= 0.94 & has_bill_length_shorter_than_head > 0.00 & has_breast_color_buff <= 0.99 & has_belly_color_buff <= 0.96 & has_tail_pattern_multicolored <= 1.00 & has_upper_tail_color_brown <= 1.00 & has_under_tail_color_grey <= 0.98 & has_back_color_grey <= 1.00 & has_wing_pattern_solid <= 1.00 & has_leg_color_black <= 1.00 & has_tail_shape_notched_tail <= 1.00 & has_head_pattern_plain <= 0.99 & has_primary_color_brown <= 0.97 & has_eye_color_black > 0.20 & has_belly_pattern_solid > 0.00 & has_bill_shape_allpurpose <= 0.97 & has_breast_color_white <= 0.73 & has_wing_color_white <= 0.72 & has_throat_color_white <= 0.76 & has_underparts_color_brown <= 0.29 & has_upperparts_color_buff > 0.00 & has_breast_color_black > 0.00 & has_primary_color_white <= 0.61 & has_belly_color_buff <= 0.72 & has_bill_shape_cone > 0.21 & has_bill_color_black <= 0.99 & has_throat_color_yellow > 0.00 & has_underp ...
# Elapsed time 0.013999223709106445
# 015.Lazuli_Bunting <-> (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black <= 0.61 & has_breast_pattern_multicolored <= 0.98 & has_forehead_color_red <= 0.82 & has_upperparts_color_buff <= 0.75 & has_breast_color_grey <= 0.97 & has_under_tail_color_brown <= 0.99 & has_primary_color_grey <= 0.97 & has_crown_color_blue <= 0.95 & has_back_color_brown <= 0.94 & has_bill_length_shorter_than_head > 0.00 & has_breast_color_buff <= 0.99 & has_belly_color_buff <= 0.96 & has_tail_pattern_multicolored <= 1.00 & has_upper_tail_color_brown <= 1.00 & has_under_tail_color_grey <= 0.98 & has_back_color_grey <= 1.00 & has_wing_pattern_solid <= 1.00 & has_leg_color_black <= 1.00 & has_tail_shape_notched_tail <= 1.00 & has_head_pattern_plain <= 0.99 & has_primary_color_brown <= 0.97 & has_eye_color_black > 0.20 & has_belly_pattern_solid > 0.00 & has_bill_shape_allpurpose <= 0.97 & has_breast_color_white <= 0.73 & has_wing_color_white <= 0.72 & has_throat_color_white <= 0.76 & has_underparts_color_brown <= 0.29 & has_upperparts_color_buff > 0.00 & has_breast_color_black > 0.00 & has_primary_color_white <= 0.61 & has_belly_color_buff <= 0.72 & has_bill_shape_cone > 0.21 & has_bill_color_black <= 0.99 & has_throat_color_yellow > 0.00 & has_underparts_color_white <= 0.89 & has_crown_color_yellow <= 0.21 & has_wing_color_white <= 0.21 & has_back_color_grey <= 0.55 & has_head_pattern_plain <= 0.19 & has_wing_pattern_multicolored <= 0.92 & has_wing_pattern_multicolored <= 0.83 & has_bill_color_black <= 0.82 & has_breast_pattern_solid > 0.03 & has_forehead_color_white > 0.00 & has_nape_color_brown > 0.00 & has_leg_color_buff <= 0.01) | (has_back_pattern_striped <= 0.36 & has_under_tail_color_buff <= 0.69 & has_back_color_buff <= 0.69 & has_upper_tail_color_white <= 0.57 & has_under_tail_color_yellow <= 0.62 & has_size_medium_9__16_in <= 0.51 & has_bill_shape_hooked_seabird <= 0.41 & has_underparts_color_grey <= 0.74 & has_breast_color_yellow <= 0.84 & has_bill_shape_dagger <= 0.61 & has_head_pattern_capped <= 0.91 & has_forehead_color_brown <= 0.28 & has_leg_color_buff <= 0.95 & has_nape_color_brown <= 0.59 & has_size_very_small_3__5_in <= 0.47 & has_back_pattern_multicolored <= 0.98 & has_forehead_color_white <= 0.65 & has_forehead_color_yellow <= 0.83 & has_belly_color_black <= 0.61 & has_breast_pattern_multicolored <= 0.98 & has_forehead_color_red <= 0.82 & has_upperparts_color_buff <= 0.75 & has_breast_color_grey <= 0.97 & has_under_tail_color_brown <= 0.99 & has_primary_color_grey <= 0.97 & has_crown_color_blue <= 0.95 & has_back_color_brown <= 0.94 & has_bill_length_shorter_than_head > 0.00 & has_breast_color_buff <= 0.99 & has_belly_color_buff <= 0.96 & has_tail_pattern_multicolored <= 1.00 & has_upper_tail_color_brown <= 1.00 & has_under_tail_color_grey <= 0.98 & has_back_color_grey <= 1.00 & has_wing_pattern_solid <= 1.00 & has_leg_color_black <= 1.00 & has_tail_shape_notched_tail <= 1.00 & has_head_pattern_plain <= 0.99 & has_primary_color_brown <= 0.97 & has_eye_color_black > 0.20 & has_belly_pattern_solid > 0.00 & has_bill_shape_allpurpose <= 0.97 & has_breast_color_white <= 0.73 & has_wing_color_white <= 0.72 & has_throat_color_white <= 0.76 & has_underparts_color_brown <= 0.29 & has_upperparts_color_buff > 0.00 & has_breast_color_black > 0.00 & has_primary_color_white <= 0.61 & has_belly_color_buff <= 0.72 & has_bill_shape_cone > 0.21 & has_bill_col ...
# Elapsed time 0.01300191879272461
# ...
# Elapsed time 0.014000415802001953
# 198.Rock_Wren <-> (has_upper_tail_color_white <= 0.58 & has_back_pattern_striped <= 0.36 & has_back_color_buff <= 0.73 & has_size_medium_9__16_in <= 0.29 & has_bill_shape_hooked_seabird <= 0.40 & has_forehead_color_yellow <= 0.61 & has_underparts_color_grey <= 0.74 & has_under_tail_color_buff <= 0.82 & has_crown_color_white <= 0.53 & has_forehead_color_red <= 0.83 & has_size_very_small_3__5_in <= 0.80 & has_primary_color_buff <= 0.97 & has_nape_color_blue <= 0.42 & has_back_pattern_multicolored <= 0.93 & has_nape_color_yellow <= 0.94 & has_belly_color_black <= 0.81 & has_nape_color_white <= 0.92 & has_bill_shape_dagger <= 0.91 & has_breast_pattern_striped <= 0.97 & has_throat_color_black <= 0.97 & has_forehead_color_black <= 1.00 & has_throat_color_grey <= 0.28 & has_eye_color_black > 0.15 & has_breast_color_brown <= 0.91 & has_belly_color_yellow <= 1.00 & has_nape_color_buff <= 0.95 & has_primary_color_black <= 1.00 & has_upperparts_color_black <= 0.99 & has_breast_color_black <= 0.93 & has_size_small_5__9_in > 0.03 & has_wing_color_yellow <= 0.97 & has_wing_color_white <= 0.94 & has_primary_color_white <= 0.84 & has_under_tail_color_grey <= 1.00 & has_upper_tail_color_grey <= 1.00 & has_tail_pattern_multicolored <= 1.00 & has_head_pattern_plain <= 0.98 & has_throat_color_yellow <= 0.97 & has_leg_color_black <= 1.00 & has_under_tail_color_black <= 0.99 & has_nape_color_grey <= 1.00 & has_underparts_color_brown <= 0.95 & has_shape_perchinglike > 0.00 & has_belly_pattern_solid > 0.00 & has_nape_color_brown <= 1.00 & has_nape_color_brown <= 1.00 & has_size_very_small_3__5_in > 0.00 & has_nape_color_white <= 0.42 & has_underparts_color_yellow <= 0.96 & has_under_tail_color_brown <= 0.95 & has_leg_color_grey > 0.00 & has_bill_shape_cone <= 0.04 & has_leg_color_black <= 0.33 & has_leg_color_grey > 0.00 & has_wing_shape_roundedwings > 0.00 & has_throat_color_yellow <= 0.73 & has_crown_color_white <= 0.00 & has_breast_color_brown <= 0.00 & has_breast_color_buff <= 0.00 & has_crown_color_white <= 0.00 & has_upperparts_color_buff <= 0.07 & has_underparts_color_brown <= 0.00 & has_forehead_color_white <= 0.00 & has_primary_color_black > 0.00 & has_back_pattern_multicolored > 0.00 & has_bill_color_black > 0.00 & has_belly_color_buff > 0.00 & has_throat_color_white > 0.00 & has_bill_color_grey > 0.00 & has_breast_color_white > 0.00 & has_back_pattern_striped > 0.00 & has_underparts_color_white > 0.01 & has_breast_color_grey > 0.00 & has_upperparts_color_black > 0.00 & has_head_pattern_capped > 0.00 & has_bill_shape_cone > 0.00 & has_shape_perchinglike > 0.51 & has_upperparts_color_yellow > 0.00 & has_forehead_color_grey > 0.00 & has_crown_color_yellow > 0.00 & has_breast_pattern_striped <= 0.00) | (has_upper_tail_color_white <= 0.58 & has_back_pattern_striped <= 0.36 & has_back_color_buff <= 0.73 & has_size_medium_9__16_in <= 0.29 & has_bill_shape_hooked_seabird <= 0.40 & has_forehead_color_yellow <= 0.61 & has_underparts_color_grey <= 0.74 & has_under_tail_color_buff <= 0.82 & has_crown_color_white <= 0.53 & has_forehead_color_red <= 0.83 & has_size_very_small_3__5_in <= 0.80 & has_primary_color_buff <= 0.97 & has_nape_color_blue <= 0.42 & has_back_pattern_multicolored <= 0.93 & has_nape_color_yellow <= 0.94 & has_belly_color_black <= 0.81 & has_nape_color_white <= 0.92 & has_bill_shape_dagger <= 0.91 & has_breast_pattern_striped <= 0.97 & has_throat_color_black <= 0.97 & has_forehead_color_black <= 1.00 & has_throat_color_grey <= 0.28 & has_eye_color_black > 0.15 & has_breast_color_brown <= 0.91 & has_belly_color_yellow <= 1.00 & has_nape_color_buff <= 0.95 & has_primary_color_black <= 1.00 & has_upperparts_color_black <= 0.99 & has_breast_color_black <= 0.93 & has_size_small_5__9_in > 0.03 & has_wing_color_yellow <= 0.97 & has_wing_color_white <= 0.94 & has_primary_color_white <= 0.84 & has_under_tail_color_grey <= 1.00 & has_upper_tail_color_grey <= 1.00 & has_tail_pattern_multicolored <= 1.00 & has_head_pattern_plain <= 0.98 & has_th ...
# Elapsed time 0.014950990676879883
# 199.Winter_Wren <-> (has_upper_tail_color_white <= 0.58 & has_back_pattern_striped <= 0.36 & has_back_color_buff <= 0.73 & has_size_medium_9__16_in <= 0.29 & has_bill_shape_hooked_seabird <= 0.40 & has_forehead_color_yellow <= 0.61 & has_underparts_color_grey <= 0.74 & has_under_tail_color_buff <= 0.82 & has_crown_color_white <= 0.53 & has_forehead_color_red <= 0.83 & has_size_very_small_3__5_in <= 0.80 & has_primary_color_buff <= 0.97 & has_nape_color_blue <= 0.42 & has_back_pattern_multicolored <= 0.93 & has_nape_color_yellow <= 0.94 & has_belly_color_black <= 0.81 & has_nape_color_white <= 0.92 & has_bill_shape_dagger <= 0.91 & has_breast_pattern_striped <= 0.97 & has_throat_color_black <= 0.97 & has_forehead_color_black <= 1.00 & has_throat_color_grey <= 0.28 & has_eye_color_black > 0.15 & has_breast_color_brown <= 0.91 & has_belly_color_yellow <= 1.00 & has_nape_color_buff <= 0.95 & has_primary_color_black <= 1.00 & has_upperparts_color_black <= 0.99 & has_breast_color_black <= 0.93 & has_size_small_5__9_in <= 0.03 & has_wing_pattern_solid <= 0.79 & has_throat_color_black <= 0.00 & has_underparts_color_brown > 0.00) | (has_upper_tail_color_white <= 0.58 & has_back_pattern_striped <= 0.36 & has_back_color_buff <= 0.73 & has_size_medium_9__16_in <= 0.29 & has_bill_shape_hooked_seabird <= 0.40 & has_forehead_color_yellow <= 0.61 & has_underparts_color_grey <= 0.74 & has_under_tail_color_buff <= 0.82 & has_crown_color_white <= 0.53 & has_forehead_color_red <= 0.83 & has_size_very_small_3__5_in <= 0.80 & has_primary_color_buff <= 0.97 & has_nape_color_blue <= 0.42 & has_back_pattern_multicolored <= 0.93 & has_nape_color_yellow <= 0.94 & has_belly_color_black <= 0.81 & has_nape_color_white <= 0.92 & has_bill_shape_dagger <= 0.91 & has_breast_pattern_striped <= 0.97 & has_throat_color_black <= 0.97 & has_forehead_color_black <= 1.00 & has_throat_color_grey <= 0.28 & has_eye_color_black > 0.15 & has_breast_color_brown <= 0.91 & has_belly_color_yellow <= 1.00 & has_nape_color_buff <= 0.95 & has_primary_color_black <= 1.00 & has_upperparts_color_black <= 0.99 & has_breast_color_black <= 0.93 & has_size_small_5__9_in > 0.03 & has_wing_color_yellow <= 0.97 & has_wing_color_white <= 0.94 & has_primary_color_white <= 0.84 & has_under_tail_color_grey <= 1.00 & has_upper_tail_color_grey <= 1.00 & has_tail_pattern_multicolored <= 1.00 & has_head_pattern_plain <= 0.98 & has_throat_color_yellow <= 0.97 & has_leg_color_black <= 1.00 & has_under_tail_color_black <= 0.99 & has_nape_color_grey <= 1.00 & has_underparts_color_brown <= 0.95 & has_shape_perchinglike > 0.00 & has_belly_pattern_solid > 0.00 & has_nape_color_brown <= 1.00 & has_nape_color_brown <= 1.00 & has_size_very_small_3__5_in > 0.00 & has_nape_color_white <= 0.42 & has_underparts_color_yellow <= 0.96 & has_under_tail_color_brown <= 0.95 & has_leg_color_grey > 0.00 & has_bill_shape_cone > 0.04 & has_belly_color_buff <= 0.72 & has_breast_color_white <= 0.90 & has_breast_color_yellow <= 0.34 & has_tail_shape_notched_tail <= 1.00 & has_wing_color_white <= 0.21 & has_tail_pattern_solid > 0.01 & has_wing_shape_roundedwings > 0.02 & has_underparts_color_yellow > 0.00 & has_wing_shape_roundedwings <= 0.99 & has_upperparts_color_black <= 0.67 & has_upper_tail_color_black <= 0.41 & has_belly_color_yellow > 0.01 & has_leg_color_black <= 0.70 & has_forehead_color_red > 0.00 & has_head_pattern_plain > 0.01 & has_upperparts_color_white > 0.00 & has_bill_length_about_the_same_as_head > 0.00 & has_crown_color_white > 0.00 & has_primary_color_grey > 0.00 & has_breast_color_yellow > 0.00 & has_belly_color_grey > 0.00 & has_wing_color_buff > 0.00 & has_back_pattern_multicolored > 0.01 & has_wing_color_grey > 0.01 & has_tail_pattern_multicolored > 0.01 & has_wing_color_yellow > 0.01 & has_back_color_grey > 0.02 & has_bill_shape_cone > 0.05 & has_under_tail_color_grey > 0.01 & has_tail_pattern_solid > 0.08 & has_belly_color_white > 0.04 & has_head_pattern_capped > 0.00 & has_size_very_small_3__5_in  ...
# Elapsed time 0.017998695373535156
# 200.Common_Yellowthroat <-> (has_upper_tail_color_white <= 0.58 & has_back_pattern_striped <= 0.36 & has_back_color_buff <= 0.73 & has_size_medium_9__16_in <= 0.29 & has_bill_shape_hooked_seabird <= 0.40 & has_forehead_color_yellow <= 0.61 & has_underparts_color_grey <= 0.74 & has_under_tail_color_buff <= 0.82 & has_crown_color_white <= 0.53 & has_forehead_color_red <= 0.83 & has_size_very_small_3__5_in <= 0.80 & has_primary_color_buff <= 0.97 & has_nape_color_blue <= 0.42 & has_back_pattern_multicolored <= 0.93 & has_nape_color_yellow <= 0.94 & has_belly_color_black <= 0.81 & has_nape_color_white <= 0.92 & has_bill_shape_dagger <= 0.91 & has_breast_pattern_striped <= 0.97 & has_throat_color_black <= 0.97 & has_forehead_color_black <= 1.00 & has_throat_color_grey <= 0.28 & has_eye_color_black > 0.15 & has_breast_color_brown <= 0.91 & has_belly_color_yellow <= 1.00 & has_nape_color_buff <= 0.95 & has_primary_color_black <= 1.00 & has_upperparts_color_black <= 0.99 & has_breast_color_black <= 0.93 & has_size_small_5__9_in > 0.03 & has_wing_color_yellow <= 0.97 & has_wing_color_white <= 0.94 & has_primary_color_white <= 0.84 & has_under_tail_color_grey <= 1.00 & has_upper_tail_color_grey <= 1.00 & has_tail_pattern_multicolored <= 1.00 & has_head_pattern_plain <= 0.98 & has_throat_color_yellow <= 0.97 & has_leg_color_black <= 1.00 & has_under_tail_color_black <= 0.99 & has_nape_color_grey <= 1.00 & has_underparts_color_brown <= 0.95 & has_shape_perchinglike > 0.00 & has_belly_pattern_solid > 0.00 & has_nape_color_brown <= 1.00 & has_nape_color_brown <= 1.00 & has_size_very_small_3__5_in > 0.00 & has_nape_color_white <= 0.42 & has_underparts_color_yellow > 0.96 & has_breast_pattern_solid > 0.76 & has_upperparts_color_buff > 0.00 & has_under_tail_color_yellow > 0.70) | (has_upper_tail_color_white <= 0.58 & has_back_pattern_striped <= 0.36 & has_back_color_buff <= 0.73 & has_size_medium_9__16_in <= 0.29 & has_bill_shape_hooked_seabird <= 0.40 & has_forehead_color_yellow <= 0.61 & has_underparts_color_grey <= 0.74 & has_under_tail_color_buff <= 0.82 & has_crown_color_white <= 0.53 & has_forehead_color_red <= 0.83 & has_size_very_small_3__5_in <= 0.80 & has_primary_color_buff <= 0.97 & has_nape_color_blue <= 0.42 & has_back_pattern_multicolored <= 0.93 & has_nape_color_yellow <= 0.94 & has_belly_color_black <= 0.81 & has_nape_color_white <= 0.92 & has_bill_shape_dagger <= 0.91 & has_breast_pattern_striped <= 0.97 & has_throat_color_black <= 0.97 & has_forehead_color_black <= 1.00 & has_throat_color_grey <= 0.28 & has_eye_color_black > 0.15 & has_breast_color_brown <= 0.91 & has_belly_color_yellow <= 1.00 & has_nape_color_buff <= 0.95 & has_primary_color_black <= 1.00 & has_upperparts_color_black <= 0.99 & has_breast_color_black <= 0.93 & has_size_small_5__9_in > 0.03 & has_wing_color_yellow <= 0.97 & has_wing_color_white <= 0.94 & has_primary_color_white <= 0.84 & has_under_tail_color_grey <= 1.00 & has_upper_tail_color_grey <= 1.00 & has_tail_pattern_multicolored <= 1.00 & has_head_pattern_plain <= 0.98 & has_throat_color_yellow > 0.97 & has_wing_color_grey > 0.27 & has_underparts_color_buff > 0.00 & has_back_color_yellow > 0.00 & has_upperparts_color_brown <= 0.00) | (has_upper_tail_color_white <= 0.58 & has_back_pattern_striped <= 0.36 & has_back_color_buff <= 0.73 & has_size_medium_9__16_in <= 0.29 & has_bill_shape_hooked_seabird <= 0.40 & has_forehead_color_yellow <= 0.61 & has_underparts_color_grey <= 0.74 & has_under_tail_color_buff <= 0.82 & has_crown_color_white <= 0.53 & has_forehead_color_red <= 0.83 & has_size_very_small_3__5_in <= 0.80 & has_primary_color_buff <= 0.97 & has_nape_color_blue <= 0.42 & has_back_pattern_multicolored <= 0.93 & has_nape_color_yellow <= 0.94 & has_belly_color_black <= 0.81 & has_nape_color_white <= 0.92 & has_bill_shape_dagger <= 0.91 & has_breast_pattern_striped <= 0.97 & has_throat_color_black <= 0.97 & has_forehead_color_black > 1.00 & has_underparts_color_yellow > 0.50) | (has_upper_tail_colo ...
# Elapsed time 0.013999462127685547
#   method  split                                        explanation  \
# 0   Tree      0  (has_back_pattern_striped <= 0.36 & has_under_...
# 1   Tree      1  (has_upper_tail_color_white <= 0.58 & has_back...
#
#                                      explanation_inv  model_accuracy  \
# 0  (has_back_pattern_striped <= 0.36 & has_under_...       90.363483
# 1  (has_upper_tail_color_white <= 0.58 & has_back...       89.010989
#
#    explanation_accuracy  explanation_accuracy_inv  elapsed_time  \
# 0             90.363483                 90.363483      0.014680
# 1             89.010989                 89.010989      0.015995
#
#    elapsed_time_inv
# 0          0.014680
# 1          0.015995

# %% [markdown]
# ## Relu NN

# %%
for seed in seeds:
    print("Seed", seed)
    set_seed(seed)

    train_data, val_data, test_data = get_splits_train_val_test(dataset)
    print(train_data.indices)

    x_val = torch.tensor(dataset.attributes[val_data.indices])
    y_val = torch.tensor(dataset.targets[val_data.indices])
    x_test = torch.tensor(dataset.attributes[test_data.indices])
    y_test = torch.tensor(dataset.targets[test_data.indices])

    # Network structures
    l1_weight = 1e-5
    hidden_neurons = [200, 100]

    # Setting device
    device = torch.device("cpu") if torch.cuda.is_available() else torch.device("cpu")
    set_seed(seed)
    print(f"Training Relu NN...")
    model = XReluNN(n_classes=dataset.n_classes, n_features=n_features,
                    hidden_neurons=hidden_neurons, loss=loss, l1_weight=l1_weight)

    results = model.fit(train_data, val_data, epochs=epochs, l_r=l_r, verbose=False,
                        metric=metric, lr_scheduler=lr_scheduler, device=device, save=False)
    print(results)
    accuracy = model.evaluate(test_data)
    print("Test Model accuracy", accuracy)

    formulas, times, exp_accuracies = [], [], []
    for i, class_to_explain in enumerate(dataset.classes):
        formula, elapsed_time = model.get_global_explanation(x_val, y_val, i,
                                                             topk_explanations=top_k_explanations,
                                                             concept_names=concept_names,
                                                             simplify=True, return_time=True)
        exp_accuracy, _ = test_multi_class_explanation(formula, i, x_test, y_test,
                                                       metric=metric, concept_names=concept_names)
        formulas.append(formula), times.append(elapsed_time), exp_accuracies.append(exp_accuracy)
        print(f"{class_to_explain} <-> {formula}")
        print("Elapsed time", elapsed_time)
        print("Explanation accuracy", exp_accuracy)

    methods.append("Relu")
    splits.append(seed)
    explanations.append(formulas[0])
    explanations_inv.append(formulas[1])
    model_accuracies.append(accuracy)
    explanation_accuracies.append(np.mean(exp_accuracies))
    explanation_accuracies_inv.append(np.mean(exp_accuracies))
    elapsed_times.append(np.mean(times))
    elapsed_times_inv.append(np.mean(times))

results = pd.DataFrame({
    'method': methods,
    'split': splits,
    'explanation': explanations,
    'explanation_inv': explanations_inv,
    'model_accuracy': model_accuracies,
    'explanation_accuracy': explanation_accuracies,
    'explanation_accuracy_inv': explanation_accuracies_inv,
    'elapsed_time': elapsed_times,
    'elapsed_time_inv': elapsed_times_inv,
})
results_relu = results[results['method'] == "Relu"]
results_relu.to_csv(os.path.join(results_dir, 'results_relu.csv'))
print(results_relu)
# Out:
# Seed 0
# [    0     1     2 ... 11785 11786 11787]
# Training Relu NN...
#    Tot losses  Train accs   Val accs  Best epoch
# 0    3.466979   39.664971  72.602676           8
# 1    0.887420   85.590596  87.292381           8
# 2    0.626867   90.201525  90.131136           8
# 3    0.551985   91.076507  90.893457           8
# 4    0.506798   91.820147  91.449500           8
# 5    0.483539   92.069832  92.034729           8
# 6    0.455509   92.283459  91.745688           8
# 7    0.438705   92.552739  91.887163           8
# 8    0.423318   92.773091  91.017280           8
# 9    0.414343   92.824004  91.795396           8
# Test Model accuracy 92.13863060016905
# 001.Black_footed_Albatross <-> has_bill_shape_hooked_seabird & has_breast_pattern_solid & has_eye_color_black & has_bill_length_about_the_same_as_head & has_size_medium_9__16_in & has_back_pattern_solid & has_belly_pattern_solid & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_underparts_color_white & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_wing_shape_roundedwings & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_multicolored & ~has_tail_pattern_solid & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.34999871253967285
# Explanation accuracy 100.0
# 002.Laysan_Albatross <-> has_underparts_color_white & has_breast_pattern_solid & has_eye_color_black & has_bill_length_about_the_same_as_head & has_forehead_color_white & has_under_tail_color_black & has_belly_color_white & has_back_pattern_solid & has_tail_pattern_solid & has_belly_pattern_solid & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_wing_color_white & ~has_upperparts_color_black & ~has_underparts_color_black & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_forehead_color_black & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_small_5__9_in & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.41700172424316406
# Explanation accuracy 49.8728813559322
# 003.Sooty_Albatross <-> has_bill_shape_hooked_seabird & has_breast_pattern_solid & has_upper_tail_color_grey & has_eye_color_black & has_bill_length_about_the_same_as_head & has_size_medium_9__16_in & has_tail_pattern_solid & has_belly_pattern_solid & has_bill_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_black & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_forehead_color_white & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_wing_shape_roundedwings & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_crown_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.34999990463256836
# Explanation accuracy 89.95755517826825
# 004.Groove_billed_Ani <-> has_upperparts_color_black & has_breast_pattern_solid & has_head_pattern_plain & has_eye_color_black & has_bill_length_shorter_than_head & has_under_tail_color_black & has_size_small_5__9_in & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_leg_color_grey & ~has_wing_pattern_multicolored
# Elapsed time 0.270000696182251
# Explanation accuracy 89.95755517826825
# 005.Crested_Auklet <-> has_upperparts_color_black & has_breast_pattern_solid & has_bill_length_shorter_than_head & has_forehead_color_black & has_under_tail_color_black & has_nape_color_black & has_size_medium_9__16_in & has_belly_pattern_solid & has_leg_color_grey & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_underparts_color_white & ~has_underparts_color_buff & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_eye_color_black & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_small_5__9_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.3809990882873535
# Explanation accuracy 92.83594743535396
# 006.Least_Auklet <-> has_bill_shape_cone & has_upperparts_color_black & has_underparts_color_white & has_breast_pattern_striped & has_bill_length_shorter_than_head & has_forehead_color_black & has_under_tail_color_black & has_belly_color_white & has_leg_color_grey & has_bill_color_black & has_crown_color_black & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_underparts_color_brown & ~has_breast_pattern_solid & ~has_breast_pattern_multicolored & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_eye_color_black & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_small_5__9_in & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_multicolored & ~has_leg_color_black & ~has_leg_color_buff & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.3370041847229004
# Explanation accuracy 92.83594743535396
# 007.Parakeet_Auklet <-> has_wing_color_black & has_upperparts_color_black & has_underparts_color_white & has_bill_length_shorter_than_head & has_forehead_color_black & has_under_tail_color_black & has_nape_color_black & has_belly_color_white & has_size_medium_9__16_in & has_tail_pattern_solid & has_belly_pattern_solid & has_leg_color_grey & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_wing_color_yellow & ~has_wing_color_white & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_breast_pattern_solid & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_breast_color_brown & ~has_eye_color_black & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_red & ~has_nape_color_buff & ~has_wing_shape_roundedwings & ~has_size_small_5__9_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_multicolored & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.48099660873413086
# Explanation accuracy 100.0
# 008.Rhinoceros_Auklet <-> has_upperparts_color_black & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_under_tail_color_black & has_size_medium_9__16_in & has_belly_pattern_solid & has_leg_color_buff & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_underparts_color_white & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_red & ~has_belly_color_white & ~has_wing_shape_roundedwings & ~has_size_small_5__9_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_black & ~has_bill_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.3579981327056885
# Explanation accuracy 94.42323103757131
# 009.Brewer_Blackbird <-> has_bill_shape_allpurpose & has_breast_pattern_solid & has_head_pattern_plain & has_eye_color_black & has_bill_length_shorter_than_head & has_under_tail_color_black & has_wing_shape_roundedwings & has_size_small_5__9_in & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_leg_color_grey & ~has_leg_color_buff & ~has_wing_pattern_multicolored
# Elapsed time 0.30499744415283203
# Explanation accuracy 91.62418578306428
# 010.Red_winged_Blackbird <-> has_upperparts_color_black & has_breast_pattern_solid & has_head_pattern_plain & has_eye_color_black & has_bill_length_shorter_than_head & has_under_tail_color_black & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_crown_color_black & has_wing_pattern_multicolored & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_leg_color_grey & ~has_leg_color_buff & ~has_wing_pattern_solid
# Elapsed time 0.3139984607696533
# Explanation accuracy 91.62418578306428
# 011.Rusty_Blackbird <-> has_bill_shape_allpurpose & has_upperparts_color_black & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_under_tail_color_black & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_crown_color_black & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_breast_pattern_striped & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_buff & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.4259979724884033
# Explanation accuracy 100.0
# 012.Yellow_headed_Blackbird <-> has_upperparts_color_black & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_under_tail_color_black & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_breast_pattern_striped & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_leg_color_grey & ~has_wing_pattern_multicolored
# Elapsed time 0.3319993019104004
# Explanation accuracy 95.43331403204014
# 013.Bobolink <-> has_bill_shape_cone & has_upperparts_color_black & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_under_tail_color_black & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_bill_color_black & has_crown_color_black & has_wing_pattern_multicolored & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_leg_color_grey & ~has_leg_color_black & ~has_wing_pattern_solid
# Elapsed time 0.2330002784729004
# Explanation accuracy 100.0
# 014.Indigo_Bunting <-> has_bill_shape_cone & has_breast_pattern_solid & has_head_pattern_plain & has_eye_color_black & has_bill_length_shorter_than_head & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_wing_pattern_multicolored & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_belly_color_buff & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_tail_pattern_solid & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_wing_pattern_solid
# Elapsed time 0.4259970188140869
# Explanation accuracy 95.43331403204014
# 015.Lazuli_Bunting <-> has_bill_shape_cone & has_upperparts_color_black & has_underparts_color_white & has_eye_color_black & has_bill_length_shorter_than_head & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_leg_color_black & has_wing_pattern_multicolored & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_underparts_color_brown & ~has_breast_pattern_solid & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid
# Elapsed time 0.25099802017211914
# Explanation accuracy 95.43331403204014
# 016.Painted_Bunting <-> has_bill_shape_cone & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_leg_color_grey & has_wing_pattern_multicolored & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_underparts_color_buff & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_belly_color_buff & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_tail_pattern_solid & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid
# Elapsed time 0.32100963592529297
# Explanation accuracy 95.43331403204014
# 017.Cardinal <-> has_bill_shape_cone & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_forehead_color_red & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_wing_pattern_multicolored & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_forehead_color_white & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_black & ~has_bill_color_black & ~has_wing_pattern_solid
# Elapsed time 0.2480006217956543
# Explanation accuracy 100.0
# 018.Spotted_Catbird <-> has_bill_shape_cone & has_eye_color_black & has_bill_length_shorter_than_head & has_size_small_5__9_in & has_shape_perchinglike & has_leg_color_grey & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_underparts_color_brown & ~has_underparts_color_white & ~has_breast_pattern_solid & ~has_breast_pattern_striped & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_black & ~has_forehead_color_white & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_belly_pattern_solid & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.3190016746520996
# Explanation accuracy 100.0
# 019.Gray_Catbird <-> has_bill_shape_allpurpose & has_breast_pattern_solid & has_upper_tail_color_grey & has_head_pattern_capped & has_eye_color_black & has_bill_length_shorter_than_head & has_size_small_5__9_in & has_shape_perchinglike & has_tail_pattern_solid & has_belly_pattern_solid & has_bill_color_black & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_white & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_wing_pattern_multicolored
# Elapsed time 0.36501145362854004
# Explanation accuracy 49.8728813559322
# 020.Yellow_breasted_Chat <-> has_bill_shape_allpurpose & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_leg_color_grey & has_bill_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_belly_pattern_solid & ~has_leg_color_black & ~has_leg_color_buff & ~has_crown_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.28600096702575684
# Explanation accuracy 100.0
# 021.Eastern_Towhee <-> has_bill_shape_cone & has_upperparts_color_black & has_underparts_color_white & has_head_pattern_plain & has_eye_color_black & has_bill_length_shorter_than_head & has_under_tail_color_black & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_bill_color_black & has_crown_color_black & has_wing_pattern_multicolored & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_breast_pattern_solid & ~has_tail_shape_notched_tail & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_black & ~has_wing_pattern_solid
# Elapsed time 0.2480013370513916
# Explanation accuracy 100.0
# 022.Chuck_will_Widow <-> has_underparts_color_brown & has_breast_color_brown & has_eye_color_black & has_bill_length_shorter_than_head & has_belly_color_buff & has_wing_shape_roundedwings & has_size_small_5__9_in & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_breast_pattern_solid & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_bill_length_about_the_same_as_head & ~has_under_tail_color_black & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_leg_color_grey & ~has_leg_color_black & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.3860008716583252
# Explanation accuracy 96.13259668508287
# 023.Brandt_Cormorant <-> has_bill_shape_hooked_seabird & has_upperparts_color_black & has_breast_pattern_solid & has_head_pattern_plain & has_eye_color_black & has_bill_length_about_the_same_as_head & has_under_tail_color_black & has_size_medium_9__16_in & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_head_pattern_capped & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_small_5__9_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_wing_pattern_multicolored
# Elapsed time 0.2800271511077881
# Explanation accuracy 88.39779005524862
# 024.Red_faced_Cormorant <-> has_bill_shape_hooked_seabird & has_upperparts_color_black & has_breast_pattern_solid & has_eye_color_black & has_bill_length_about_the_same_as_head & has_forehead_color_black & has_under_tail_color_black & has_wing_shape_roundedwings & has_size_medium_9__16_in & has_back_pattern_solid & has_belly_pattern_solid & has_leg_color_black & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_breast_pattern_striped & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_breast_color_brown & ~has_forehead_color_red & ~has_size_small_5__9_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_buff & ~has_bill_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.357999324798584
# Explanation accuracy 94.42323103757131
# 025.Pelagic_Cormorant <-> has_upperparts_color_black & has_breast_pattern_solid & has_head_pattern_plain & has_eye_color_black & has_bill_length_about_the_same_as_head & has_under_tail_color_black & has_size_medium_9__16_in & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_head_pattern_capped & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_small_5__9_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_leg_color_grey & ~has_leg_color_buff & ~has_wing_pattern_multicolored
# Elapsed time 0.24599456787109375
# Explanation accuracy 100.0
# 026.Bronzed_Cowbird <-> has_upperparts_color_black & has_breast_pattern_solid & has_head_pattern_plain & has_eye_color_black & has_bill_length_shorter_than_head & has_under_tail_color_black & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_leg_color_grey & ~has_leg_color_buff & ~has_wing_pattern_multicolored
# Elapsed time 0.22099089622497559
# Explanation accuracy 95.43331403204014
# 027.Shiny_Cowbird <-> has_bill_shape_allpurpose & has_upperparts_color_black & has_underparts_color_black & has_breast_pattern_solid & has_head_pattern_plain & has_eye_color_black & has_bill_length_shorter_than_head & has_under_tail_color_black & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_leg_color_grey & ~has_leg_color_buff & ~has_wing_pattern_multicolored
# Elapsed time 0.4060032367706299
# Explanation accuracy 95.43331403204014
# 028.Brown_Creeper <-> has_underparts_color_white & has_breast_pattern_solid & has_back_color_buff & has_throat_color_white & has_eye_color_black & has_bill_length_about_the_same_as_head & has_belly_color_white & has_wing_shape_roundedwings & has_tail_pattern_solid & has_belly_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_wing_color_yellow & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_breast_pattern_striped & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_forehead_color_red & ~has_under_tail_color_yellow & ~has_under_tail_color_black & ~has_belly_color_buff & ~has_size_small_5__9_in & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_solid & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.33700132369995117
# Explanation accuracy 100.0
# 029.American_Crow <-> has_breast_pattern_solid & has_head_pattern_plain & has_eye_color_black & has_bill_length_about_the_same_as_head & has_under_tail_color_black & has_wing_shape_roundedwings & has_size_medium_9__16_in & has_shape_perchinglike & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_head_pattern_capped & ~has_forehead_color_red & ~has_size_small_5__9_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_buff & ~has_wing_pattern_multicolored
# Elapsed time 0.33300232887268066
# Explanation accuracy 95.43331403204014
# 030.Fish_Crow <-> has_bill_shape_allpurpose & has_breast_pattern_solid & has_head_pattern_plain & has_eye_color_black & has_bill_length_about_the_same_as_head & has_under_tail_color_black & has_wing_shape_roundedwings & has_size_small_5__9_in & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_breast_pattern_striped & ~has_tail_shape_notched_tail & ~has_head_pattern_capped & ~has_bill_length_shorter_than_head & ~has_forehead_color_red & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_leg_color_grey & ~has_leg_color_buff & ~has_wing_pattern_multicolored
# Elapsed time 0.2769894599914551
# Explanation accuracy 86.29994209612045
# 031.Black_billed_Cuckoo <-> has_bill_shape_allpurpose & has_underparts_color_white & has_breast_pattern_solid & has_eye_color_black & has_bill_length_about_the_same_as_head & has_belly_color_white & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_leg_color_grey & has_bill_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_upperparts_color_black & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_shorter_than_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_belly_color_buff & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_leg_color_black & ~has_leg_color_buff & ~has_crown_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.3769969940185547
# Explanation accuracy 95.43331403204014
# 032.Mangrove_Cuckoo <-> has_bill_shape_allpurpose & has_underparts_color_buff & has_breast_pattern_solid & has_eye_color_black & has_bill_length_about_the_same_as_head & has_under_tail_color_black & has_belly_color_buff & has_size_small_5__9_in & has_shape_perchinglike & has_back_pattern_solid & has_belly_pattern_solid & has_leg_color_grey & has_bill_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_wing_color_yellow & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_shorter_than_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_nape_color_buff & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_tail_pattern_solid & ~has_leg_color_black & ~has_leg_color_buff & ~has_crown_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.3079962730407715
# Explanation accuracy 100.0
# 033.Yellow_billed_Cuckoo <-> has_underparts_color_white & has_breast_pattern_solid & has_eye_color_black & has_bill_length_about_the_same_as_head & has_belly_color_white & has_size_small_5__9_in & has_shape_perchinglike & has_tail_pattern_solid & has_belly_pattern_solid & has_leg_color_grey & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_upperparts_color_black & ~has_underparts_color_brown & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_shorter_than_head & ~has_forehead_color_black & ~has_forehead_color_white & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.41100025177001953
# Explanation accuracy 89.95755517826825
# 034.Gray_crowned_Rosy_Finch <-> has_bill_shape_cone & has_underparts_color_brown & has_breast_color_brown & has_eye_color_black & has_bill_length_shorter_than_head & has_under_tail_color_black & has_size_small_5__9_in & has_shape_perchinglike & has_leg_color_black & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_breast_pattern_solid & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_belly_pattern_solid & ~has_leg_color_grey & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.22400617599487305
# Explanation accuracy 100.0
# 035.Purple_Finch <-> has_bill_shape_cone & has_underparts_color_white & has_tail_shape_notched_tail & has_eye_color_black & has_bill_length_shorter_than_head & has_forehead_color_red & has_size_small_5__9_in & has_shape_perchinglike & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_upperparts_color_black & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_breast_pattern_solid & ~has_breast_pattern_striped & ~has_breast_pattern_multicolored & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_under_tail_color_black & ~has_belly_color_buff & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_belly_pattern_solid & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_striped & ~has_wing_pattern_multicolored
# Elapsed time 0.34099483489990234
# Explanation accuracy 95.43331403204014
# 036.Northern_Flicker <-> has_back_color_buff & has_eye_color_black & has_bill_length_about_the_same_as_head & has_size_small_5__9_in & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_upperparts_color_black & ~has_upperparts_color_buff & ~has_underparts_color_brown & ~has_underparts_color_white & ~has_breast_pattern_solid & ~has_upper_tail_color_grey & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_shorter_than_head & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_belly_color_buff & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_belly_pattern_solid & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.5409984588623047
# Explanation accuracy 49.8728813559322
# 037.Acadian_Flycatcher <-> has_bill_shape_allpurpose & has_underparts_color_white & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_size_small_5__9_in & has_shape_perchinglike & has_tail_pattern_solid & has_belly_pattern_solid & has_leg_color_black & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_breast_pattern_striped & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_under_tail_color_yellow & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.44495105743408203
# Explanation accuracy 95.43331403204014
# 038.Great_Crested_Flycatcher <-> has_bill_shape_allpurpose & has_breast_pattern_solid & has_tail_shape_notched_tail & has_eye_color_black & has_bill_length_about_the_same_as_head & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_upper_tail_color_grey & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_shorter_than_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_buff & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.32099437713623047
# Explanation accuracy 95.43331403204014
# 039.Least_Flycatcher <-> has_bill_shape_allpurpose & has_underparts_color_white & has_breast_pattern_solid & has_tail_shape_notched_tail & has_eye_color_black & has_bill_length_shorter_than_head & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_belly_color_buff & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.2500030994415283
# Explanation accuracy 91.62418578306428
# 040.Olive_sided_Flycatcher <-> has_bill_shape_allpurpose & has_underparts_color_white & has_tail_shape_notched_tail & has_eye_color_black & has_bill_length_shorter_than_head & has_size_small_5__9_in & has_shape_perchinglike & has_leg_color_black & has_bill_color_black & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_breast_pattern_solid & ~has_head_pattern_plain & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_leg_color_grey & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.1900005340576172
# Explanation accuracy 88.39779005524862
# 041.Scissor_tailed_Flycatcher <-> has_bill_shape_allpurpose & has_underparts_color_white & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_forehead_color_white & has_under_tail_color_black & has_size_small_5__9_in & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_breast_pattern_striped & ~has_tail_shape_notched_tail & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_leg_color_grey & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.18200254440307617
# Explanation accuracy 83.26969311271391
# 042.Vermilion_Flycatcher <-> has_bill_shape_allpurpose & has_breast_pattern_solid & has_tail_shape_notched_tail & has_eye_color_black & has_bill_length_shorter_than_head & has_forehead_color_red & has_under_tail_color_black & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_breast_pattern_striped & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_buff & ~has_wing_pattern_multicolored
# Elapsed time 0.25299859046936035
# Explanation accuracy 100.0
# 043.Yellow_bellied_Flycatcher <-> has_bill_shape_allpurpose & has_breast_pattern_solid & has_tail_shape_notched_tail & has_eye_color_black & has_bill_length_shorter_than_head & has_size_small_5__9_in & has_shape_perchinglike & has_back_pattern_solid & has_tail_pattern_solid & has_belly_pattern_solid & has_leg_color_black & has_wing_pattern_multicolored & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_breast_pattern_striped & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_belly_color_buff & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_leg_color_buff & ~has_bill_color_black & ~has_wing_pattern_solid
# Elapsed time 0.2760009765625
# Explanation accuracy 96.13259668508287
# 044.Frigatebird <-> has_bill_shape_hooked_seabird & has_wing_color_black & has_upperparts_color_black & has_underparts_color_black & has_underparts_color_white & has_breast_pattern_solid & has_head_pattern_plain & has_eye_color_black & has_forehead_color_black & has_under_tail_color_black & has_back_pattern_solid & has_tail_pattern_solid & has_belly_pattern_solid & has_leg_color_black & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_wing_color_white & ~has_underparts_color_brown & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_bill_length_shorter_than_head & ~has_forehead_color_red & ~has_belly_color_white & ~has_wing_shape_roundedwings & ~has_size_small_5__9_in & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_bill_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.27100062370300293
# Explanation accuracy 95.43331403204014
# 045.Northern_Fulmar <-> has_bill_shape_hooked_seabird & has_breast_pattern_solid & has_upper_tail_color_grey & has_head_pattern_plain & has_eye_color_black & has_bill_length_about_the_same_as_head & has_forehead_color_white & has_size_medium_9__16_in & has_belly_pattern_solid & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_tail_shape_notched_tail & ~has_wing_shape_roundedwings & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_leg_color_grey & ~has_leg_color_black & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.20299983024597168
# Explanation accuracy 87.41489361702128
# 046.Gadwall <-> has_underparts_color_brown & has_breast_color_brown & has_eye_color_black & has_bill_length_about_the_same_as_head & has_under_tail_color_black & has_size_medium_9__16_in & has_bill_color_black & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_breast_pattern_solid & ~has_head_pattern_plain & ~has_wing_shape_roundedwings & ~has_size_small_5__9_in & ~has_size_very_small_3__5_in & ~has_leg_color_grey & ~has_leg_color_black & ~has_crown_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.1629955768585205
# Explanation accuracy 95.43331403204014
# 047.American_Goldfinch <-> has_bill_shape_cone & has_upperparts_color_black & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_forehead_color_black & has_under_tail_color_black & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & has_crown_color_black & has_wing_pattern_multicolored & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_underparts_color_brown & ~has_underparts_color_white & ~has_breast_pattern_striped & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_forehead_color_red & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_wing_pattern_solid
# Elapsed time 0.23300552368164062
# Explanation accuracy 89.95755517826825
# 048.European_Goldfinch <-> has_bill_shape_cone & has_wing_color_yellow & has_upperparts_color_black & has_underparts_color_white & has_underparts_color_buff & has_tail_shape_notched_tail & has_eye_color_black & has_bill_length_shorter_than_head & has_forehead_color_red & has_under_tail_color_black & has_belly_color_white & has_belly_color_buff & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_leg_color_buff & has_crown_color_black & has_wing_pattern_multicolored & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_breast_pattern_solid & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_breast_color_brown & ~has_throat_color_black & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_white & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_multicolored & ~has_belly_pattern_solid & ~has_leg_color_grey & ~has_leg_color_black & ~has_bill_color_black & ~has_wing_pattern_solid
# Elapsed time 0.3130006790161133
# Explanation accuracy 100.0
# 049.Boat_tailed_Grackle <-> has_bill_shape_allpurpose & has_breast_pattern_solid & has_head_pattern_plain & has_eye_color_black & has_bill_length_about_the_same_as_head & has_under_tail_color_black & has_wing_shape_roundedwings & has_belly_pattern_solid & has_leg_color_black & has_bill_color_black & has_crown_color_black & has_wing_pattern_solid & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_tail_shape_notched_tail & ~has_head_pattern_capped & ~has_forehead_color_white & ~has_forehead_color_red & ~has_size_small_5__9_in & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_multicolored & ~has_leg_color_grey & ~has_wing_pattern_multicolored
# Elapsed time 0.3590085506439209
# Explanation accuracy 100.0
# 050.Eared_Grebe <-> has_upperparts_color_black & has_breast_pattern_solid & has_bill_length_about_the_same_as_head & has_forehead_color_black & has_size_medium_9__16_in & has_belly_pattern_solid & has_bill_color_black & has_crown_color_black & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_wing_color_yellow & ~has_underparts_color_brown & ~has_underparts_color_black & ~has_underparts_color_white & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_eye_color_black & ~has_forehead_color_red & ~has_under_tail_color_black & ~has_wing_shape_roundedwings & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.4479994773864746
# Explanation accuracy 49.8728813559322
# 051.Horned_Grebe <-> has_size_medium_9__16_in & has_bill_color_black & has_crown_color_black & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_eye_color_black & ~has_wing_shape_roundedwings & ~has_size_small_5__9_in & ~has_size_very_small_3__5_in & ~has_leg_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.16599631309509277
# Explanation accuracy 79.26276513159543
# ...
# Elapsed time 0.4790019989013672
# Explanation accuracy 100.0
# 187.American_Three_toed_Woodpecker <-> has_bill_shape_dagger & has_wing_color_white & has_upperparts_color_black & has_underparts_color_white & has_upper_tail_color_black & has_breast_color_white & has_throat_color_white & has_eye_color_black & has_bill_length_about_the_same_as_head & has_forehead_color_black & has_under_tail_color_black & has_wing_shape_roundedwings & has_size_small_5__9_in & has_leg_color_grey & has_bill_color_black & has_crown_color_black & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_breast_pattern_solid & ~has_breast_pattern_striped & ~has_breast_pattern_multicolored & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_bill_length_shorter_than_head & ~has_under_tail_color_yellow & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_solid & ~has_belly_pattern_solid & ~has_leg_color_black & ~has_leg_color_buff & ~has_wing_pattern_solid & ~has_wing_pattern_striped & ~has_wing_pattern_multicolored
# Elapsed time 0.3989994525909424
# Explanation accuracy 94.42323103757131
# 188.Pileated_Woodpecker <-> has_bill_shape_dagger & has_upperparts_color_black & has_breast_pattern_solid & has_tail_shape_notched_tail & has_upper_tail_color_black & has_throat_color_white & has_eye_color_black & has_bill_length_about_the_same_as_head & has_forehead_color_red & has_under_tail_color_black & has_size_medium_9__16_in & has_back_pattern_solid & has_tail_pattern_solid & has_belly_pattern_solid & has_leg_color_grey & has_leg_color_black & has_bill_color_black & has_wing_pattern_solid & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_wing_color_white & ~has_underparts_color_white & ~has_breast_pattern_striped & ~has_back_color_buff & ~has_upper_tail_color_grey & ~has_breast_color_white & ~has_under_tail_color_yellow & ~has_belly_color_grey & ~has_wing_shape_roundedwings & ~has_size_small_5__9_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_leg_color_buff & ~has_crown_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.24200057983398438
# Explanation accuracy 89.95755517826825
# 189.Red_bellied_Woodpecker <-> has_bill_shape_dagger & has_wing_color_black & has_wing_color_white & has_upperparts_color_black & has_underparts_color_white & has_breast_pattern_solid & has_upper_tail_color_black & has_head_pattern_capped & has_breast_color_white & has_throat_color_white & has_eye_color_black & has_bill_length_about_the_same_as_head & has_forehead_color_red & has_under_tail_color_black & has_size_small_5__9_in & has_belly_pattern_solid & has_leg_color_grey & has_bill_color_black & has_wing_pattern_striped & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_breast_pattern_striped & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_bill_length_shorter_than_head & ~has_forehead_color_white & ~has_under_tail_color_yellow & ~has_belly_color_grey & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_solid & ~has_tail_pattern_solid & ~has_leg_color_black & ~has_leg_color_buff & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.37000346183776855
# Explanation accuracy 96.13259668508287
# 190.Red_cockaded_Woodpecker <-> has_bill_shape_dagger & has_wing_color_white & has_upperparts_color_black & has_upper_tail_color_black & has_head_pattern_capped & has_breast_color_white & has_throat_color_white & has_eye_color_black & has_bill_length_about_the_same_as_head & has_forehead_color_black & has_under_tail_color_black & has_size_small_5__9_in & has_leg_color_grey & has_bill_color_black & has_crown_color_black & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_breast_pattern_solid & ~has_breast_pattern_striped & ~has_breast_pattern_multicolored & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_head_pattern_plain & ~has_breast_color_black & ~has_bill_length_shorter_than_head & ~has_under_tail_color_yellow & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_solid & ~has_belly_pattern_solid & ~has_leg_color_black & ~has_leg_color_buff & ~has_wing_pattern_solid & ~has_wing_pattern_striped & ~has_wing_pattern_multicolored
# Elapsed time 0.3569908142089844
# Explanation accuracy 100.0
# 191.Red_headed_Woodpecker <-> has_bill_shape_dagger & has_wing_color_black & has_wing_color_white & has_upperparts_color_black & has_underparts_color_white & has_breast_pattern_solid & has_upper_tail_color_black & has_head_pattern_plain & has_breast_color_white & has_eye_color_black & has_bill_length_about_the_same_as_head & has_forehead_color_red & has_under_tail_color_black & has_size_small_5__9_in & has_back_pattern_solid & has_tail_pattern_solid & has_belly_pattern_solid & has_leg_color_grey & has_bill_color_grey & has_wing_pattern_multicolored & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_breast_pattern_striped & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_head_pattern_capped & ~has_breast_color_black & ~has_throat_color_white & ~has_bill_length_shorter_than_head & ~has_under_tail_color_yellow & ~has_nape_color_blue & ~has_belly_color_grey & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_striped
# Elapsed time 0.39699697494506836
# Explanation accuracy 95.43331403204014
# 192.Downy_Woodpecker <-> has_bill_shape_allpurpose & has_wing_color_black & has_wing_color_white & has_upperparts_color_black & has_underparts_color_white & has_breast_pattern_solid & has_upper_tail_color_black & has_breast_color_white & has_throat_color_white & has_eye_color_black & has_bill_length_shorter_than_head & has_forehead_color_black & has_under_tail_color_black & has_belly_color_white & has_size_small_5__9_in & has_belly_pattern_solid & has_leg_color_grey & has_bill_color_black & has_crown_color_black & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_breast_pattern_striped & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_head_pattern_plain & ~has_head_pattern_capped & ~has_breast_color_black & ~has_bill_length_about_the_same_as_head & ~has_under_tail_color_yellow & ~has_belly_color_buff & ~has_wing_shape_roundedwings & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_shape_perchinglike & ~has_back_pattern_solid & ~has_tail_pattern_solid & ~has_leg_color_black & ~has_leg_color_buff & ~has_wing_pattern_solid & ~has_wing_pattern_striped & ~has_wing_pattern_multicolored
# Elapsed time 0.44699716567993164
# Explanation accuracy 95.43331403204014
# 193.Bewick_Wren <-> has_bill_shape_allpurpose & has_breast_pattern_solid & has_throat_color_white & has_eye_color_black & has_bill_length_about_the_same_as_head & has_under_tail_color_black & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_back_pattern_solid & has_belly_pattern_solid & has_wing_pattern_solid & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_wing_color_white & ~has_underparts_color_brown & ~has_breast_pattern_striped & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_bill_length_shorter_than_head & ~has_under_tail_color_yellow & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_tail_pattern_solid & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.26900649070739746
# Explanation accuracy 100.0
# 194.Cactus_Wren <-> has_wing_color_black & has_wing_color_white & has_back_color_brown & has_upper_tail_color_black & has_throat_color_white & has_eye_color_black & has_bill_length_about_the_same_as_head & has_under_tail_color_black & has_nape_color_brown & has_belly_color_buff & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_underparts_color_brown & ~has_underparts_color_white & ~has_breast_pattern_solid & ~has_breast_pattern_striped & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_head_pattern_plain & ~has_breast_color_brown & ~has_bill_length_shorter_than_head & ~has_forehead_color_red & ~has_under_tail_color_yellow & ~has_nape_color_blue & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_solid & ~has_tail_pattern_solid & ~has_belly_pattern_solid & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_grey & ~has_bill_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.5280044078826904
# Explanation accuracy 100.0
# 195.Carolina_Wren <-> has_bill_shape_allpurpose & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_wing_shape_roundedwings & has_size_small_5__9_in & has_size_very_small_3__5_in & has_shape_perchinglike & has_back_pattern_solid & has_belly_pattern_solid & has_leg_color_buff & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_breast_pattern_striped & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_throat_color_white & ~has_bill_length_about_the_same_as_head & ~has_under_tail_color_yellow & ~has_size_medium_9__16_in & ~has_leg_color_grey & ~has_leg_color_black & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.24999737739562988
# Explanation accuracy 49.8728813559322
# 196.House_Wren <-> has_bill_shape_allpurpose & has_breast_pattern_solid & has_back_color_brown & has_eye_color_black & has_bill_length_about_the_same_as_head & has_belly_color_buff & has_shape_perchinglike & has_belly_pattern_solid & has_leg_color_buff & has_wing_pattern_striped & ~has_bill_shape_dagger & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_underparts_color_white & ~has_breast_pattern_striped & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_upper_tail_color_black & ~has_head_pattern_plain & ~has_breast_color_black & ~has_breast_color_white & ~has_throat_color_white & ~has_bill_length_shorter_than_head & ~has_under_tail_color_yellow & ~has_under_tail_color_black & ~has_belly_color_grey & ~has_belly_color_white & ~has_wing_shape_roundedwings & ~has_size_small_5__9_in & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_solid & ~has_tail_pattern_solid & ~has_leg_color_grey & ~has_leg_color_black & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.4740006923675537
# Explanation accuracy 100.0
# 197.Marsh_Wren <-> has_bill_shape_allpurpose & has_underparts_color_white & has_breast_pattern_solid & has_breast_color_white & has_throat_color_white & has_eye_color_black & has_bill_length_shorter_than_head & has_belly_color_white & has_belly_color_buff & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_belly_pattern_solid & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_wing_color_white & ~has_upperparts_color_black & ~has_breast_pattern_striped & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_head_pattern_plain & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_red & ~has_under_tail_color_yellow & ~has_under_tail_color_black & ~has_nape_color_black & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_solid & ~has_tail_pattern_solid & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_striped & ~has_wing_pattern_multicolored
# Elapsed time 0.2729945182800293
# Explanation accuracy 100.0
# 198.Rock_Wren <-> has_underparts_color_white & has_breast_pattern_solid & has_breast_color_white & has_throat_color_white & has_eye_color_black & has_bill_length_about_the_same_as_head & has_belly_color_buff & has_wing_shape_roundedwings & has_size_very_small_3__5_in & has_shape_perchinglike & has_belly_pattern_solid & ~has_bill_shape_hooked_seabird & ~has_bill_shape_allpurpose & ~has_bill_shape_cone & ~has_breast_pattern_striped & ~has_tail_shape_notched_tail & ~has_bill_length_shorter_than_head & ~has_under_tail_color_yellow & ~has_size_medium_9__16_in & ~has_back_pattern_solid & ~has_leg_color_grey & ~has_leg_color_black & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_solid & ~has_wing_pattern_multicolored
# Elapsed time 0.24699926376342773
# Explanation accuracy 95.43331403204014
# 199.Winter_Wren <-> has_bill_shape_allpurpose & has_underparts_color_brown & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_breast_pattern_striped & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_bill_length_about_the_same_as_head & ~has_under_tail_color_yellow & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_back_pattern_solid & ~has_belly_pattern_solid & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_bill_color_black & ~has_crown_color_black & ~has_wing_pattern_striped & ~has_wing_pattern_multicolored
# Elapsed time 0.2310013771057129
# Explanation accuracy 91.62418578306428
# 200.Common_Yellowthroat <-> has_bill_shape_allpurpose & has_breast_pattern_solid & has_eye_color_black & has_bill_length_shorter_than_head & has_forehead_color_black & has_under_tail_color_yellow & has_wing_shape_roundedwings & has_size_small_5__9_in & has_shape_perchinglike & has_back_pattern_solid & has_belly_pattern_solid & has_bill_color_black & has_wing_pattern_solid & ~has_bill_shape_hooked_seabird & ~has_bill_shape_cone & ~has_wing_color_white & ~has_upperparts_color_black & ~has_breast_pattern_striped & ~has_back_color_buff & ~has_tail_shape_notched_tail & ~has_upper_tail_color_grey & ~has_head_pattern_capped & ~has_bill_length_about_the_same_as_head & ~has_forehead_color_red & ~has_belly_color_grey & ~has_size_medium_9__16_in & ~has_size_very_small_3__5_in & ~has_leg_color_grey & ~has_leg_color_black & ~has_leg_color_buff & ~has_crown_color_black & ~has_wing_pattern_multicolored
# Elapsed time 0.3390004634857178
# Explanation accuracy 100.0
#   method  split                                        explanation  \
# 2   Relu      0  has_bill_shape_hooked_seabird & has_breast_pat...
# 3   Relu      1  has_bill_shape_hooked_seabird & has_breast_pat...
#
#                                      explanation_inv  model_accuracy  \
# 2  has_underparts_color_white & has_breast_patter...       92.138631
# 3  has_bill_shape_hooked_seabird & has_wing_color...       91.885038
#
#    explanation_accuracy  explanation_accuracy_inv  elapsed_time  \
# 2             91.405036                 91.405036      0.288178
# 3             92.745833                 92.745833      0.352671
#
#    elapsed_time_inv
# 2          0.288178
# 3          0.352671

# %% [markdown]
# ## PSI NN

# %%
for seed in seeds:
    print("Seed", seed)
    set_seed(seed)

    train_data, val_data, test_data = get_splits_train_val_test(dataset)
    print(train_data.indices)

    x_test = torch.tensor(dataset.attributes[test_data.indices])
    y_test = torch.tensor(dataset.targets[test_data.indices])

    # Network structures
    l1_weight = 5e-6
    hidden_neurons = [10, 5]
    fan_in = 3
    lr_psi = 0.01

    # Setting device
    device = torch.device("cpu") if torch.cuda.is_available() else torch.device("cpu")
    set_seed(seed)

    print("Training Psi NN...")
    model = PsiNetwork(dataset.n_classes, n_features, hidden_neurons, loss,
                       l1_weight, fan_in=fan_in)

    results = model.fit(train_data, val_data, epochs=epochs, l_r=lr_psi, verbose=False,
                        metric=metric, lr_scheduler=lr_scheduler, device=device, save=False)
    print(results)
    accuracy = model.evaluate(test_data, metric=metric)
    print("Test model accuracy", accuracy)

    formulas, times, exp_accuracies = [], [], []
    for i, class_to_explain in enumerate(dataset.classes):
        formula, elapsed_time = model.get_global_explanation(i, concept_names,
                                                             simplify=True, return_time=True)
        exp_accuracy, _ = test_multi_class_explanation(formula, i, x_test, y_test,
                                                       metric=metric, concept_names=concept_names)
        formulas.append(formula), times.append(elapsed_time), exp_accuracies.append(exp_accuracy)
        print(f"{class_to_explain} <-> {formula}")
        print("Elapsed time", elapsed_time)
        print("Explanation accuracy", exp_accuracy)

    methods.append("Psi")
    splits.append(seed)
    explanations.append(formulas[0])
    explanations_inv.append(formulas[1])
    model_accuracies.append(accuracy)
    explanation_accuracies.append(np.mean(exp_accuracies))
    explanation_accuracies_inv.append(np.mean(exp_accuracies))
    elapsed_times.append(np.mean(times))
    elapsed_times_inv.append(np.mean(times))

results = pd.DataFrame({
    'method': methods,
    'split': splits,
    'explanation': explanations,
    'explanation_inv': explanations_inv,
    'model_accuracy': model_accuracies,
    'explanation_accuracy': explanation_accuracies,
    'explanation_accuracy_inv': explanation_accuracies_inv,
    'elapsed_time': elapsed_times,
    'elapsed_time_inv': elapsed_times_inv,
})
results_psi = results[results['method'] == "Psi"]
results_psi.to_csv(os.path.join(results_dir, 'results_psi.csv'))
print(results_psi)

# %% [markdown]
# ## Mu NN

# %%
for seed in seeds:
    print("Seed", seed)
    set_seed(seed)

    train_data, val_data, test_data = get_splits_train_val_test(dataset)
    print(train_data.indices)

    x_val = torch.tensor(dataset.attributes[val_data.indices])
    y_val = torch.tensor(dataset.targets[val_data.indices])
    x_test = torch.tensor(dataset.attributes[test_data.indices])
    y_test = torch.tensor(dataset.targets[test_data.indices])

    # Network structures
    l1_weight = 1e-3
    hidden_neurons = [10, 5]

    # Setting device
    device = torch.device("cpu") if torch.cuda.is_available() else torch.device("cpu")
    set_seed(seed)

    print("Training General NN...")
    model = XGeneralNN(n_classes=dataset.n_classes, n_features=n_features, hidden_neurons=hidden_neurons,
                       loss=loss, l1_weight=l1_weight)

    results = model.fit(train_data, val_data, epochs=epochs, l_r=l_r, metric=metric,
                        lr_scheduler=lr_scheduler, device=device, save=False, verbose=False)
    print(results)
    accuracy = model.evaluate(test_data, metric=metric)
    print("Test model accuracy", accuracy)

    formulas, times, exp_accuracies = [], [], []
    for i, class_to_explain in enumerate(dataset.classes):
        formula, elapsed_time = model.get_global_explanation(x_val, y_val, i, simplify=True,
                                                             topk_explanations=top_k_explanations,
                                                             concept_names=concept_names, return_time=True)
        exp_accuracy, _ = test_multi_class_explanation(formula, i, x_test, y_test,
                                                       metric=metric, concept_names=concept_names)
        formulas.append(formula), times.append(elapsed_time), exp_accuracies.append(exp_accuracy)
        print(f"{class_to_explain} <-> {formula}")
        print("Elapsed time", elapsed_time)
        print("Explanation accuracy", exp_accuracy)

    methods.append("General")
    splits.append(seed)
    explanations.append(formulas[0])
    explanations_inv.append(formulas[1])
    model_accuracies.append(accuracy)
    explanation_accuracies.append(np.mean(exp_accuracies))
    explanation_accuracies_inv.append(np.mean(exp_accuracies))
    elapsed_times.append(np.mean(times))
    elapsed_times_inv.append(np.mean(times))

# %%
results = pd.DataFrame({
    'method': methods,
    'split': splits,
    'explanation': explanations,
    'explanation_inv': explanations_inv,
    'model_accuracy': model_accuracies,
    'explanation_accuracy': explanation_accuracies,
    'explanation_accuracy_inv': explanation_accuracies_inv,
    'elapsed_time': elapsed_times,
    'elapsed_time_inv': elapsed_times_inv,
})
results_general = results[results['method'] == "General"]
results_general.to_csv(os.path.join(results_dir, 'results_general.csv'))
results.to_csv(os.path.join(results_dir, 'results.csv'))
print(results)

# %% [markdown]
# # Summary

# %%
cols = ['model_accuracy', 'explanation_accuracy', 'explanation_accuracy_inv', 'elapsed_time', 'elapsed_time_inv']
mean_cols = [f'{c}_mean' for c in cols]
sem_cols = [f'{c}_sem' for c in cols]

# general
results_general = results[results['method'] == "General"]
df_mean = results_general[cols].mean()
df_sem = results_general[cols].sem()
df_mean.columns = mean_cols
df_sem.columns = sem_cols
summary_pruning = pd.concat([df_mean, df_sem])
summary_pruning.name = 'general'

# # lime
# df_mean = results_lime[cols].mean()
# df_sem = results_lime[cols].sem()
# df_mean.columns = mean_cols
# df_sem.columns = sem_cols
# summary_lime = pd.concat([df_mean, df_sem])
# summary_lime.name = 'lime'

# relu
results_relu = results[results['method'] == "Relu"]
df_mean = results_relu[cols].mean()
df_sem = results_relu[cols].sem()
df_mean.columns = mean_cols
df_sem.columns = sem_cols
summary_weights = pd.concat([df_mean, df_sem])
summary_weights.name = 'relu'

# psi
results_psi = results[results['method'] == "Psi"]
df_mean = results_psi[cols].mean()
df_sem = results_psi[cols].sem()
df_mean.columns = mean_cols
df_sem.columns = sem_cols
summary_psi = pd.concat([df_mean, df_sem])
summary_psi.name = 'psi'

# tree
results_tree = results[results['method'] == "Tree"]
df_mean = results_tree[cols].mean()
df_sem = results_tree[cols].sem()
df_mean.columns = mean_cols
df_sem.columns = sem_cols
summary_tree = pd.concat([df_mean, df_sem])
summary_tree.name = 'tree'

summary = pd.concat([summary_pruning,
                     #                      summary_lime,
                     summary_weights,
                     summary_psi,
                     summary_tree], axis=1).T
summary.columns = mean_cols + sem_cols
print(summary)

# %%
summary.to_csv(os.path.join(results_dir, 'summary.csv'))
