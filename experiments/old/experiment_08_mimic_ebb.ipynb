# %%
import sys
sys.path.append('..')
import os
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, KBinsDiscretizer
from lens.models.brl import XBRLClassifier
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from torch.utils.data import TensorDataset, DataLoader
import time
from sklearn.metrics import accuracy_score
from sympy import simplify_logic
from sklearn.model_selection import train_test_split

from lens.utils.base import validate_network, set_seed, tree_to_formula
from lens.utils.relu_nn import get_reduced_model, prune_features
from lens.utils.psi_nn import prune_equal_fanin
from lens import logic
import lens

set_seed(0)

#%%

data = pd.read_csv('data/mimic-ii/full_cohort_data.csv')
# data.drop('hgb_first')
fs = [
    'aline_flg',
    'gender_num',
    # 'hosp_exp_flg',
    # 'icu_exp_flg',
    # 'day_28_flg',
    # 'censor_flg',
    'sepsis_flg', 'chf_flg', 'afib_flg',
    'renal_flg', 'liver_flg', 'copd_flg', 'cad_flg', 'stroke_flg',
    'mal_flg', 'resp_flg',
]
features = fs
data1 = data[fs].values
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
data1 = imp_mean.fit_transform(data1)

f2 = fs.copy()
f2.append('day_icu_intime')
f2.append('service_unit')
f2.append('day_28_flg')
f2.append('hospital_los_day')
f2.append('icu_exp_flg')
f2.append('hosp_exp_flg')
f2.append('censor_flg')
f2.append('mort_day_censored')
f2 = data.columns.difference(f2)
data2 = data[f2].values
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
data2 = imp_mean.fit_transform(data2)
scaler = MinMaxScaler((0, 1))
data2 = scaler.fit_transform(data2)
features = features + list(f2)
est = KBinsDiscretizer(n_bins=3, encode='onehot-dense', strategy='uniform')
data2d = est.fit_transform(data2)
f2d = []
for feature in f2:
    #f2d.append(feature + '_VLOW')
    f2d.append(feature + '_LOW')
    f2d.append(feature + '_NORMAL')
    f2d.append(feature + '_HIGH')
    #f2d.append(feature + '_VHIGH')
features = fs + f2d

datax = np.hstack((data1, data2d))
datay = data['day_28_flg'].values

x = torch.FloatTensor(datax)
y = torch.LongTensor(datay)
print(x.shape)
print(y.shape)
# Out:
# torch.Size([1776, 90])
# torch.Size([1776])

# %%
results_dir = 'results/mimic_explain_classifier'
if not os.path.isdir(results_dir):
    os.makedirs(results_dir)


device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# concepts = [f'c{i:03}' for i in range(x.shape[1])]
concepts =  features
n_rep = 10
tot_epochs = 5001
prune_epochs = 2001
seed = 42

n_splits = 10
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)

# %%
def train_nn(x_train, y_train, need_pruning, seed, device, l1=0.001, lr=0.001, relu=False, verbose=False):
    set_seed(seed)
    x_train = x_train.to(device)
    y_train = y_train.to(device)
    layers = [
        torch.nn.Linear(x_train.size(1), 100),
        torch.nn.ReLU() if relu else torch.nn.LeakyReLU(),
        torch.nn.Linear(100, 50),
        torch.nn.ReLU() if relu else torch.nn.LeakyReLU(),
        torch.nn.Linear(50, 30),
        torch.nn.ReLU() if relu else torch.nn.LeakyReLU(),
        torch.nn.Linear(30, 10),
        torch.nn.ReLU() if relu else torch.nn.LeakyReLU(),
        torch.nn.Linear(10, 2),
        torch.nn.Softmax(dim=1),
    ]
    model = torch.nn.Sequential(*layers).to(device)

    optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
    loss_form = torch.nn.CrossEntropyLoss()
    model.train()
    for epoch in range(tot_epochs):
        # forward pass
        optimizer.zero_grad()
        y_pred = model(x_train)
        # Compute Loss
        loss = loss_form(y_pred, y_train)
        
        if need_pruning or relu:
            for module in model.children():
                if isinstance(module, torch.nn.Linear):
                    loss += l1 * torch.norm(module.weight, 1)
                    loss += l1 * torch.norm(module.bias, 1)
                    break

        # backward pass
        loss.backward()
        optimizer.step()

        if epoch == prune_epochs and need_pruning and not relu and epoch % 1000 == 1:
            prune_features(model, n_classes=1, device=device)
            need_pruning = True
            
        # compute accuracy
        if epoch % 500 == 0 and verbose:
            y_pred_d = torch.argmax(y_pred, dim=1)
            accuracy = y_pred_d.eq(y_train).sum().item() / y_train.size(0)
            print(f'\t Epoch {epoch}: train accuracy: {accuracy:.4f}')
    
    return model

# %%
def train_psi_nn(x_train, y_train, need_pruning, seed, device, verbose=False):
    set_seed(seed)
    x_train = x_train.to(device)
    y_train = y_train.to(device).to(torch.float)
    layers = [
        torch.nn.Linear(x_train.size(1), 5),
        torch.nn.Sigmoid(),
        torch.nn.Linear(5, 5),
        torch.nn.Sigmoid(),
        torch.nn.Linear(5, 1),
        torch.nn.Sigmoid(),
    ]
    model = torch.nn.Sequential(*layers).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.1)
    loss_form = torch.nn.BCELoss()
    model.train()
    for epoch in range(tot_epochs):
        # forward pass
        optimizer.zero_grad()
        y_pred = model(x_train).squeeze()
        # Compute Loss
        loss = loss_form(y_pred, y_train)

        for module in model.children():
            if isinstance(module, torch.nn.Linear):
                loss += 0.001 * torch.norm(module.weight, 1)

        # backward pass
        loss.backward()
        optimizer.step()

        if epoch > prune_epochs and need_pruning:
            model = prune_equal_fanin(model, 2, validate=True, device=device)
            need_pruning = False
            
        # compute accuracy
        if epoch % 500 == 0 and verbose:
            y_pred_d = y_pred > 0.5
            accuracy = y_pred_d.eq(y_train).sum().item() / y_train.size(0)
            print(f'\t Epoch {epoch}: train accuracy: {accuracy:.4f}')
    
    return model

# %%
def c_to_y(method, need_pruning, l1=0.0001, lr=0.0001, relu=False, verbose=False):
    methods = []
    splits = []
    explanations = []
    explanations_inv = []
    model_accuracies = []
    explanation_accuracies = []
    explanation_accuracies_inv = []
    elapsed_times = []
    elapsed_times_inv = []
    explanation_fidelities = []
    explanation_complexities = []
    for split, (trainval_index, test_index) in enumerate(skf.split(x.cpu().detach().numpy(), y.cpu().detach().numpy())):
        print(f'Split [{split+1}/{n_splits}]')
        x_trainval, x_test = torch.FloatTensor(x[trainval_index]), torch.FloatTensor(x[test_index])
        y_trainval, y_test = torch.LongTensor(y[trainval_index]), torch.LongTensor(y[test_index])
        x_train, x_val, y_train, y_val = train_test_split(x_trainval, y_trainval, test_size=0.3, random_state=42)
        
        model = train_nn(x_trainval, y_trainval, False, seed, device, l1=0, lr=0.0005, relu=False, verbose=False)
        y_preds_trainval = model(x_trainval.to(device)).cpu().argmax(dim=1)
        y_preds_train = model(x_train.to(device)).cpu().argmax(dim=1)
        y_preds_val = model(x_val.to(device)).cpu().argmax(dim=1)
        y_preds_test = model(x_test.to(device)).cpu().argmax(dim=1)
        
        black_box_accuracy = accuracy_score(y_test, y_preds_test)
        print(f'\t Black box accuracy: {black_box_accuracy:.4f}')
            
        explanation, explanation_inv = '', ''
        explanation_accuracy, explanation_accuracy_inv = 0, 0

        target_class = 1
        start = time.time()
        
        if 'tree' in method:
            if method == 'tree-3':
                classifier = DecisionTreeClassifier(random_state=seed, max_depth=3)
            else:
                classifier = DecisionTreeClassifier(random_state=seed)
            classifier.fit(x_trainval.cpu().detach().numpy(), y_preds_trainval.cpu().detach().numpy())
            y_preds = classifier.predict(x_test.cpu().detach().numpy())

            explanation = tree_to_formula(classifier, concepts, target_class)
            
            # compute metrics
            model_accuracy = accuracy_score(y_test, y_preds)
            explanation_accuracy = model_accuracy
            explanation_fidelity = accuracy_score(y_preds_test.cpu().detach().numpy(), y_preds)
            explanation_complexity = lens.logic.complexity(explanation)
        
        elif method == 'brl':
            train_dataset = TensorDataset(x_trainval, y_preds_trainval)
            val_dataset = TensorDataset(x_val, y_preds_val)
            test_dataset = TensorDataset(x_test, y_preds_test)
            dummy_concepts = [f'feature{i:010}' for i in range(len(concepts))]
            model = XBRLClassifier(name=os.path.join(results_dir, f'{method}_{split}'), 
                                   n_classes=1, 
                                   n_features=x_train.shape[1], feature_names=dummy_concepts, 
                                   class_names=['~day_28_flg', 'day_28_flg'], discretize=True)
            results = model.fit(train_dataset, metric=accuracy_score, save=True)
            global_explanation, elapsed_time = model.get_global_explanation(0, concepts=dummy_concepts, return_time=True)
            explanation_fidelity = 0
            explanation_complexity = 0
            
            # compute metrics
            y_preds = model.forward(x_test)
            model_accuracy = accuracy_score(y_test, y_preds)
            explanation = logic.base.replace_names(global_explanation, concepts)
            target_class = 1
            explanation_accuracy, y_formula = logic.base.test_explanation(global_explanation, 
                                                                          target_class, 
                                                                          x=x_test, y=y_test,
                                                                          metric=accuracy_score)
            explanation_fidelity = accuracy_score(y_preds_test.cpu().detach().numpy(), y_formula)
            explanation_complexity = lens.logic.complexity(global_explanation)
                
        else:
            if method == 'psi':
                # positive class
                target_class = 1
                model = train_psi_nn(x_trainval, y_preds_trainval.eq(target_class), need_pruning, seed, device, verbose)
                y_preds = model(x_test.to(device)).cpu().detach().numpy()>0.5
                model_accuracy = accuracy_score(y_preds_test.cpu().detach().numpy(), y_preds)
                
            else:
                model = train_nn(x_trainval, y_preds_trainval, need_pruning, seed, device, l1, lr, relu, verbose)
                y_preds = model(x_test.to(device)).cpu().detach().numpy().argmax(axis=1)
                model_accuracy = accuracy_score(y_preds_test.cpu().detach().numpy(), y_preds)

            print(f'\t Model\'s accuracy: {model_accuracy:.4f}')
            
            # positive class
            target_class = 1
            if method == 'psi':
                global_explanation = logic.generate_fol_explanations(model, device)[0]
                print(global_explanation)
            else:
                global_explanation, _, _ = logic.relu_nn.combine_local_explanations(model, 
                                                                                   x_val.to(device), 
                                                                                   y_preds_val.to(device), 
                                                                                   topk_explanations=1,
                                                                                   target_class=target_class,
                                                                                   method=method, device=device)
            
            explanation_fidelity = 0
            explanation_complexity = 0
            if global_explanation:
                explanation = logic.base.replace_names(global_explanation, concepts)
                explanation_accuracy, y_formula = logic.base.test_explanation(global_explanation, 
                                                                              target_class, 
                                                                              x=x_test, y=y_test,
                                                                              metric=accuracy_score)
                explanation_fidelity = accuracy_score(y_preds_test.cpu().detach().numpy(), y_formula)
                explanation_complexity = lens.logic.complexity(global_explanation)

        elapsed_time = time.time() - start
        
        if verbose:
            print(f'\t Model\'s accuracy: {model_accuracy:.4f}')
            print(f'\t Class {target_class} - Global explanation: "{explanation}" - Accuracy: {explanation_accuracy:.4f}')
            print(f'\t Elapsed time {elapsed_time}')
            print(f'\t Fidelity: "{explanation_fidelity:.4f}" - Complexity: "{explanation_complexity}"')

        methods.append(method)
        splits.append(split)
        explanations.append(explanation)
        model_accuracies.append(black_box_accuracy)
        explanation_accuracies.append(explanation_accuracy)
        elapsed_times.append(elapsed_time)
        explanation_fidelities.append(explanation_fidelity)
        explanation_complexities.append(explanation_complexity)
    
    explanation_consistency = lens.logic.formula_consistency(explanations)
    print(f'Consistency of explanations: {explanation_consistency:.4f}')
    
    results = pd.DataFrame({
        'method': methods,
        'split': splits,
        'explanation': explanations,
        'model_accuracy': model_accuracies,
        'explanation_accuracy': explanation_accuracies,
        'explanation_fidelity': explanation_fidelities,
        'explanation_complexity': explanation_complexities,
        'explanation_consistency': explanation_consistency,
        'elapsed_time': elapsed_times,
    })
    results.to_csv(os.path.join(results_dir, f'results_{method}.csv'))
    
    return results

# %% [markdown]
# # General pruning

# %%
method = 'pruning'
need_pruning = True
relu = False
results_pruning = c_to_y(method, need_pruning, relu=relu, l1=0.000001, lr=0.0005, verbose=True)
results_pruning
# Out:
# Split [1/10]
# 	 Black box accuracy: 0.8652
# 	 Epoch 0: train accuracy: 0.1120
# 	 Epoch 500: train accuracy: 0.9700
# 	 Epoch 1000: train accuracy: 0.9887
# 	 Epoch 1500: train accuracy: 0.9887
# 	 Epoch 2000: train accuracy: 0.9887
# Pruned 85/90 features
# 	 Epoch 2500: train accuracy: 0.9218
# 	 Epoch 3000: train accuracy: 0.9218
# 	 Epoch 3500: train accuracy: 0.9218
# 	 Epoch 4000: train accuracy: 0.9218
# 	 Epoch 4500: train accuracy: 0.9218
# 	 Epoch 5000: train accuracy: 0.9218
# 	 Model's accuracy: 0.9551
# 	 Model's accuracy: 0.9551
# 	 Class 1 - Global explanation: "afib_flg & stroke_flg & ~abg_count_NORMAL & ~sapsi_first_HIGH & ~sodium_first_LOW" - Accuracy: 0.8427
# 	 Elapsed time 15.418745040893555
# 	 Fidelity: "0.9551" - Complexity: "5"
# Split [2/10]
# 	 Black box accuracy: 0.8652
# 	 Epoch 0: train accuracy: 0.1176
# 	 Epoch 500: train accuracy: 0.9844
# 	 Epoch 1000: train accuracy: 0.9919
# 	 Epoch 1500: train accuracy: 0.9919
# 	 Epoch 2000: train accuracy: 0.9919
# Pruned 86/90 features
# 	 Epoch 2500: train accuracy: 0.9161
# 	 Epoch 3000: train accuracy: 0.9161
# 	 Epoch 3500: train accuracy: 0.9161
# 	 Epoch 4000: train accuracy: 0.9161
# 	 Epoch 4500: train accuracy: 0.9161
# 	 Epoch 5000: train accuracy: 0.9161
# 	 Model's accuracy: 0.9270
# 	 Model's accuracy: 0.9270
# 	 Class 1 - Global explanation: "afib_flg & stroke_flg & ~sapsi_first_HIGH & ~weight_first_NORMAL" - Accuracy: 0.8539
# 	 Elapsed time 14.452853679656982
# 	 Fidelity: "0.9213" - Complexity: "4"
# Split [3/10]
# 	 Black box accuracy: 0.8764
# 	 Epoch 0: train accuracy: 0.1320
# 	 Epoch 500: train accuracy: 0.9931
# 	 Epoch 1000: train accuracy: 0.9944
# 	 Epoch 1500: train accuracy: 0.9944
# 	 Epoch 2000: train accuracy: 0.9962
# Pruned 83/90 features
# 	 Epoch 2500: train accuracy: 0.9368
# 	 Epoch 3000: train accuracy: 0.9368
# 	 Epoch 3500: train accuracy: 0.9374
# 	 Epoch 4000: train accuracy: 0.9374
# 	 Epoch 4500: train accuracy: 0.9374
# 	 Epoch 5000: train accuracy: 0.9374
# 	 Model's accuracy: 0.9326
# 	 Model's accuracy: 0.9326
# 	 Class 1 - Global explanation: "stroke_flg & age_HIGH & ~hgb_first_LOW & ~map_1st_HIGH & ~sapsi_first_LOW & ~sapsi_first_HIGH & ~sodium_first_LOW" - Accuracy: 0.8764
# 	 Elapsed time 15.885036706924438
# 	 Fidelity: "0.9326" - Complexity: "7"
# Split [4/10]
# 	 Black box accuracy: 0.8596
# 	 Epoch 0: train accuracy: 0.1220
# 	 Epoch 500: train accuracy: 0.9643
# 	 Epoch 1000: train accuracy: 0.9931
# 	 Epoch 1500: train accuracy: 0.9931
# 	 Epoch 2000: train accuracy: 0.9937
# Pruned 83/90 features
# 	 Epoch 2500: train accuracy: 0.9449
# 	 Epoch 3000: train accuracy: 0.9449
# 	 Epoch 3500: train accuracy: 0.9449
# 	 Epoch 4000: train accuracy: 0.9449
# 	 Epoch 4500: train accuracy: 0.9449
# 	 Epoch 5000: train accuracy: 0.9449
# 	 Model's accuracy: 0.9607
# 	 Model's accuracy: 0.9607
# 	 Class 1 - Global explanation: "stroke_flg & age_HIGH & ~hgb_first_LOW & ~sapsi_first_LOW & ~sapsi_first_HIGH & ~tco2_first_HIGH & ~weight_first_NORMAL" - Accuracy: 0.8596
# 	 Elapsed time 14.851997375488281
# 	 Fidelity: "0.9551" - Complexity: "7"
# Split [5/10]
# 	 Black box accuracy: 0.8258
# 	 Epoch 0: train accuracy: 0.1220
# 	 Epoch 500: train accuracy: 0.8780
# 	 Epoch 1000: train accuracy: 0.9906
# 	 Epoch 1500: train accuracy: 0.9906
# 	 Epoch 2000: train accuracy: 0.9925
# Pruned 83/90 features
# 	 Epoch 2500: train accuracy: 0.9337
# 	 Epoch 3000: train accuracy: 0.9343
# 	 Epoch 3500: train accuracy: 0.9349
# 	 Epoch 4000: train accuracy: 0.9349
# 	 Epoch 4500: train accuracy: 0.9349
# 	 Epoch 5000: train accuracy: 0.9349
# 	 Model's accuracy: 0.9382
# 	 Model's accuracy: 0.9382
# 	 Class 1 - Global explanation: "afib_flg & stroke_flg & age_HIGH & ~hgb_first_LOW & ~sapsi_first_HIGH & ~sodium_first_LOW & ~sofa_first_HIGH" - Accuracy: 0.8483
# 	 Elapsed time 15.033448934555054
# 	 Fidelity: "0.9101" - Complexity: "7"
# Split [6/10]
# 	 Black box accuracy: 0.8596
# 	 Epoch 0: train accuracy: 0.1258
# 	 Epoch 500: train accuracy: 0.8742
# 	 Epoch 1000: train accuracy: 0.9956
# 	 Epoch 1500: train accuracy: 0.9962
# 	 Epoch 2000: train accuracy: 0.9962
# Pruned 83/90 features
# 	 Epoch 2500: train accuracy: 0.9293
# 	 Epoch 3000: train accuracy: 0.9293
# 	 Epoch 3500: train accuracy: 0.9293
# 	 Epoch 4000: train accuracy: 0.9293
# 	 Epoch 4500: train accuracy: 0.9293
# 	 Epoch 5000: train accuracy: 0.9293
# 	 Model's accuracy: 0.9494
# 	 Model's accuracy: 0.9494
# 	 Class 1 - Global explanation: "stroke_flg & age_HIGH & ~afib_flg & ~hgb_first_LOW & ~sapsi_first_LOW & ~sapsi_first_HIGH & ~sodium_first_LOW" - Accuracy: 0.8876
# 	 Elapsed time 14.964742183685303
# 	 Fidelity: "0.9157" - Complexity: "7"
# Split [7/10]
# 	 Black box accuracy: 0.8079
# 	 Epoch 0: train accuracy: 0.1238
# 	 Epoch 500: train accuracy: 0.8762
# 	 Epoch 1000: train accuracy: 0.9806
# 	 Epoch 1500: train accuracy: 0.9819
# 	 Epoch 2000: train accuracy: 0.9819
# Pruned 84/90 features
# 	 Epoch 2500: train accuracy: 0.9368
# 	 Epoch 3000: train accuracy: 0.9368
# 	 Epoch 3500: train accuracy: 0.9368
# 	 Epoch 4000: train accuracy: 0.9368
# 	 Epoch 4500: train accuracy: 0.9368
# 	 Epoch 5000: train accuracy: 0.9368
# 	 Model's accuracy: 0.9322
# 	 Model's accuracy: 0.9322
# 	 Class 1 - Global explanation: "stroke_flg & age_HIGH & ~afib_flg & ~hgb_first_LOW & ~sofa_first_HIGH & ~weight_first_NORMAL" - Accuracy: 0.8362
# 	 Elapsed time 14.96267819404602
# 	 Fidelity: "0.8814" - Complexity: "6"
# Split [8/10]
# 	 Black box accuracy: 0.8701
# 	 Epoch 0: train accuracy: 0.1194
# 	 Epoch 500: train accuracy: 0.9912
# 	 Epoch 1000: train accuracy: 0.9919
# 	 Epoch 1500: train accuracy: 0.9919
# 	 Epoch 2000: train accuracy: 0.9919
# Pruned 78/90 features
# 	 Epoch 2500: train accuracy: 0.9481
# 	 Epoch 3000: train accuracy: 0.9481
# 	 Epoch 3500: train accuracy: 0.9481
# 	 Epoch 4000: train accuracy: 0.9481
# 	 Epoch 4500: train accuracy: 0.9481
# 	 Epoch 5000: train accuracy: 0.9481
# 	 Model's accuracy: 0.9887
# 	 Model's accuracy: 0.9887
# 	 Class 1 - Global explanation: "stroke_flg & age_HIGH & ~afib_flg & ~abg_count_NORMAL & ~age_NORMAL & ~bun_first_NORMAL & ~creatinine_first_NORMAL & ~hgb_first_LOW & ~iv_day_1_NORMAL & ~sapsi_first_LOW & ~sapsi_first_HIGH & ~sodium_first_LOW" - Accuracy: 0.8475
# 	 Elapsed time 15.80054259300232
# 	 Fidelity: "0.9548" - Complexity: "12"
# Split [9/10]
# 	 Black box accuracy: 0.8305
# 	 Epoch 0: train accuracy: 0.1351
# 	 Epoch 500: train accuracy: 0.9987
# 	 Epoch 1000: train accuracy: 0.9994
# 	 Epoch 1500: train accuracy: 0.9994
# 	 Epoch 2000: train accuracy: 0.9994
# Pruned 84/90 features
# 	 Epoch 2500: train accuracy: 0.9356
# 	 Epoch 3000: train accuracy: 0.9356
# 	 Epoch 3500: train accuracy: 0.9356
# 	 Epoch 4000: train accuracy: 0.9356
# 	 Epoch 4500: train accuracy: 0.9356
# 	 Epoch 5000: train accuracy: 0.9356
# 	 Model's accuracy: 0.9492
# 	 Model's accuracy: 0.9492
# 	 Class 1 - Global explanation: "stroke_flg & age_HIGH & ~afib_flg & ~age_LOW & ~sapsi_first_HIGH & ~sodium_first_LOW" - Accuracy: 0.8531
# 	 Elapsed time 15.153543949127197
# 	 Fidelity: "0.8757" - Complexity: "6"
# Split [10/10]
# 	 Black box accuracy: 0.8531
# 	 Epoch 0: train accuracy: 0.1420
# 	 Epoch 500: train accuracy: 0.9987
# 	 Epoch 1000: train accuracy: 0.9987
# 	 Epoch 1500: train accuracy: 0.9987
# 	 Epoch 2000: train accuracy: 0.9987
# Pruned 81/90 features
# 	 Epoch 2500: train accuracy: 0.9381
# 	 Epoch 3000: train accuracy: 0.9381
# 	 Epoch 3500: train accuracy: 0.9381
# 	 Epoch 4000: train accuracy: 0.9381
# 	 Epoch 4500: train accuracy: 0.9381
# 	 Epoch 5000: train accuracy: 0.9381
# 	 Model's accuracy: 0.9718
# 	 Model's accuracy: 0.9718
# 	 Class 1 - Global explanation: "stroke_flg & age_HIGH & ~afib_flg & ~bun_first_NORMAL & ~hgb_first_LOW & ~map_1st_HIGH & ~sapsi_first_LOW & ~sapsi_first_HIGH & ~sodium_first_LOW" - Accuracy: 0.8701
# 	 Elapsed time 16.495365381240845
# 	 Fidelity: "0.9266" - Complexity: "9"
# Consistency of explanations: 0.4118
#     method  split                                        explanation  \
# 0  pruning      0  afib_flg & stroke_flg & ~abg_count_NORMAL & ~s...
# 1  pruning      1  afib_flg & stroke_flg & ~sapsi_first_HIGH & ~w...
# 2  pruning      2  stroke_flg & age_HIGH & ~hgb_first_LOW & ~map_...
# 3  pruning      3  stroke_flg & age_HIGH & ~hgb_first_LOW & ~saps...
# 4  pruning      4  afib_flg & stroke_flg & age_HIGH & ~hgb_first_...
# 5  pruning      5  stroke_flg & age_HIGH & ~afib_flg & ~hgb_first...
# 6  pruning      6  stroke_flg & age_HIGH & ~afib_flg & ~hgb_first...
# 7  pruning      7  stroke_flg & age_HIGH & ~afib_flg & ~abg_count...
# 8  pruning      8  stroke_flg & age_HIGH & ~afib_flg & ~age_LOW &...
# 9  pruning      9  stroke_flg & age_HIGH & ~afib_flg & ~bun_first...
#
#    model_accuracy  explanation_accuracy  explanation_fidelity  \
# 0        0.865169              0.842697              0.955056
# 1        0.865169              0.853933              0.921348
# 2        0.876404              0.876404              0.932584
# 3        0.859551              0.859551              0.955056
# 4        0.825843              0.848315              0.910112
# 5        0.859551              0.887640              0.915730
# 6        0.807910              0.836158              0.881356
# 7        0.870056              0.847458              0.954802
# 8        0.830508              0.853107              0.875706
# 9        0.853107              0.870056              0.926554
#
#    explanation_complexity  explanation_consistency  elapsed_time
# 0                       5                 0.411765     15.418745
# 1                       4                 0.411765     14.452854
# 2                       7                 0.411765     15.885037
# 3                       7                 0.411765     14.851997
# 4                       7                 0.411765     15.033449
# 5                       7                 0.411765     14.964742
# 6                       6                 0.411765     14.962678
# 7                      12                 0.411765     15.800543
# 8                       6                 0.411765     15.153544
# 9                       9                 0.411765     16.495365

# %% [markdown]
# # ReLUs

# %%
method = 'weights'
need_pruning = False
relu = True
results_weights = c_to_y(method='weights', need_pruning=False, l1=0.0000001, lr=0.0005, relu=True, verbose=True)
results_weights
# Out:
# Split [1/10]
# 	 Black box accuracy: 0.8652
# 	 Epoch 0: train accuracy: 0.1120
# 	 Epoch 500: train accuracy: 0.9931
# 	 Epoch 1000: train accuracy: 0.9931
# 	 Epoch 1500: train accuracy: 0.9931
# 	 Epoch 2000: train accuracy: 0.9931
# 	 Epoch 2500: train accuracy: 0.9931
# 	 Epoch 3000: train accuracy: 0.9931
# 	 Epoch 3500: train accuracy: 0.9931
# 	 Epoch 4000: train accuracy: 0.9931
# 	 Epoch 4500: train accuracy: 0.9931
# 	 Epoch 5000: train accuracy: 0.9931
# 	 Model's accuracy: 0.9775
# 	 Model's accuracy: 0.9775
# 	 Class 1 - Global explanation: "stroke_flg & ~afib_flg & ~abg_count_NORMAL & ~hgb_first_LOW & ~sapsi_first_HIGH & ~sodium_first_LOW & ~weight_first_NORMAL" - Accuracy: 0.8371
# 	 Elapsed time 15.642074584960938
# 	 Fidelity: "0.8933" - Complexity: "7"
# Split [2/10]
# 	 Black box accuracy: 0.8652
# 	 Epoch 0: train accuracy: 0.1176
# 	 Epoch 500: train accuracy: 0.9931
# 	 Epoch 1000: train accuracy: 0.9937
# 	 Epoch 1500: train accuracy: 0.9937
# 	 Epoch 2000: train accuracy: 0.9937
# 	 Epoch 2500: train accuracy: 0.9937
# 	 Epoch 3000: train accuracy: 0.9937
# 	 Epoch 3500: train accuracy: 0.9937
# 	 Epoch 4000: train accuracy: 0.9937
# 	 Epoch 4500: train accuracy: 0.9937
# 	 Epoch 5000: train accuracy: 0.9937
# 	 Model's accuracy: 0.9719
# 	 Model's accuracy: 0.9719
# 	 Class 1 - Global explanation: "stroke_flg & ~afib_flg & ~weight_first_NORMAL" - Accuracy: 0.8258
# 	 Elapsed time 15.179162979125977
# 	 Fidelity: "0.8820" - Complexity: "3"
# Split [3/10]
# 	 Black box accuracy: 0.8764
# 	 Epoch 0: train accuracy: 0.1320
# 	 Epoch 500: train accuracy: 0.9987
# 	 Epoch 1000: train accuracy: 0.9987
# 	 Epoch 1500: train accuracy: 0.9994
# 	 Epoch 2000: train accuracy: 0.9994
# 	 Epoch 2500: train accuracy: 1.0000
# 	 Epoch 3000: train accuracy: 1.0000
# 	 Epoch 3500: train accuracy: 1.0000
# 	 Epoch 4000: train accuracy: 1.0000
# 	 Epoch 4500: train accuracy: 1.0000
# 	 Epoch 5000: train accuracy: 1.0000
# 	 Model's accuracy: 0.9551
# 	 Model's accuracy: 0.9551
# 	 Class 1 - Global explanation: "stroke_flg & ~sapsi_first_LOW & ~sapsi_first_HIGH & ~sodium_first_LOW" - Accuracy: 0.8652
# 	 Elapsed time 19.137606382369995
# 	 Fidelity: "0.9326" - Complexity: "4"
# Split [4/10]
# 	 Black box accuracy: 0.8596
# 	 Epoch 0: train accuracy: 0.1220
# 	 Epoch 500: train accuracy: 0.9962
# 	 Epoch 1000: train accuracy: 0.9969
# 	 Epoch 1500: train accuracy: 0.9969
# 	 Epoch 2000: train accuracy: 0.9969
# 	 Epoch 2500: train accuracy: 0.9969
# 	 Epoch 3000: train accuracy: 0.9969
# 	 Epoch 3500: train accuracy: 0.9969
# 	 Epoch 4000: train accuracy: 0.9969
# 	 Epoch 4500: train accuracy: 0.9969
# 	 Epoch 5000: train accuracy: 0.9969
# 	 Model's accuracy: 0.9663
# 	 Model's accuracy: 0.9663
# 	 Class 1 - Global explanation: "stroke_flg & ~abg_count_NORMAL & ~age_LOW & ~bun_first_HIGH & ~hgb_first_LOW & ~sapsi_first_LOW & ~sapsi_first_HIGH & ~weight_first_NORMAL" - Accuracy: 0.8596
# 	 Elapsed time 16.155410289764404
# 	 Fidelity: "0.9438" - Complexity: "8"
# Split [5/10]
# 	 Black box accuracy: 0.8258
# 	 Epoch 0: train accuracy: 0.1220
# 	 Epoch 500: train accuracy: 0.9919
# 	 Epoch 1000: train accuracy: 0.9937
# 	 Epoch 1500: train accuracy: 0.9962
# 	 Epoch 2000: train accuracy: 0.9962
# 	 Epoch 2500: train accuracy: 0.9962
# 	 Epoch 3000: train accuracy: 0.9962
# 	 Epoch 3500: train accuracy: 0.9962
# 	 Epoch 4000: train accuracy: 0.9962
# 	 Epoch 4500: train accuracy: 0.9962
# 	 Epoch 5000: train accuracy: 0.9969
# 	 Model's accuracy: 0.9775
# 	 Model's accuracy: 0.9775
# 	 Class 1 - Global explanation: "stroke_flg & age_HIGH & ~abg_count_NORMAL & ~creatinine_first_NORMAL & ~hgb_first_LOW & ~map_1st_HIGH & ~sapsi_first_HIGH" - Accuracy: 0.8596
# 	 Elapsed time 21.770095348358154
# 	 Fidelity: "0.9438" - Complexity: "7"
# Split [6/10]
# 	 Black box accuracy: 0.8596
# 	 Epoch 0: train accuracy: 0.1258
# 	 Epoch 500: train accuracy: 0.9987
# 	 Epoch 1000: train accuracy: 1.0000
# 	 Epoch 1500: train accuracy: 1.0000
# 	 Epoch 2000: train accuracy: 1.0000
# 	 Epoch 2500: train accuracy: 1.0000
# 	 Epoch 3000: train accuracy: 1.0000
# 	 Epoch 3500: train accuracy: 1.0000
# 	 Epoch 4000: train accuracy: 1.0000
# 	 Epoch 4500: train accuracy: 1.0000
# 	 Epoch 5000: train accuracy: 1.0000
# 	 Model's accuracy: 0.9719
# 	 Model's accuracy: 0.9719
# 	 Class 1 - Global explanation: "stroke_flg & ~creatinine_first_NORMAL & ~hgb_first_LOW & ~sapsi_first_LOW & ~sapsi_first_HIGH & ~sodium_first_LOW & ~sofa_first_HIGH" - Accuracy: 0.8258
# 	 Elapsed time 17.68642783164978
# 	 Fidelity: "0.8989" - Complexity: "7"
# Split [7/10]
# 	 Black box accuracy: 0.8079
# 	 Epoch 0: train accuracy: 0.1238
# 	 Epoch 500: train accuracy: 0.9919
# 	 Epoch 1000: train accuracy: 0.9962
# 	 Epoch 1500: train accuracy: 0.9962
# 	 Epoch 2000: train accuracy: 0.9962
# 	 Epoch 2500: train accuracy: 0.9962
# 	 Epoch 3000: train accuracy: 0.9962
# 	 Epoch 3500: train accuracy: 0.9962
# 	 Epoch 4000: train accuracy: 0.9962
# 	 Epoch 4500: train accuracy: 0.9962
# 	 Epoch 5000: train accuracy: 0.9962
# 	 Model's accuracy: 0.9774
# 	 Model's accuracy: 0.9774
# 	 Class 1 - Global explanation: "stroke_flg & ~resp_flg & ~creatinine_first_NORMAL & ~hgb_first_LOW & ~sapsi_first_LOW & ~sapsi_first_HIGH & ~sodium_first_LOW & ~tco2_first_HIGH & ~weight_first_NORMAL" - Accuracy: 0.8305
# 	 Elapsed time 16.702914476394653
# 	 Fidelity: "0.8644" - Complexity: "9"
# Split [8/10]
# 	 Black box accuracy: 0.8701
# 	 Epoch 0: train accuracy: 0.1194
# 	 Epoch 500: train accuracy: 0.9944
# 	 Epoch 1000: train accuracy: 0.9987
# 	 Epoch 1500: train accuracy: 0.9987
# 	 Epoch 2000: train accuracy: 0.9987
# 	 Epoch 2500: train accuracy: 0.9987
# 	 Epoch 3000: train accuracy: 0.9987
# 	 Epoch 3500: train accuracy: 0.9987
# 	 Epoch 4000: train accuracy: 0.9987
# 	 Epoch 4500: train accuracy: 0.9987
# 	 Epoch 5000: train accuracy: 0.9987
# 	 Model's accuracy: 0.9774
# 	 Model's accuracy: 0.9774
# 	 Class 1 - Global explanation: "afib_flg & age_HIGH & ~stroke_flg & ~abg_count_NORMAL & ~bun_first_NORMAL & ~bun_first_HIGH & ~chloride_first_HIGH & ~creatinine_first_NORMAL & ~hgb_first_LOW & ~sapsi_first_LOW & ~sapsi_first_HIGH & ~sodium_first_LOW" - Accuracy: 0.8418
# 	 Elapsed time 23.0760977268219
# 	 Fidelity: "0.9040" - Complexity: "12"
# Split [9/10]
# 	 Black box accuracy: 0.8305
# 	 Epoch 0: train accuracy: 0.1351
# 	 Epoch 500: train accuracy: 0.9981
# 	 Epoch 1000: train accuracy: 0.9987
# 	 Epoch 1500: train accuracy: 0.9987
# 	 Epoch 2000: train accuracy: 0.9987
# 	 Epoch 2500: train accuracy: 0.9987
# 	 Epoch 3000: train accuracy: 0.9987
# 	 Epoch 3500: train accuracy: 0.9987
# 	 Epoch 4000: train accuracy: 0.9987
# 	 Epoch 4500: train accuracy: 0.9987
# 	 Epoch 5000: train accuracy: 0.9987
# 	 Model's accuracy: 0.9661
# 	 Model's accuracy: 0.9661
# 	 Class 1 - Global explanation: "stroke_flg & ~sodium_first_LOW" - Accuracy: 0.8475
# 	 Elapsed time 15.923318147659302
# 	 Fidelity: "0.8814" - Complexity: "2"
# Split [10/10]
# 	 Black box accuracy: 0.8531
# 	 Epoch 0: train accuracy: 0.1420
# 	 Epoch 500: train accuracy: 1.0000
# 	 Epoch 1000: train accuracy: 1.0000
# 	 Epoch 1500: train accuracy: 1.0000
# 	 Epoch 2000: train accuracy: 1.0000
# 	 Epoch 2500: train accuracy: 1.0000
# 	 Epoch 3000: train accuracy: 1.0000
# 	 Epoch 3500: train accuracy: 1.0000
# 	 Epoch 4000: train accuracy: 1.0000
# 	 Epoch 4500: train accuracy: 1.0000
# 	 Epoch 5000: train accuracy: 1.0000
# 	 Model's accuracy: 1.0000
# 	 Model's accuracy: 1.0000
# 	 Class 1 - Global explanation: "~stroke_flg & ~hgb_first_LOW & ~sapsi_first_LOW & ~sapsi_first_HIGH & ~sodium_first_LOW" - Accuracy: 0.5141
# 	 Elapsed time 23.292561054229736
# 	 Fidelity: "0.5141" - Complexity: "5"
# Consistency of explanations: 0.3556
#     method  split                                        explanation  \
# 0  weights      0  stroke_flg & ~afib_flg & ~abg_count_NORMAL & ~...
# 1  weights      1      stroke_flg & ~afib_flg & ~weight_first_NORMAL
# 2  weights      2  stroke_flg & ~sapsi_first_LOW & ~sapsi_first_H...
# 3  weights      3  stroke_flg & ~abg_count_NORMAL & ~age_LOW & ~b...
# 4  weights      4  stroke_flg & age_HIGH & ~abg_count_NORMAL & ~c...
# 5  weights      5  stroke_flg & ~creatinine_first_NORMAL & ~hgb_f...
# 6  weights      6  stroke_flg & ~resp_flg & ~creatinine_first_NOR...
# 7  weights      7  afib_flg & age_HIGH & ~stroke_flg & ~abg_count...
# 8  weights      8                     stroke_flg & ~sodium_first_LOW
# 9  weights      9  ~stroke_flg & ~hgb_first_LOW & ~sapsi_first_LO...
#
#    model_accuracy  explanation_accuracy  explanation_fidelity  \
# 0        0.865169              0.837079              0.893258
# 1        0.865169              0.825843              0.882022
# 2        0.876404              0.865169              0.932584
# 3        0.859551              0.859551              0.943820
# 4        0.825843              0.859551              0.943820
# 5        0.859551              0.825843              0.898876
# 6        0.807910              0.830508              0.864407
# 7        0.870056              0.841808              0.903955
# 8        0.830508              0.847458              0.881356
# 9        0.853107              0.514124              0.514124
#
#    explanation_complexity  explanation_consistency  elapsed_time
# 0                       7                 0.355556     15.642075
# 1                       3                 0.355556     15.179163
# 2                       4                 0.355556     19.137606
# 3                       8                 0.355556     16.155410
# 4                       7                 0.355556     21.770095
# 5                       7                 0.355556     17.686428
# 6                       9                 0.355556     16.702914
# 7                      12                 0.355556     23.076098
# 8                       2                 0.355556     15.923318
# 9                       5                 0.355556     23.292561

# %% [markdown]
# # Psi network

# %%
method = 'psi'
need_pruning = True
relu = False
results_psi = c_to_y(method, need_pruning, l1=0.0001, lr=0.0001, relu=False, verbose=True)
results_psi
# Out:
# Split [1/10]
# 	 Black box accuracy: 0.8652
# 	 Epoch 0: train accuracy: 0.1120
# 	 Epoch 500: train accuracy: 0.9743
# 	 Epoch 1000: train accuracy: 0.9775
# 	 Epoch 1500: train accuracy: 0.9756
# 	 Epoch 2000: train accuracy: 0.9750
# 	 Epoch 2500: train accuracy: 0.9080
# 	 Epoch 3000: train accuracy: 0.9074
# 	 Epoch 3500: train accuracy: 0.9074
# 	 Epoch 4000: train accuracy: 0.9074
# 	 Epoch 4500: train accuracy: 0.9074
# 	 Epoch 5000: train accuracy: 0.9074
# 	 Model's accuracy: 0.9213
# (feature0000000009)
# 	 Model's accuracy: 0.9213
# 	 Class 1 - Global explanation: "(stroke_flg)" - Accuracy: 0.8427
# 	 Elapsed time 10.046723365783691
# 	 Fidelity: "0.9213" - Complexity: "1"
# Split [2/10]
# 	 Black box accuracy: 0.8652
# 	 Epoch 0: train accuracy: 0.1176
# 	 Epoch 500: train accuracy: 0.9637
# 	 Epoch 1000: train accuracy: 0.9700
# 	 Epoch 1500: train accuracy: 0.9700
# 	 Epoch 2000: train accuracy: 0.9768
# 	 Epoch 2500: train accuracy: 0.9043
# 	 Epoch 3000: train accuracy: 0.9036
# 	 Epoch 3500: train accuracy: 0.9036
# 	 Epoch 4000: train accuracy: 0.9036
# 	 Epoch 4500: train accuracy: 0.9036
# 	 Epoch 5000: train accuracy: 0.9036
# 	 Model's accuracy: 0.8820
# (feature0000000009)
# 	 Model's accuracy: 0.8820
# 	 Class 1 - Global explanation: "(stroke_flg)" - Accuracy: 0.8258
# 	 Elapsed time 10.29395842552185
# 	 Fidelity: "0.8820" - Complexity: "1"
# Split [3/10]
# 	 Black box accuracy: 0.8764
# 	 Epoch 0: train accuracy: 0.1320
# 	 Epoch 500: train accuracy: 0.9768
# 	 Epoch 1000: train accuracy: 0.9806
# 	 Epoch 1500: train accuracy: 0.9762
# 	 Epoch 2000: train accuracy: 0.9781
# 	 Epoch 2500: train accuracy: 0.9355
# 	 Epoch 3000: train accuracy: 0.9355
# 	 Epoch 3500: train accuracy: 0.9355
# 	 Epoch 4000: train accuracy: 0.9355
# 	 Epoch 4500: train accuracy: 0.9355
# 	 Epoch 5000: train accuracy: 0.9355
# 	 Model's accuracy: 0.9326
# (feature0000000009 & feature0000000017)
# 	 Model's accuracy: 0.9326
# 	 Class 1 - Global explanation: "(stroke_flg & age_HIGH)" - Accuracy: 0.8764
# 	 Elapsed time 10.179928302764893
# 	 Fidelity: "0.9326" - Complexity: "2"
# Split [4/10]
# 	 Black box accuracy: 0.8596
# 	 Epoch 0: train accuracy: 0.1220
# 	 Epoch 500: train accuracy: 0.9693
# 	 Epoch 1000: train accuracy: 0.9793
# 	 Epoch 1500: train accuracy: 0.9743
# 	 Epoch 2000: train accuracy: 0.9812
# 	 Epoch 2500: train accuracy: 0.9230
# 	 Epoch 3000: train accuracy: 0.9230
# 	 Epoch 3500: train accuracy: 0.9230
# 	 Epoch 4000: train accuracy: 0.9230
# 	 Epoch 4500: train accuracy: 0.9230
# 	 Epoch 5000: train accuracy: 0.9230
# 	 Model's accuracy: 0.9438
# (feature0000000009 & ~feature0000000063)
# 	 Model's accuracy: 0.9438
# 	 Class 1 - Global explanation: "(stroke_flg & ~sapsi_first_LOW)" - Accuracy: 0.8596
# 	 Elapsed time 10.09394907951355
# 	 Fidelity: "0.9438" - Complexity: "2"
# Split [5/10]
# 	 Black box accuracy: 0.8258
# 	 Epoch 0: train accuracy: 0.1220
# 	 Epoch 500: train accuracy: 0.9643
# 	 Epoch 1000: train accuracy: 0.9656
# 	 Epoch 1500: train accuracy: 0.9650
# 	 Epoch 2000: train accuracy: 0.9650
# 	 Epoch 2500: train accuracy: 0.9293
# 	 Epoch 3000: train accuracy: 0.9293
# 	 Epoch 3500: train accuracy: 0.9293
# 	 Epoch 4000: train accuracy: 0.9293
# 	 Epoch 4500: train accuracy: 0.9293
# 	 Epoch 5000: train accuracy: 0.9293
# 	 Model's accuracy: 0.9438
# (feature0000000017)
# 	 Model's accuracy: 0.9438
# 	 Class 1 - Global explanation: "(age_HIGH)" - Accuracy: 0.7416
# 	 Elapsed time 10.06317400932312
# 	 Fidelity: "0.8146" - Complexity: "1"
# Split [6/10]
# 	 Black box accuracy: 0.8596
# 	 Epoch 0: train accuracy: 0.1258
# 	 Epoch 500: train accuracy: 0.9768
# 	 Epoch 1000: train accuracy: 0.9800
# 	 Epoch 1500: train accuracy: 0.9712
# 	 Epoch 2000: train accuracy: 0.9775
# 	 Epoch 2500: train accuracy: 0.9105
# 	 Epoch 3000: train accuracy: 0.9105
# 	 Epoch 3500: train accuracy: 0.9105
# 	 Epoch 4000: train accuracy: 0.9105
# 	 Epoch 4500: train accuracy: 0.9105
# 	 Epoch 5000: train accuracy: 0.9105
# 	 Model's accuracy: 0.9101
# (feature0000000009 & ~feature0000000063)
# 	 Model's accuracy: 0.9101
# 	 Class 1 - Global explanation: "(stroke_flg & ~sapsi_first_LOW)" - Accuracy: 0.8371
# 	 Elapsed time 10.146026372909546
# 	 Fidelity: "0.9101" - Complexity: "2"
# Split [7/10]
# 	 Black box accuracy: 0.8079
# 	 Epoch 0: train accuracy: 0.1238
# 	 Epoch 500: train accuracy: 0.9619
# 	 Epoch 1000: train accuracy: 0.9587
# 	 Epoch 1500: train accuracy: 0.9619
# 	 Epoch 2000: train accuracy: 0.9625
# 	 Epoch 2500: train accuracy: 0.8974
# 	 Epoch 3000: train accuracy: 0.8974
# 	 Epoch 3500: train accuracy: 0.8974
# 	 Epoch 4000: train accuracy: 0.8974
# 	 Epoch 4500: train accuracy: 0.8974
# 	 Epoch 5000: train accuracy: 0.8974
# 	 Model's accuracy: 0.8757
# (feature0000000009)
# 	 Model's accuracy: 0.8757
# 	 Class 1 - Global explanation: "(stroke_flg)" - Accuracy: 0.8192
# 	 Elapsed time 10.174665927886963
# 	 Fidelity: "0.8757" - Complexity: "1"
# Split [8/10]
# 	 Black box accuracy: 0.8701
# 	 Epoch 0: train accuracy: 0.1194
# 	 Epoch 500: train accuracy: 0.9737
# 	 Epoch 1000: train accuracy: 0.9737
# 	 Epoch 1500: train accuracy: 0.9656
# 	 Epoch 2000: train accuracy: 0.9737
# 	 Epoch 2500: train accuracy: 0.8962
# 	 Epoch 3000: train accuracy: 0.8962
# 	 Epoch 3500: train accuracy: 0.8962
# 	 Epoch 4000: train accuracy: 0.8962
# 	 Epoch 4500: train accuracy: 0.8962
# 	 Epoch 5000: train accuracy: 0.8962
# 	 Model's accuracy: 0.9435
# (feature0000000009)
# 	 Model's accuracy: 0.9435
# 	 Class 1 - Global explanation: "(stroke_flg)" - Accuracy: 0.8588
# 	 Elapsed time 10.292563438415527
# 	 Fidelity: "0.9435" - Complexity: "1"
# Split [9/10]
# 	 Black box accuracy: 0.8305
# 	 Epoch 0: train accuracy: 0.1351
# 	 Epoch 500: train accuracy: 0.9750
# 	 Epoch 1000: train accuracy: 0.9787
# 	 Epoch 1500: train accuracy: 0.9787
# 	 Epoch 2000: train accuracy: 0.9762
# 	 Epoch 2500: train accuracy: 0.9043
# 	 Epoch 3000: train accuracy: 0.9043
# 	 Epoch 3500: train accuracy: 0.9043
# 	 Epoch 4000: train accuracy: 0.9043
# 	 Epoch 4500: train accuracy: 0.9043
# 	 Epoch 5000: train accuracy: 0.9043
# 	 Model's accuracy: 0.8814
# (feature0000000009)
# 	 Model's accuracy: 0.8814
# 	 Class 1 - Global explanation: "(stroke_flg)" - Accuracy: 0.8475
# 	 Elapsed time 10.045091390609741
# 	 Fidelity: "0.8814" - Complexity: "1"
# Split [10/10]
# 	 Black box accuracy: 0.8531
# 	 Epoch 0: train accuracy: 0.1420
# 	 Epoch 500: train accuracy: 0.9719
# 	 Epoch 1000: train accuracy: 0.9694
# 	 Epoch 1500: train accuracy: 0.9700
# 	 Epoch 2000: train accuracy: 0.9687
# 	 Epoch 2500: train accuracy: 0.8849
# 	 Epoch 3000: train accuracy: 0.8849
# 	 Epoch 3500: train accuracy: 0.8849
# 	 Epoch 4000: train accuracy: 0.8849
# 	 Epoch 4500: train accuracy: 0.8849
# 	 Epoch 5000: train accuracy: 0.8849
# 	 Model's accuracy: 0.9266
# (feature0000000009)
# 	 Model's accuracy: 0.9266
# 	 Class 1 - Global explanation: "(stroke_flg)" - Accuracy: 0.8814
# 	 Elapsed time 10.057717561721802
# 	 Fidelity: "0.9266" - Complexity: "1"
# Consistency of explanations: 0.4333
#   method  split                      explanation  model_accuracy  \
# 0    psi      0                     (stroke_flg)        0.865169
# 1    psi      1                     (stroke_flg)        0.865169
# 2    psi      2          (stroke_flg & age_HIGH)        0.876404
# 3    psi      3  (stroke_flg & ~sapsi_first_LOW)        0.859551
# 4    psi      4                       (age_HIGH)        0.825843
# 5    psi      5  (stroke_flg & ~sapsi_first_LOW)        0.859551
# 6    psi      6                     (stroke_flg)        0.807910
# 7    psi      7                     (stroke_flg)        0.870056
# 8    psi      8                     (stroke_flg)        0.830508
# 9    psi      9                     (stroke_flg)        0.853107
#
#    explanation_accuracy  explanation_fidelity  explanation_complexity  \
# 0              0.842697              0.921348                       1
# 1              0.825843              0.882022                       1
# 2              0.876404              0.932584                       2
# 3              0.859551              0.943820                       2
# 4              0.741573              0.814607                       1
# 5              0.837079              0.910112                       2
# 6              0.819209              0.875706                       1
# 7              0.858757              0.943503                       1
# 8              0.847458              0.881356                       1
# 9              0.881356              0.926554                       1
#
#    explanation_consistency  elapsed_time
# 0                 0.433333     10.046723
# 1                 0.433333     10.293958
# 2                 0.433333     10.179928
# 3                 0.433333     10.093949
# 4                 0.433333     10.063174
# 5                 0.433333     10.146026
# 6                 0.433333     10.174666
# 7                 0.433333     10.292563
# 8                 0.433333     10.045091
# 9                 0.433333     10.057718

# %% [markdown]
# # Decision tree

# %%
method = 'tree'
need_pruning = False
relu = False
results_tree = c_to_y(method, need_pruning, relu, verbose=True)
results_tree
# Out:
# Split [1/10]
# 	 Black box accuracy: 0.8652
# 	 Model's accuracy: 0.8596
# 	 Class 1 - Global explanation: "(stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & tco2_first_HIGH <= 0.50 & abg_count_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & chloride_first_LOW > 0.50 & hr_1st_LOW > 0.50 & pco2_first_LOW <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & tco2_first_HIGH <= 0.50 & abg_count_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & platelet_first_HIGH <= 0.50 & sofa_first_HIGH <= 0.50 & age_HIGH <= 0.50 & chloride_first_LOW > 0.50 & mal_flg > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & tco2_first_HIGH <= 0.50 & abg_count_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & platelet_first_HIGH <= 0.50 & sofa_first_HIGH <= 0.50 & age_HIGH > 0.50 & tco2_first_LOW > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & tco2_first_HIGH <= 0.50 & abg_count_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & platelet_first_HIGH <= 0.50 & sofa_first_HIGH > 0.50 & po2_first_NORMAL > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & tco2_first_HIGH <= 0.50 & abg_count_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & platelet_first_HIGH > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & tco2_first_HIGH <= 0.50 & abg_count_HIGH > 0.50 & sofa_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & tco2_first_HIGH > 0.50 & age_NORMAL <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL > 0.50 & age_HIGH > 0.50 & chloride_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL > 0.50 & age_HIGH > 0.50 & chloride_first_NORMAL > 0.50 & gender_num <= 0.50 & service_num_HIGH <= 0.50 & creatinine_first_NORMAL <= 0.50 & po2_first_HIGH <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH > 0.50 & age_NORMAL <= 0.50 & service_num_LOW <= 0.50 & mal_flg <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH > 0.50 & age_NORMAL <= 0.50 & service_num_LOW > 0.50 & hr_1st_HIGH > 0.50 & resp_flg <= 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH <= 0.50 & chloride_first_LOW > 0.50 & day_icu_intime_num_HIGH <= 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & pco2_first_LOW <= 0.50 & icu_los_day_LOW > 0.50 & hgb_first_NORMAL > 0.50 & cad_flg <= 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & pco2_first_LOW <= 0.50 & icu_los_day_LOW > 0.50 & hgb_first_NORMAL > 0.50 & cad_flg > 0.50 & hour_icu_intime_HIGH > 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & pco2_first_LOW > 0.50 & hr_1st_HIGH <= 0.50 & abg_count_LOW <= 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & pco2_first_LOW > 0.50 & hr_1st_HIGH <= 0.50 & abg_count_LOW > 0.50 & hgb_first_NORMAL <= 0.50 & hour_icu_intime_NORMAL > 0.50 & po2_first_LOW > 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & pco2_first_LOW > 0.50 & hr_1st_HIGH <= 0.50 & abg_count_LOW > 0.50 & hgb_first_NORMAL > 0.50 & renal_flg <= 0.50 & sapsi_first_LOW <= 0.50 & po2_first_NORMAL <= 0.50 & resp_flg <= 0.50 & day_icu_intime_num_HIGH <= 0.50 & mal_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & hour_icu_intime_NORMAL > 0.50 & aline_flg > 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & pco2_first_LOW > 0.50 & hr_1st_HIGH <= 0.50 & abg_count_LOW > 0.50 & hgb_first_NORMAL > 0.50 & renal_flg <= 0.50 & sapsi_first_LOW <= 0.50 & po2_first_NORMAL <= 0.50 & resp_flg <= 0.50 & day_icu_intime_num_HIGH <= 0.50 & mal_flg <= 0.50 & sapsi_first_HIGH > 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & pco2_first_LOW > 0.50 & hr_1st_HIGH <= 0.50 & abg_count_LOW > 0.50 & hgb_first_NORMAL > 0.50 & renal_flg <= 0.50 & sapsi_first_LOW <= 0.50 & po2_first_NORMAL <= 0.50 & resp ...
# 	 Elapsed time 0.009973526000976562
# 	 Fidelity: "0.9157" - Complexity: "432"
# Split [2/10]
# 	 Black box accuracy: 0.8652
# 	 Model's accuracy: 0.8596
# 	 Class 1 - Global explanation: "(stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & iv_day_1_NORMAL <= 0.50 & sofa_first_HIGH > 0.50 & po2_first_NORMAL > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & iv_day_1_NORMAL > 0.50 & potassium_first_LOW <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH > 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & abg_count_LOW <= 0.50 & potassium_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH > 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & abg_count_LOW > 0.50 & chf_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL > 0.50 & chloride_first_LOW > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH > 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & abg_count_LOW > 0.50 & chf_flg <= 0.50 & sapsi_first_HIGH > 0.50 & service_num_LOW <= 0.50 & day_icu_intime_num_NORMAL <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH > 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & abg_count_LOW > 0.50 & chf_flg > 0.50 & day_icu_intime_num_LOW <= 0.50 & chloride_first_NORMAL <= 0.50 & service_num_HIGH > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH > 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & abg_count_LOW > 0.50 & chf_flg > 0.50 & day_icu_intime_num_LOW > 0.50 & gender_num <= 0.50 & resp_flg <= 0.50 & hour_icu_intime_LOW > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH > 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & abg_count_LOW > 0.50 & chf_flg > 0.50 & day_icu_intime_num_LOW > 0.50 & gender_num <= 0.50 & resp_flg > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH > 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & tco2_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH > 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & tco2_first_NORMAL > 0.50 & day_icu_intime_num_NORMAL > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH > 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & chloride_first_HIGH > 0.50 & hour_icu_intime_LOW > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH > 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH > 0.50 & sofa_first_HIGH > 0.50 & hgb_first_HIGH <= 0.50 & resp_flg <= 0.50 & hr_1st_HIGH > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_HIGH > 0.50 & sofa_first_HIGH > 0.50 & hgb_first_HIGH <= 0.50 & resp_flg > 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & chloride_first_LOW <= 0.50 & po2_first_NORMAL > 0.50 & potassium_first_LOW <= 0.50 & tco2_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & chloride_first_LOW > 0.50 & day_icu_intime_num_HIGH <= 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH > 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & hour_icu_intime_LOW <= 0.50 & sapsi_first_NORMAL <= 0.50 & chloride_first_LOW <= 0.50 & bun_first_LOW <= 0.50 & chloride_first_NORMAL > 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & hour_icu_intime_LOW <= 0.50 & sapsi_first_NORMAL <= 0.50 & chloride_first_LOW > 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & hour_icu_intime_LOW <= 0.50 & sapsi_first_NORMAL > 0.50 & po2_first_NORMAL <= 0.50 & day_icu_intime_num_NORMAL <= 0.50 & resp_flg > 0.50 & tco2_first_NORMAL <= 0.50) | (stroke_flg  ...
# 	 Elapsed time 0.007978677749633789
# 	 Fidelity: "0.9270" - Complexity: "432"
# Split [3/10]
# 	 Black box accuracy: 0.8764
# 	 Model's accuracy: 0.8596
# 	 Class 1 - Global explanation: "(stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL > 0.50 & mal_flg <= 0.50 & afib_flg > 0.50 & platelet_first_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL > 0.50 & mal_flg > 0.50 & renal_flg <= 0.50 & sapsi_first_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH > 0.50 & hr_1st_HIGH > 0.50 & creatinine_first_HIGH <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg <= 0.50 & abg_count_LOW <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg <= 0.50 & abg_count_LOW > 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & chf_flg > 0.50 & mal_flg > 0.50 & day_icu_intime_num_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg <= 0.50 & abg_count_LOW > 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL > 0.50 & day_icu_intime_num_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg <= 0.50 & abg_count_LOW > 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH > 0.50 & service_num_LOW <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg <= 0.50 & abg_count_LOW > 0.50 & bun_first_HIGH > 0.50 & chf_flg <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_NORMAL <= 0.50 & weight_first_NORMAL <= 0.50 & po2_first_LOW <= 0.50 & renal_flg <= 0.50 & bun_first_NORMAL <= 0.50 & sapsi_first_HIGH <= 0.50 & sofa_first_LOW <= 0.50 & cad_flg <= 0.50 & chloride_first_NORMAL <= 0.50 & po2_first_HIGH <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_NORMAL <= 0.50 & weight_first_NORMAL <= 0.50 & po2_first_LOW <= 0.50 & renal_flg <= 0.50 & bun_first_NORMAL <= 0.50 & sapsi_first_HIGH <= 0.50 & sofa_first_LOW <= 0.50 & cad_flg > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_NORMAL <= 0.50 & weight_first_NORMAL <= 0.50 & po2_first_LOW <= 0.50 & renal_flg <= 0.50 & bun_first_NORMAL <= 0.50 & sapsi_first_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_NORMAL <= 0.50 & weight_first_NORMAL <= 0.50 & po2_first_LOW <= 0.50 & renal_flg <= 0.50 & bun_first_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_NORMAL <= 0.50 & weight_first_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_NORMAL > 0.50 & sapsi_first_NORMAL > 0.50 & gender_num > 0.50 & po2_first_HIGH <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & day_icu_intime_num_HIGH > 0.50 & map_1st_NORMAL <= 0.50 & hour_icu_intime_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & day_icu_intime_num_HIGH > 0.50 & map_1st_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg > 0.50 & tco2_first_NORMAL <= 0.50 & po2_first_LOW <= 0.50 & platelet_first_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg > 0.50 & tco2_first_NORMAL ...
# 	 Elapsed time 0.008976936340332031
# 	 Fidelity: "0.9157" - Complexity: "361"
# Split [4/10]
# 	 Black box accuracy: 0.8596
# 	 Model's accuracy: 0.8652
# 	 Class 1 - Global explanation: "(stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH > 0.50 & afib_flg <= 0.50 & icu_los_day_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH > 0.50 & afib_flg > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_LOW > 0.50 & hour_icu_intime_LOW > 0.50 & chf_flg <= 0.50 & tco2_first_NORMAL <= 0.50 & map_1st_LOW <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & hr_1st_LOW > 0.50 & hour_icu_intime_LOW > 0.50 & chf_flg > 0.50 & day_icu_intime_num_HIGH <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg <= 0.50 & chloride_first_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg > 0.50 & tco2_first_NORMAL <= 0.50 & hr_1st_LOW <= 0.50 & aline_flg > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg > 0.50 & tco2_first_NORMAL > 0.50 & bun_first_NORMAL <= 0.50 & service_num_LOW <= 0.50 & gender_num <= 0.50 & platelet_first_LOW > 0.50 & cad_flg <= 0.50 & sofa_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg > 0.50 & tco2_first_NORMAL > 0.50 & bun_first_NORMAL <= 0.50 & service_num_LOW <= 0.50 & gender_num <= 0.50 & platelet_first_LOW > 0.50 & cad_flg <= 0.50 & sofa_first_NORMAL > 0.50 & day_icu_intime_num_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg > 0.50 & tco2_first_NORMAL > 0.50 & bun_first_NORMAL <= 0.50 & service_num_LOW <= 0.50 & gender_num <= 0.50 & platelet_first_LOW > 0.50 & cad_flg <= 0.50 & sofa_first_NORMAL > 0.50 & day_icu_intime_num_NORMAL > 0.50 & mal_flg > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg > 0.50 & tco2_first_NORMAL > 0.50 & bun_first_NORMAL <= 0.50 & service_num_LOW > 0.50 & day_icu_intime_num_LOW > 0.50 & hour_icu_intime_HIGH <= 0.50 & hgb_first_NORMAL > 0.50 & sofa_first_LOW <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg > 0.50 & tco2_first_NORMAL > 0.50 & bun_first_NORMAL > 0.50 & day_icu_intime_num_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH > 0.50 & service_num_LOW <= 0.50 & day_icu_intime_num_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & bun_first_HIGH > 0.50 & day_icu_intime_num_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & tco2_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & so ...
# 	 Elapsed time 0.006981372833251953
# 	 Fidelity: "0.9494" - Complexity: "418"
# Split [5/10]
# 	 Black box accuracy: 0.8258
# 	 Model's accuracy: 0.8596
# 	 Class 1 - Global explanation: "(stroke_flg <= 0.50 & age_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg <= 0.50 & mal_flg > 0.50 & hour_icu_intime_NORMAL > 0.50 & aline_flg <= 0.50 & hr_1st_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg > 0.50 & resp_flg > 0.50 & map_1st_LOW <= 0.50 & service_num_LOW <= 0.50 & hour_icu_intime_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & afib_flg > 0.50 & resp_flg > 0.50 & map_1st_LOW > 0.50 & day_icu_intime_num_HIGH <= 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & sapsi_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & map_1st_LOW <= 0.50 & mal_flg > 0.50 & tco2_first_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & sapsi_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & map_1st_LOW > 0.50 & chloride_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & sapsi_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & map_1st_LOW > 0.50 & chloride_first_NORMAL > 0.50 & day_icu_intime_num_HIGH > 0.50 & sofa_first_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & sapsi_first_HIGH <= 0.50 & platelet_first_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & sapsi_first_HIGH > 0.50 & day_icu_intime_num_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & sapsi_first_HIGH <= 0.50 & pco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & sodium_first_LOW <= 0.50 & chf_flg > 0.50 & hr_1st_LOW > 0.50 & hgb_first_HIGH <= 0.50 & platelet_first_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & sapsi_first_HIGH <= 0.50 & pco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & sodium_first_LOW > 0.50 & day_icu_intime_num_LOW > 0.50 & hour_icu_intime_HIGH <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & sapsi_first_HIGH <= 0.50 & pco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg <= 0.50 & chloride_first_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & sapsi_first_HIGH <= 0.50 & pco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg > 0.50 & mal_flg <= 0.50 & chloride_first_LOW <= 0.50 & day_icu_intime_num_LOW <= 0.50 & map_1st_LOW > 0.50 & service_num_LOW <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & sapsi_first_HIGH <= 0.50 & pco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg > 0.50 & mal_flg <= 0.50 & chloride_first_LOW <= 0.50 & day_icu_intime_num_LOW > 0.50 & copd_flg <= 0.50 & po2_first_NORMAL > 0.50 & hour_icu_intime_HIGH <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & sapsi_first_HIGH <= 0.50 & pco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg > 0.50 & mal_flg <= 0.50 & chloride_first_LOW <= 0.50 & day_icu_intime_num_LOW > 0.50 & copd_flg > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & sapsi_first_HIGH <= 0.50 & pco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg > 0.50 & mal_flg <= 0.50 & chloride_first_LOW > 0.50 & gender_num <= 0.50 & hour_icu_intime_LOW <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & sapsi_first_HIGH <= 0.50 & pco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg > 0.50 & mal_flg > 0.50 & tco2_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & sapsi_first_HIGH <= 0.50 & pco2_first_HIGH <= 0.50 & h ...
# 	 Elapsed time 0.008975505828857422
# 	 Fidelity: "0.9326" - Complexity: "513"
# Split [6/10]
# 	 Black box accuracy: 0.8596
# 	 Model's accuracy: 0.8596
# 	 Class 1 - Global explanation: "(stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & chloride_first_NORMAL <= 0.50 & iv_day_1_LOW <= 0.50 & hr_1st_NORMAL <= 0.50 & hour_icu_intime_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & chloride_first_NORMAL <= 0.50 & iv_day_1_LOW > 0.50 & afib_flg > 0.50 & day_icu_intime_num_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & chloride_first_NORMAL > 0.50 & sofa_first_HIGH <= 0.50 & afib_flg <= 0.50 & hr_1st_HIGH > 0.50 & mal_flg > 0.50 & tco2_first_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & chloride_first_NORMAL > 0.50 & sofa_first_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_NORMAL > 0.50 & tco2_first_NORMAL <= 0.50 & copd_flg <= 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & chloride_first_NORMAL > 0.50 & sofa_first_HIGH > 0.50 & hr_1st_HIGH > 0.50 & resp_flg > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & platelet_first_HIGH > 0.50 & potassium_first_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH > 0.50 & hr_1st_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & sodium_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & bun_first_LOW <= 0.50 & resp_flg > 0.50 & day_icu_intime_num_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & sodium_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg <= 0.50 & hr_1st_HIGH <= 0.50 & chf_flg > 0.50 & mal_flg > 0.50 & day_icu_intime_num_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & sodium_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg <= 0.50 & hr_1st_HIGH > 0.50 & tco2_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & sodium_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg > 0.50 & day_icu_intime_num_HIGH <= 0.50 & hgb_first_NORMAL > 0.50 & hr_1st_HIGH <= 0.50 & platelet_first_LOW > 0.50 & chloride_first_LOW <= 0.50 & sofa_first_NORMAL > 0.50 & tco2_first_LOW <= 0.50 & day_icu_intime_num_NORMAL <= 0.50 & service_num_LOW > 0.50 & hour_icu_intime_HIGH <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & sodium_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg > 0.50 & day_icu_intime_num_HIGH <= 0.50 & hgb_first_NORMAL > 0.50 & hr_1st_HIGH <= 0.50 & platelet_first_LOW > 0.50 & chloride_first_LOW <= 0.50 & sofa_first_NORMAL > 0.50 & tco2_first_LOW <= 0.50 & day_icu_intime_num_NORMAL > 0.50 & mal_flg > 0.50 & cad_flg <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & sodium_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg > 0.50 & day_icu_intime_num_HIGH <= 0.50 & hgb_first_NORMAL > 0.50 & hr_1st_HIGH <= 0.50 & platelet_first_LOW > 0.50 & chloride_first_LOW <= 0.50 & sofa_first_NORMAL > 0.50 & tco2_first_LOW > 0.50 & aline_flg > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & sodium_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & resp_flg > 0.50 & day_icu_intime_num_HIGH <= 0.50 & hgb_first_NORMAL > 0.50 & hr_1st_HIGH <= 0.50 & platelet_first_LOW > 0.50 & chloride_first_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & sodium_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & bun_first_LOW >  ...
# 	 Elapsed time 0.010000944137573242
# 	 Fidelity: "0.9438" - Complexity: "505"
# Split [7/10]
# 	 Black box accuracy: 0.8079
# 	 Model's accuracy: 0.8079
# 	 Class 1 - Global explanation: "(stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_NORMAL <= 0.50 & chloride_first_LOW > 0.50 & map_1st_NORMAL <= 0.50 & tco2_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_NORMAL > 0.50 & cad_flg > 0.50 & sodium_first_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH > 0.50 & hour_icu_intime_NORMAL > 0.50 & resp_flg > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg > 0.50 & resp_flg > 0.50 & chloride_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg > 0.50 & resp_flg > 0.50 & chloride_first_NORMAL > 0.50 & day_icu_intime_num_NORMAL > 0.50 & gender_num > 0.50 & age_LOW <= 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH > 0.50 & hr_1st_HIGH > 0.50 & day_icu_intime_num_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & afib_flg <= 0.50 & pco2_first_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & service_num_HIGH <= 0.50 & sodium_first_HIGH <= 0.50 & mal_flg > 0.50 & tco2_first_LOW <= 0.50 & hgb_first_HIGH > 0.50 & aline_flg > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & afib_flg <= 0.50 & pco2_first_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & service_num_HIGH <= 0.50 & sodium_first_HIGH <= 0.50 & mal_flg > 0.50 & tco2_first_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & afib_flg <= 0.50 & pco2_first_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & service_num_HIGH <= 0.50 & sodium_first_HIGH > 0.50 & day_icu_intime_num_LOW <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & afib_flg <= 0.50 & pco2_first_HIGH <= 0.50 & bun_first_HIGH <= 0.50 & sapsi_first_HIGH > 0.50 & hr_1st_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & afib_flg <= 0.50 & pco2_first_HIGH <= 0.50 & bun_first_HIGH > 0.50 & day_icu_intime_num_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & afib_flg <= 0.50 & pco2_first_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_NORMAL <= 0.50 & aline_flg <= 0.50 & chf_flg <= 0.50 & hour_icu_intime_LOW <= 0.50 & day_icu_intime_num_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_NORMAL <= 0.50 & aline_flg <= 0.50 & chf_flg <= 0.50 & hour_icu_intime_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_NORMAL <= 0.50 & aline_flg > 0.50 & hr_1st_LOW > 0.50 & po2_first_HIGH <= 0.50 & chloride_first_LOW > 0.50 & platelet_first_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_NORMAL <= 0.50 & aline_flg > 0.50 & hr_1st_LOW > 0.50 & po2_first_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_NORMAL > 0.50 & gender_num > 0.50 & po2_first_HIGH <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg <= 0.50 & chloride_first_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg > 0.50 & tco2_first_NORMAL <= 0.50 & hr_1st_LOW <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg > 0.50 & tco2_first_NORMAL <= 0.50 & hr_1st_LOW > 0.50 & pco2_first_NORMAL > 0.50 & cad_flg > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & resp_flg > 0.50 & tc ...
# 	 Elapsed time 0.008975744247436523
# 	 Fidelity: "0.9209" - Complexity: "477"
# Split [8/10]
# 	 Black box accuracy: 0.8701
# 	 Model's accuracy: 0.8814
# 	 Class 1 - Global explanation: "(stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_LOW <= 0.50 & age_NORMAL <= 0.50 & sofa_first_LOW <= 0.50 & creatinine_first_NORMAL <= 0.50 & sapsi_first_LOW <= 0.50 & chloride_first_HIGH <= 0.50 & resp_flg <= 0.50 & po2_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_LOW <= 0.50 & age_NORMAL <= 0.50 & sofa_first_LOW <= 0.50 & creatinine_first_NORMAL <= 0.50 & sapsi_first_LOW <= 0.50 & chloride_first_HIGH <= 0.50 & resp_flg > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & tco2_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & sofa_first_HIGH <= 0.50 & age_HIGH > 0.50 & hr_1st_HIGH <= 0.50 & mal_flg > 0.50 & resp_flg > 0.50 & tco2_first_LOW <= 0.50 & hr_1st_NORMAL <= 0.50 & gender_num <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & tco2_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & sofa_first_HIGH <= 0.50 & age_HIGH > 0.50 & hr_1st_HIGH <= 0.50 & mal_flg > 0.50 & resp_flg > 0.50 & tco2_first_LOW > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & tco2_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & sofa_first_HIGH <= 0.50 & age_HIGH > 0.50 & hr_1st_HIGH > 0.50 & tco2_first_LOW <= 0.50 & day_icu_intime_num_NORMAL > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & tco2_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & sofa_first_HIGH <= 0.50 & age_HIGH > 0.50 & hr_1st_HIGH > 0.50 & tco2_first_LOW > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & tco2_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & sofa_first_HIGH > 0.50 & chf_flg <= 0.50 & map_1st_LOW > 0.50 & day_icu_intime_num_NORMAL <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & tco2_first_HIGH <= 0.50 & platelet_first_HIGH <= 0.50 & sofa_first_HIGH > 0.50 & chf_flg > 0.50 & hr_1st_LOW <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & tco2_first_HIGH <= 0.50 & platelet_first_HIGH > 0.50 & potassium_first_LOW <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & tco2_first_HIGH > 0.50 & age_NORMAL <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH > 0.50 & icu_los_day_NORMAL <= 0.50 & age_NORMAL <= 0.50 & resp_flg <= 0.50 & po2_first_HIGH <= 0.50 & hr_1st_NORMAL <= 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH > 0.50 & icu_los_day_NORMAL <= 0.50 & age_NORMAL <= 0.50 & resp_flg <= 0.50 & po2_first_HIGH <= 0.50 & hr_1st_NORMAL > 0.50 & day_icu_intime_num_LOW > 0.50) | (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi_first_HIGH > 0.50 & icu_los_day_NORMAL > 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & bun_first_NORMAL > 0.50 & day_icu_intime_num_NORMAL > 0.50 & cad_flg <= 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH > 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & sofa_first_LOW <= 0.50 & po2_first_HIGH <= 0.50 & mal_flg <= 0.50 & hour_icu_intime_LOW <= 0.50 & sapsi_first_NORMAL <= 0.50 & service_num_LOW > 0.50 & hr_1st_NORMAL <= 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & sofa_first_LOW <= 0.50 & po2_first_HIGH <= 0.50 & mal_flg <= 0.50 & hour_icu_intime_LOW <= 0.50 & sapsi_first_NORMAL > 0.50 & sodium_first_NORMAL > 0.50 & copd_flg <= 0.50 & hr_1st_LOW <= 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50 & sofa_first_LOW <= 0.50 & po2_first_HIGH <= 0.50 & mal_flg <= 0.50 & hour_icu_intime_LOW <= 0.50 & sapsi_first_NORMAL > 0.50 & sodium_first_NORMAL > 0.50 & copd_flg <= 0.50 & hr_1st_LOW > 0.50 & gender_num > 0.50) | (stroke_flg <= 0.50 & afib_flg > 0.50 & age_HIGH > 0.50  ...
# 	 Elapsed time 0.008985280990600586
# 	 Fidelity: "0.9435" - Complexity: "370"
# Split [9/10]
# 	 Black box accuracy: 0.8305
# 	 Model's accuracy: 0.8588
# 	 Class 1 - Global explanation: "(stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & mal_flg > 0.50 & hour_icu_intime_NORMAL > 0.50 & hr_1st_LOW > 0.50 & aline_flg <= 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg <= 0.50 & sofa_first_HIGH > 0.50 & day_icu_intime_num_HIGH > 0.50 & map_1st_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg > 0.50 & bun_first_LOW <= 0.50 & day_icu_intime_num_NORMAL > 0.50 & sodium_first_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg > 0.50 & bun_first_LOW > 0.50 & day_icu_intime_num_LOW > 0.50 & chloride_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi_first_HIGH > 0.50 & hr_1st_HIGH > 0.50 & hour_icu_intime_LOW <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_LOW <= 0.50 & renal_flg <= 0.50 & day_icu_intime_num_NORMAL <= 0.50 & service_num_HIGH <= 0.50 & hr_1st_LOW <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_LOW <= 0.50 & renal_flg <= 0.50 & day_icu_intime_num_NORMAL <= 0.50 & service_num_HIGH <= 0.50 & hr_1st_LOW > 0.50 & bun_first_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_LOW <= 0.50 & renal_flg <= 0.50 & day_icu_intime_num_NORMAL > 0.50 & potassium_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg <= 0.50 & chloride_first_HIGH <= 0.50 & chf_flg > 0.50 & mal_flg > 0.50 & day_icu_intime_num_LOW > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg <= 0.50 & chloride_first_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg > 0.50 & iv_day_1_NORMAL <= 0.50 & tco2_first_NORMAL <= 0.50 & hr_1st_LOW <= 0.50 & aline_flg > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg > 0.50 & iv_day_1_NORMAL <= 0.50 & tco2_first_NORMAL > 0.50 & day_icu_intime_num_LOW <= 0.50 & chloride_first_LOW > 0.50 & service_num_HIGH > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg > 0.50 & iv_day_1_NORMAL <= 0.50 & tco2_first_NORMAL > 0.50 & day_icu_intime_num_LOW > 0.50 & hour_icu_intime_HIGH <= 0.50 & copd_flg <= 0.50 & po2_first_NORMAL > 0.50 & pco2_first_NORMAL <= 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg > 0.50 & iv_day_1_NORMAL <= 0.50 & tco2_first_NORMAL > 0.50 & day_icu_intime_num_LOW > 0.50 & hour_icu_intime_HIGH <= 0.50 & copd_flg > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH <= 0.50 & resp_flg > 0.50 & iv_day_1_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_HIGH <= 0.50 & hr_1st_HIGH > 0.50 & tco2_first_LOW <= 0.50 & day_icu_intime_num_NORMAL > 0.50) | (stroke_flg <= 0.50 & age_HIGH > 0.50 & afib_flg <= 0.50 & sofa_first_HIGH <= 0.50 & bun_first_LOW > 0.50 & sa ...
# 	 Elapsed time 0.00897669792175293
# 	 Fidelity: "0.9040" - Complexity: "413"
# Split [10/10]
# 	 Black box accuracy: 0.8531
# 	 Model's accuracy: 0.8418
# 	 Class 1 - Global explanation: "(age_HIGH <= 0.50 & stroke_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg <= 0.50 & iv_day_1_NORMAL <= 0.50 & sofa_first_HIGH > 0.50 & map_1st_LOW > 0.50 & hr_1st_HIGH > 0.50) | (age_HIGH <= 0.50 & stroke_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg <= 0.50 & iv_day_1_NORMAL > 0.50 & hr_1st_LOW <= 0.50 & hr_1st_HIGH > 0.50 & potassium_first_NORMAL > 0.50) | (age_HIGH <= 0.50 & stroke_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg <= 0.50 & iv_day_1_NORMAL > 0.50 & hr_1st_LOW > 0.50 & platelet_first_NORMAL <= 0.50) | (age_HIGH <= 0.50 & stroke_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg > 0.50 & resp_flg > 0.50 & chloride_first_NORMAL <= 0.50 & day_icu_intime_num_HIGH <= 0.50) | (age_HIGH <= 0.50 & stroke_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg > 0.50 & resp_flg > 0.50 & chloride_first_NORMAL > 0.50 & day_icu_intime_num_NORMAL > 0.50 & bun_first_LOW <= 0.50) | (age_HIGH <= 0.50 & stroke_flg <= 0.50 & sapsi_first_HIGH <= 0.50 & afib_flg > 0.50 & resp_flg > 0.50 & chloride_first_NORMAL > 0.50 & day_icu_intime_num_NORMAL > 0.50 & bun_first_LOW > 0.50 & service_num_LOW <= 0.50) | (age_HIGH <= 0.50 & stroke_flg <= 0.50 & sapsi_first_HIGH > 0.50 & hr_1st_HIGH > 0.50 & tco2_first_NORMAL <= 0.50) | (age_HIGH <= 0.50 & stroke_flg > 0.50 & hgb_first_NORMAL <= 0.50 & bun_first_LOW <= 0.50 & day_icu_intime_num_LOW <= 0.50) | (age_HIGH <= 0.50 & stroke_flg > 0.50 & hgb_first_NORMAL <= 0.50 & bun_first_LOW > 0.50 & sofa_first_HIGH <= 0.50 & afib_flg <= 0.50 & resp_flg > 0.50 & hour_icu_intime_LOW > 0.50 & service_num_LOW <= 0.50) | (age_HIGH <= 0.50 & stroke_flg > 0.50 & hgb_first_NORMAL <= 0.50 & bun_first_LOW > 0.50 & sofa_first_HIGH <= 0.50 & afib_flg > 0.50 & hour_icu_intime_HIGH > 0.50) | (age_HIGH <= 0.50 & stroke_flg > 0.50 & hgb_first_NORMAL <= 0.50 & bun_first_LOW > 0.50 & sofa_first_HIGH > 0.50) | (age_HIGH <= 0.50 & stroke_flg > 0.50 & hgb_first_NORMAL > 0.50 & hour_icu_intime_NORMAL <= 0.50 & service_num_LOW <= 0.50 & iv_day_1_LOW <= 0.50) | (age_HIGH <= 0.50 & stroke_flg > 0.50 & hgb_first_NORMAL > 0.50 & hour_icu_intime_NORMAL <= 0.50 & service_num_LOW <= 0.50 & iv_day_1_LOW > 0.50 & resp_flg > 0.50 & sofa_first_LOW <= 0.50) | (age_HIGH <= 0.50 & stroke_flg > 0.50 & hgb_first_NORMAL > 0.50 & hour_icu_intime_NORMAL <= 0.50 & service_num_LOW > 0.50 & cad_flg <= 0.50) | (age_HIGH <= 0.50 & stroke_flg > 0.50 & hgb_first_NORMAL > 0.50 & hour_icu_intime_NORMAL > 0.50) | (age_HIGH > 0.50 & stroke_flg <= 0.50 & afib_flg <= 0.50 & bun_first_LOW <= 0.50 & po2_first_LOW <= 0.50 & platelet_first_NORMAL > 0.50) | (age_HIGH > 0.50 & stroke_flg <= 0.50 & afib_flg <= 0.50 & bun_first_LOW <= 0.50 & po2_first_LOW > 0.50 & day_icu_intime_num_HIGH <= 0.50 & sodium_first_NORMAL <= 0.50) | (age_HIGH > 0.50 & stroke_flg <= 0.50 & afib_flg <= 0.50 & bun_first_LOW <= 0.50 & po2_first_LOW > 0.50 & day_icu_intime_num_HIGH > 0.50) | (age_HIGH > 0.50 & stroke_flg <= 0.50 & afib_flg <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_NORMAL <= 0.50 & resp_flg <= 0.50 & hr_1st_HIGH <= 0.50 & tco2_first_HIGH > 0.50) | (age_HIGH > 0.50 & stroke_flg <= 0.50 & afib_flg <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_NORMAL <= 0.50 & resp_flg <= 0.50 & hr_1st_HIGH > 0.50) | (age_HIGH > 0.50 & stroke_flg <= 0.50 & afib_flg <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_NORMAL <= 0.50 & resp_flg > 0.50 & po2_first_LOW > 0.50 & icu_los_day_NORMAL <= 0.50 & potassium_first_NORMAL <= 0.50) | (age_HIGH > 0.50 & stroke_flg <= 0.50 & afib_flg <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_NORMAL <= 0.50 & resp_flg > 0.50 & po2_first_LOW > 0.50 & icu_los_day_NORMAL <= 0.50 & potassium_first_NORMAL > 0.50 & copd_flg <= 0.50) | (age_HIGH > 0.50 & stroke_flg <= 0.50 & afib_flg <= 0.50 & bun_first_LOW > 0.50 & sapsi_first_HIGH <= 0.50 & tco2_first_NORMAL > 0.50 & chloride_first_NORMAL <= 0.50 & aline_flg <= 0.50 & chloride_first ...
# 	 Elapsed time 0.008975982666015625
# 	 Fidelity: "0.9548" - Complexity: "400"
# Consistency of explanations: 0.6036
#   method  split                                        explanation  \
# 0   tree      0  (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi...
# 1   tree      1  (stroke_flg <= 0.50 & afib_flg <= 0.50 & age_H...
# 2   tree      2  (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi...
# 3   tree      3  (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi...
# 4   tree      4  (stroke_flg <= 0.50 & age_HIGH <= 0.50 & hr_1s...
# 5   tree      5  (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi...
# 6   tree      6  (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi...
# 7   tree      7  (stroke_flg <= 0.50 & afib_flg <= 0.50 & sapsi...
# 8   tree      8  (stroke_flg <= 0.50 & age_HIGH <= 0.50 & sapsi...
# 9   tree      9  (age_HIGH <= 0.50 & stroke_flg <= 0.50 & sapsi...
#
#    model_accuracy  explanation_accuracy  explanation_fidelity  \
# 0        0.865169              0.859551              0.915730
# 1        0.865169              0.859551              0.926966
# 2        0.876404              0.859551              0.915730
# 3        0.859551              0.865169              0.949438
# 4        0.825843              0.859551              0.932584
# 5        0.859551              0.859551              0.943820
# 6        0.807910              0.807910              0.920904
# 7        0.870056              0.881356              0.943503
# 8        0.830508              0.858757              0.903955
# 9        0.853107              0.841808              0.954802
#
#    explanation_complexity  explanation_consistency  elapsed_time
# 0                     432                 0.603597      0.009974
# 1                     432                 0.603597      0.007979
# 2                     361                 0.603597      0.008977
# 3                     418                 0.603597      0.006981
# 4                     513                 0.603597      0.008976
# 5                     505                 0.603597      0.010001
# 6                     477                 0.603597      0.008976
# 7                     370                 0.603597      0.008985
# 8                     413                 0.603597      0.008977
# 9                     400                 0.603597      0.008976

# %%
method = 'tree-3'
need_pruning = False
relu = False
results_tree = c_to_y(method, need_pruning, relu, verbose=True)
results_tree
# Out:
# Split [1/10]
# 	 Black box accuracy: 0.8652
# 	 Model's accuracy: 0.8596
# 	 Class 1 - Global explanation: "(stroke_flg > 0.50 & age_HIGH > 0.50 & sapsi_first_LOW <= 0.50)" - Accuracy: 0.8596
# 	 Elapsed time 0.004986763000488281
# 	 Fidelity: "0.9494" - Complexity: "3"
# Split [2/10]
# 	 Black box accuracy: 0.8652
# 	 Model's accuracy: 0.8764
# 	 Class 1 - Global explanation: "(stroke_flg > 0.50 & age_HIGH > 0.50 & weight_first_LOW > 0.50)" - Accuracy: 0.8764
# 	 Elapsed time 0.00594639778137207
# 	 Fidelity: "0.9326" - Complexity: "3"
# Split [3/10]
# 	 Black box accuracy: 0.8764
# 	 Model's accuracy: 0.8764
# 	 Class 1 - Global explanation: "(stroke_flg > 0.50 & age_HIGH <= 0.50 & bun_first_LOW <= 0.50) | (stroke_flg > 0.50 & age_HIGH > 0.50 & sapsi_first_LOW <= 0.50)" - Accuracy: 0.8764
# 	 Elapsed time 0.007995367050170898
# 	 Fidelity: "0.9326" - Complexity: "6"
# Split [4/10]
# 	 Black box accuracy: 0.8596
# 	 Model's accuracy: 0.8652
# 	 Class 1 - Global explanation: "(stroke_flg > 0.50 & age_HIGH > 0.50 & sapsi_first_LOW <= 0.50)" - Accuracy: 0.8652
# 	 Elapsed time 0.0049915313720703125
# 	 Fidelity: "0.9607" - Complexity: "3"
# Split [5/10]
# 	 Black box accuracy: 0.8258
# 	 Model's accuracy: 0.8596
# 	 Class 1 - Global explanation: "(stroke_flg > 0.50 & age_HIGH > 0.50 & po2_first_HIGH <= 0.50) | (stroke_flg > 0.50 & age_HIGH > 0.50 & po2_first_HIGH > 0.50)" - Accuracy: 0.8596
# 	 Elapsed time 0.006981849670410156
# 	 Fidelity: "0.9438" - Complexity: "6"
# Split [6/10]
# 	 Black box accuracy: 0.8596
# 	 Model's accuracy: 0.8652
# 	 Class 1 - Global explanation: "(stroke_flg <= 0.50 & age_HIGH > 0.50 & sodium_first_HIGH > 0.50) | (stroke_flg > 0.50 & age_HIGH > 0.50 & sapsi_first_LOW <= 0.50)" - Accuracy: 0.8652
# 	 Elapsed time 0.005983591079711914
# 	 Fidelity: "0.9494" - Complexity: "6"
# Split [7/10]
# 	 Black box accuracy: 0.8079
# 	 Model's accuracy: 0.8418
# 	 Class 1 - Global explanation: "(stroke_flg > 0.50 & age_HIGH > 0.50 & sapsi_first_LOW <= 0.50)" - Accuracy: 0.8418
# 	 Elapsed time 0.006984233856201172
# 	 Fidelity: "0.9209" - Complexity: "3"
# Split [8/10]
# 	 Black box accuracy: 0.8701
# 	 Model's accuracy: 0.8701
# 	 Class 1 - Global explanation: "(stroke_flg > 0.50 & age_HIGH <= 0.50 & liver_flg > 0.50) | (stroke_flg > 0.50 & age_HIGH > 0.50 & platelet_first_NORMAL <= 0.50) | (stroke_flg > 0.50 & age_HIGH > 0.50 & platelet_first_NORMAL > 0.50)" - Accuracy: 0.8701
# 	 Elapsed time 0.005995035171508789
# 	 Fidelity: "0.9774" - Complexity: "9"
# Split [9/10]
# 	 Black box accuracy: 0.8305
# 	 Model's accuracy: 0.8870
# 	 Class 1 - Global explanation: "(stroke_flg > 0.50 & age_HIGH > 0.50 & sapsi_first_LOW <= 0.50)" - Accuracy: 0.8870
# 	 Elapsed time 0.005983114242553711
# 	 Fidelity: "0.9209" - Complexity: "3"
# Split [10/10]
# 	 Black box accuracy: 0.8531
# 	 Model's accuracy: 0.8701
# 	 Class 1 - Global explanation: "(age_HIGH > 0.50 & stroke_flg <= 0.50 & afib_flg > 0.50) | (age_HIGH > 0.50 & stroke_flg > 0.50 & sapsi_first_LOW <= 0.50)" - Accuracy: 0.8701
# 	 Elapsed time 0.005975246429443359
# 	 Fidelity: "0.9605" - Complexity: "6"
# Consistency of explanations: 0.2857
#    method  split                                        explanation  \
# 0  tree-3      0  (stroke_flg > 0.50 & age_HIGH > 0.50 & sapsi_f...
# 1  tree-3      1  (stroke_flg > 0.50 & age_HIGH > 0.50 & weight_...
# 2  tree-3      2  (stroke_flg > 0.50 & age_HIGH <= 0.50 & bun_fi...
# 3  tree-3      3  (stroke_flg > 0.50 & age_HIGH > 0.50 & sapsi_f...
# 4  tree-3      4  (stroke_flg > 0.50 & age_HIGH > 0.50 & po2_fir...
# 5  tree-3      5  (stroke_flg <= 0.50 & age_HIGH > 0.50 & sodium...
# 6  tree-3      6  (stroke_flg > 0.50 & age_HIGH > 0.50 & sapsi_f...
# 7  tree-3      7  (stroke_flg > 0.50 & age_HIGH <= 0.50 & liver_...
# 8  tree-3      8  (stroke_flg > 0.50 & age_HIGH > 0.50 & sapsi_f...
# 9  tree-3      9  (age_HIGH > 0.50 & stroke_flg <= 0.50 & afib_f...
#
#    model_accuracy  explanation_accuracy  explanation_fidelity  \
# 0        0.865169              0.859551              0.949438
# 1        0.865169              0.876404              0.932584
# 2        0.876404              0.876404              0.932584
# 3        0.859551              0.865169              0.960674
# 4        0.825843              0.859551              0.943820
# 5        0.859551              0.865169              0.949438
# 6        0.807910              0.841808              0.920904
# 7        0.870056              0.870056              0.977401
# 8        0.830508              0.887006              0.920904
# 9        0.853107              0.870056              0.960452
#
#    explanation_complexity  explanation_consistency  elapsed_time
# 0                       3                 0.285714      0.004987
# 1                       3                 0.285714      0.005946
# 2                       6                 0.285714      0.007995
# 3                       3                 0.285714      0.004992
# 4                       6                 0.285714      0.006982
# 5                       6                 0.285714      0.005984
# 6                       3                 0.285714      0.006984
# 7                       9                 0.285714      0.005995
# 8                       3                 0.285714      0.005983
# 9                       6                 0.285714      0.005975

# %% [markdown]
# # BRL

# %%
method = 'brl'
need_pruning = False
relu = False
results_brl = c_to_y(method, need_pruning, relu, verbose=True)
results_brl
# Out:
# Split [1/10]
# 	 Black box accuracy: 0.8652
# Labels (1598, 1)
# Discretized features
# Completed model 1/1!
# Train_acc: 0.9, Val_acc: 0.0
# 	 Model's accuracy: 0.8596
# 	 Class 1 - Global explanation: "(stroke_flg & age_HIGH & sodium_first_HIGH) | (stroke_flg & age_HIGH & ~sapsi_first_LOW) | (stroke_flg & sodium_first_HIGH & ~hgb_first_HIGH) | (stroke_flg & ~hgb_first_HIGH & ~sapsi_first_LOW)" - Accuracy: 0.8652
# 	 Elapsed time 551.2550559043884
# 	 Fidelity: "0.9326" - Complexity: "12"
# Split [2/10]
# 	 Black box accuracy: 0.8652
# Labels (1598, 1)
# Discretized features
# Completed model 1/1!
# Train_acc: 0.9, Val_acc: 0.0
# 	 Model's accuracy: 0.8652
# 	 Class 1 - Global explanation: "(stroke_flg & age_HIGH & wbc_first_HIGH & ~sapsi_first_LOW) | (stroke_flg & age_HIGH & weight_first_LOW & ~sapsi_first_LOW) | (stroke_flg & wbc_first_HIGH & ~hgb_first_HIGH & ~sapsi_first_LOW) | (stroke_flg & weight_first_LOW & ~hgb_first_HIGH & ~sapsi_first_LOW)" - Accuracy: 0.8652
# 	 Elapsed time 550.8910205364227
# 	 Fidelity: "0.9326" - Complexity: "16"
# Split [3/10]
# 	 Black box accuracy: 0.8764
# Labels (1598, 1)
# Discretized features
# Completed model 1/1!
# Train_acc: 0.9, Val_acc: 0.0
# 	 Model's accuracy: 0.8764
# 	 Class 1 - Global explanation: "(renal_flg & stroke_flg & ~abg_count_LOW) | (renal_flg & stroke_flg & ~sapsi_first_LOW) | (stroke_flg & age_HIGH & ~abg_count_LOW) | (stroke_flg & age_HIGH & ~sapsi_first_LOW) | (resp_flg & age_HIGH & bun_first_NORMAL & ~abg_count_LOW) | (resp_flg & age_HIGH & bun_first_NORMAL & ~sapsi_first_LOW) | (resp_flg & age_HIGH & ~abg_count_LOW & ~tco2_first_NORMAL) | (resp_flg & age_HIGH & ~sapsi_first_LOW & ~tco2_first_NORMAL)" - Accuracy: 0.8764
# 	 Elapsed time 545.3257713317871
# 	 Fidelity: "0.9326" - Complexity: "28"
# Split [4/10]
# 	 Black box accuracy: 0.8596
# Labels (1598, 1)
# Discretized features
# Completed model 1/1!
# Train_acc: 0.9, Val_acc: 0.0
# 	 Model's accuracy: 0.8652
# 	 Class 1 - Global explanation: "(stroke_flg & age_HIGH & weight_first_LOW & ~sapsi_first_LOW) | (stroke_flg & platelet_first_HIGH & weight_first_LOW & ~sapsi_first_LOW)" - Accuracy: 0.8652
# 	 Elapsed time 526.0278358459473
# 	 Fidelity: "0.9607" - Complexity: "8"
# Split [5/10]
# 	 Black box accuracy: 0.8258
# Labels (1598, 1)
# Discretized features
# Completed model 1/1!
# Train_acc: 0.9, Val_acc: 0.0
# 	 Model's accuracy: 0.8539
# 	 Class 1 - Global explanation: "(stroke_flg & hgb_first_NORMAL & ~sapsi_first_LOW) | (resp_flg & age_HIGH & bun_first_NORMAL & ~sapsi_first_LOW) | (stroke_flg & age_HIGH & ~creatinine_first_NORMAL & ~sapsi_first_LOW) | (resp_flg & age_HIGH & ~sapsi_first_LOW & ~tco2_first_NORMAL)" - Accuracy: 0.8539
# 	 Elapsed time 540.5768389701843
# 	 Fidelity: "0.9494" - Complexity: "15"
# Split [6/10]
# 	 Black box accuracy: 0.8596
# Labels (1598, 1)
# Discretized features
# Completed model 1/1!
# Train_acc: 0.9, Val_acc: 0.0
# 	 Model's accuracy: 0.8652
# 	 Class 1 - Global explanation: "(chf_flg & stroke_flg & age_HIGH & ~sodium_first_LOW) | (chf_flg & age_HIGH & sodium_first_HIGH & ~service_num_HIGH) | (stroke_flg & age_HIGH & ~sapsi_first_LOW & ~sodium_first_LOW) | (age_HIGH & sodium_first_HIGH & ~sapsi_first_LOW & ~service_num_HIGH)" - Accuracy: 0.8652
# 	 Elapsed time 559.6863331794739
# 	 Fidelity: "0.9494" - Complexity: "16"
# Split [7/10]
# 	 Black box accuracy: 0.8079
# Labels (1599, 1)
# Discretized features
# Completed model 1/1!
# Train_acc: 0.9, Val_acc: 0.0
# 	 Model's accuracy: 0.8249
# 	 Class 1 - Global explanation: "(afib_flg & resp_flg & ~(sapsi_first_LOW & ~tco2_first_HIGH)) | (platelet_first_LOW & ~service_num_HIGH & ~(afib_flg & resp_flg) & ~(sapsi_first_LOW & ~tco2_first_HIGH) & ~(~stroke_flg & ~age_HIGH) & ~(~stroke_flg & ~sofa_first_HIGH)) | (age_HIGH & weight_first_LOW & ~(afib_flg & resp_flg) & ~(platelet_first_LOW & ~service_num_HIGH) & ~(sapsi_first_LOW & ~tco2_first_HIGH) & ~(~stroke_flg & ~age_HIGH) & ~(~stroke_flg & ~sofa_first_HIGH)) | (iv_day_1_HIGH & ~(afib_flg & resp_flg) & ~(age_HIGH & weight_first_LOW) & ~(platelet_first_LOW & ~service_num_HIGH) & ~(sapsi_first_LOW & ~tco2_first_HIGH) & ~(~stroke_flg & ~age_HIGH) & ~(~stroke_flg & ~sofa_first_HIGH))" - Accuracy: 0.8249
# 	 Elapsed time 536.183712720871
# 	 Fidelity: "0.9379" - Complexity: "39"
# Split [8/10]
# 	 Black box accuracy: 0.8701
# Labels (1599, 1)
# Discretized features
# Completed model 1/1!
# Train_acc: 0.9, Val_acc: 0.0
# 	 Model's accuracy: 0.8644
# 	 Class 1 - Global explanation: "(stroke_flg & age_HIGH & ~sodium_first_LOW) | (stroke_flg & tco2_first_HIGH & ~sodium_first_LOW) | (age_HIGH & ~bun_first_LOW & ~weight_first_HIGH) | (stroke_flg & tco2_first_HIGH & ~bun_first_LOW & ~weight_first_HIGH)" - Accuracy: 0.8644
# 	 Elapsed time 548.4926996231079
# 	 Fidelity: "0.9831" - Complexity: "13"
# Split [9/10]
# 	 Black box accuracy: 0.8305
# Labels (1599, 1)
# Discretized features
# Completed model 1/1!
# Train_acc: 0.9, Val_acc: 0.0
# 	 Model's accuracy: 0.8644
# 	 Class 1 - Global explanation: "(stroke_flg & ~sapsi_first_LOW & ~(hr_1st_NORMAL & sapsi_first_LOW) & ~(age_NORMAL & ~weight_first_NORMAL) & ~(~age_HIGH & ~chloride_first_LOW)) | (~renal_flg & ~bun_first_LOW & ~(hr_1st_NORMAL & sapsi_first_LOW) & ~(stroke_flg & ~sapsi_first_LOW) & ~(age_NORMAL & ~weight_first_NORMAL) & ~(~age_HIGH & ~chloride_first_LOW)) | (afib_flg & ~(hr_1st_NORMAL & sapsi_first_LOW) & ~(stroke_flg & ~sapsi_first_LOW) & ~(age_NORMAL & ~weight_first_NORMAL) & ~(~renal_flg & ~bun_first_LOW) & ~(~age_HIGH & ~chloride_first_LOW)) | (sofa_first_HIGH & ~afib_flg & ~(hr_1st_NORMAL & sapsi_first_LOW) & ~(stroke_flg & ~sapsi_first_LOW) & ~(age_NORMAL & ~weight_first_NORMAL) & ~(~renal_flg & ~bun_first_LOW) & ~(~age_HIGH & ~chloride_first_LOW))" - Accuracy: 0.8475
# 	 Elapsed time 527.9149992465973
# 	 Fidelity: "0.9492" - Complexity: "41"
# Split [10/10]
# 	 Black box accuracy: 0.8531
# Labels (1599, 1)
# Discretized features
# Completed model 1/1!
# Train_acc: 0.9, Val_acc: 0.0
# 	 Model's accuracy: 0.8418
# 	 Class 1 - Global explanation: "(creatinine_first_LOW & sapsi_first_HIGH & ~(age_NORMAL & ~stroke_flg)) | (~bun_first_LOW & ~hr_1st_HIGH & ~(creatinine_first_LOW & sapsi_first_HIGH) & ~(age_LOW & ~sepsis_flg) & ~(age_NORMAL & ~stroke_flg)) | (stroke_flg & ~renal_flg & ~age_NORMAL & ~(creatinine_first_LOW & sapsi_first_HIGH) & ~(age_LOW & ~sepsis_flg) & ~(age_NORMAL & ~stroke_flg) & ~(~age_LOW & ~sapsi_first_NORMAL) & ~(~bun_first_LOW & ~hr_1st_HIGH)) | (tco2_first_NORMAL & ~age_NORMAL & ~(creatinine_first_LOW & sapsi_first_HIGH) & ~(stroke_flg & ~renal_flg) & ~(age_LOW & ~sepsis_flg) & ~(age_NORMAL & ~stroke_flg) & ~(~afib_flg & ~spo2_1st_LOW) & ~(~age_LOW & ~sapsi_first_NORMAL) & ~(~bun_first_LOW & ~hr_1st_HIGH))" - Accuracy: 0.8418
# 	 Elapsed time 547.9319286346436
# 	 Fidelity: "0.9548" - Complexity: "41"
# Consistency of explanations: 0.2222
#   method  split                                        explanation  \
# 0    brl      0  (stroke_flg & age_HIGH & sodium_first_HIGH) | ...
# 1    brl      1  (stroke_flg & age_HIGH & wbc_first_HIGH & ~sap...
# 2    brl      2  (renal_flg & stroke_flg & ~abg_count_LOW) | (r...
# 3    brl      3  (stroke_flg & age_HIGH & weight_first_LOW & ~s...
# 4    brl      4  (stroke_flg & hgb_first_NORMAL & ~sapsi_first_...
# 5    brl      5  (chf_flg & stroke_flg & age_HIGH & ~sodium_fir...
# 6    brl      6  (afib_flg & resp_flg & ~(sapsi_first_LOW & ~tc...
# 7    brl      7  (stroke_flg & age_HIGH & ~sodium_first_LOW) | ...
# 8    brl      8  (stroke_flg & ~sapsi_first_LOW & ~(hr_1st_NORM...
# 9    brl      9  (creatinine_first_LOW & sapsi_first_HIGH & ~(a...
#
#    model_accuracy  explanation_accuracy  explanation_fidelity  \
# 0        0.865169              0.865169              0.932584
# 1        0.865169              0.865169              0.932584
# 2        0.876404              0.876404              0.932584
# 3        0.859551              0.865169              0.960674
# 4        0.825843              0.853933              0.949438
# 5        0.859551              0.865169              0.949438
# 6        0.807910              0.824859              0.937853
# 7        0.870056              0.864407              0.983051
# 8        0.830508              0.847458              0.949153
# 9        0.853107              0.841808              0.954802
#
#    explanation_complexity  explanation_consistency  elapsed_time
# 0                      12                 0.222222    551.255056
# 1                      16                 0.222222    550.891021
# 2                      28                 0.222222    545.325771
# 3                       8                 0.222222    526.027836
# 4                      15                 0.222222    540.576839
# 5                      16                 0.222222    559.686333
# 6                      39                 0.222222    536.183713
# 7                      13                 0.222222    548.492700
# 8                      41                 0.222222    527.914999
# 9                      41                 0.222222    547.931929

# %% [markdown]
# # Summary

# %%
import glob

cols = ['model_accuracy', 'explanation_accuracy', 'explanation_fidelity', 
        'explanation_complexity', 'elapsed_time', 'explanation_consistency']
mean_cols = [f'{c}_mean' for c in cols]
sem_cols = [f'{c}_sem' for c in cols]

df_list = []
files = glob.glob(f'{results_dir}/**/results**.csv', recursive = True)
for file in files:
    df = pd.read_csv(file, index_col=0)
    method = df['method'][0]
    df_mean = df[cols].mean()
    df_sem = df[cols].sem()
    df_mean.columns = mean_cols
    df_sem.columns = sem_cols
    summary = pd.concat([df_mean, df_sem])
    summary.name = method
    df_list.append(summary)


summary = pd.concat(df_list, axis=1).T
summary.columns = mean_cols + sem_cols
summary
# Out:
#          model_accuracy_mean  explanation_accuracy_mean  \
# brl                 0.851327                   0.856954
# pruning             0.851327                   0.857532
# psi                 0.851327                   0.838993
# tree-3              0.851327                   0.867117
# tree                0.851327                   0.855275
# weights             0.851327                   0.810693
#
#          explanation_fidelity_mean  explanation_complexity_mean  \
# brl                       0.948216                         22.9
# pruning                   0.922831                          7.0
# psi                       0.903161                          1.3
# tree-3                    0.944820                          4.8
# tree                      0.930743                        432.1
# weights                   0.865822                          6.4
#
#          elapsed_time_mean  explanation_consistency_mean  model_accuracy_sem  \
# brl             543.428620                      0.222222            0.007047
# pruning          15.301895                      0.411765            0.007047
# psi              10.139380                      0.433333            0.007047
# tree-3            0.006182                      0.285714            0.007047
# tree              0.008880                      0.603597            0.007047
# weights          18.456567                      0.355556            0.007047
#
#          explanation_accuracy_sem  explanation_fidelity_sem  \
# brl                      0.004787                  0.005007
# pruning                  0.005077                  0.009045
# psi                      0.012539                  0.012733
# tree-3                   0.003870                  0.005816
# tree                     0.006061                  0.005318
# weights                  0.033260                  0.040017
#
#          explanation_complexity_sem  elapsed_time_sem  \
# brl                        4.132392          3.390933
# pruning                    0.699206          0.190695
# psi                        0.152753          0.030241
# tree-3                     0.663325          0.000291
# tree                      16.459006          0.000277
# weights                    0.945163          1.001188
#
#          explanation_consistency_sem
# brl                              0.0
# pruning                          0.0
# psi                              0.0
# tree-3                           0.0
# tree                             0.0
# weights                          0.0

# %%
summary.to_csv(os.path.join(results_dir, 'summary.csv'))
