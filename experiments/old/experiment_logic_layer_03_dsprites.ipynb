# %%
import sys
sys.path.append('..')
import os
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, KBinsDiscretizer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from torch.utils.data import TensorDataset, DataLoader
from torchvision.models import resnet18
import torch.nn.functional as F
import time
from sklearn.metrics import accuracy_score
from sympy import simplify_logic
from sklearn.model_selection import train_test_split

import lens
from lens.utils.base import validate_network, set_seed, tree_to_formula
from lens.utils.layer import prune_logic_layers
from lens import logic

from dSprites.dSprites_loader import load_dsprites, concept_filters, get_shape_scale
from dSprites.dSprites_style_I2C import i2c_style

results_dir = './results_ll/dsprites'
if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
n_rep = 10
tot_epochs = 10001
prune_epochs = 60001

# %%
def get_data(path):
    # Load dataset specified by schema
    dataset_schema = 'small_skip'
    # dataset_schema = 'big_skip'

    # Get filtered concept values
    shape_range, scale_range, rot_range, x_pos_range, y_pos_range = concept_filters(dataset_schema)

    # Define function for filtering out specified concept values only
    def c_filter_fn(concepts):
        in_shape_range = (concepts[1] in shape_range)
        in_scale_range = (concepts[2] in scale_range)
        in_rot_range = (concepts[3] in rot_range)
        in_x_range = (concepts[4] in x_pos_range)
        in_y_range = (concepts[5] in y_pos_range)

        return (in_shape_range and in_scale_range and in_rot_range and in_x_range and in_y_range)

    label_fn = get_shape_scale(shape_range, scale_range)
    
    # Load dataset
    x_train, y_train, x_val, y_val, x_test, y_test, c_train, c_val, c_test, c_names = load_dsprites(path,
                                                                               c_filter_fn=c_filter_fn,
                                                                               label_fn=label_fn,
                                                                               train_test_split_flag=True)


    return x_train, y_train, x_val, y_val, x_test, y_test, c_train, c_val, c_test, c_names

# Load the model, as well as input, label, and concept data
data = get_data(path='./dSprites/data/dsprites.npz')
x_train, y_train, x_val, y_val, x_test, y_test, c_train, c_val, c_test, c_names = data
x_train = torch.FloatTensor(x_train)
y_train = torch.FloatTensor(y_train)
x_val = torch.FloatTensor(x_val)
y_val = torch.FloatTensor(y_val)
x_test = torch.FloatTensor(x_test)
y_test = torch.FloatTensor(y_test)
c_train = torch.FloatTensor(c_train)
c_val = torch.FloatTensor(c_val)
c_test = torch.FloatTensor(c_test)
print("Data loaded successfully...")
# Out:
# x_train shape: (20993, 3, 64, 64)
# c_train shape: (20993, 50)
# y_train shape: (20993, 18)
# Number of images in x_train 20993
# Number of images in x_val 10341
# Number of images in x_test 5530
# Data loaded successfully...

# %%
args = {
    'models_dir': './models_ll/dSprites/', 
    'model_style': 'CBM',
    'seed': 0,
    'batch_size': 256,
}

if not os.path.isdir(args['models_dir']):
    os.makedirs(args['models_dir'])

train_dataset = TensorDataset(x_train, c_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=args['batch_size'], shuffle=False)
val_dataset = TensorDataset(x_val, c_val, y_val)
valid_loader = DataLoader(val_dataset, batch_size=args['batch_size'], shuffle=False)
test_dataset = TensorDataset(x_test, c_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=args['batch_size'], shuffle=False)

# %%
n_concepts = c_train.size(1)
n_outputs = y_train.size(1)

# %%
colors = ['white']
shapes = ['square', 'ellipse', 'heart']
scale = ['very small', 'small', 's-medium', 'b-medium', 'big', 'very big']
rotation = ['0°', '5°', '10°', '15°', '20°', '25°', '30°', '35°']
x_pos = ['x0', 'x2', 'x4', 'x6', 'x8', 'x10', 'x12', 'x14', 'x16', 'x18', 'x20', 'x22', 'x24', 'x26', 'x28', 'x30']
y_pos = ['y0', 'y2', 'y4', 'y6', 'y8', 'y10', 'y12', 'y14', 'y16', 'y18', 'y20', 'y22', 'y24', 'y26', 'y28', 'y30']
concepts = colors + shapes + scale + rotation + x_pos + y_pos
len(concepts)
# Out:
# 50

# %%
def l1_loss(model):
    loss = 0
    for module in model.children():
        if isinstance(module, lens.nn.XLogic):
            loss += torch.norm(module.weight, 1) + torch.norm(module.bias, 1)
            break
    return loss

# %%
def cbm_learning(net, dataloader, device, optimizer, criterion, epoch, n_epochs, train=False, base=False):
    running_loss = 0.0
    y_correct = 0
    c_correct = 0
    c_total = 0
    y_total = 0
    need_pruning = True
    prune_epochs = 30
    total_step = len(dataloader)
    for batch_idx, (data_, concepts_, target_) in enumerate(dataloader):
        data_, concepts_, target_ = data_.to(device), concepts_.to(device), target_.to(device)

        if train:
            optimizer.zero_grad()
        
        if base:
            c_preds = net[0](data_)
            loss = criterion(c_preds, concepts_)
        else:
            c_preds = net[0](data_)
            y_preds = net[1](c_preds)
            loss = criterion(y_preds, target_) + 0.00001 * l1_loss(net_top)

        if train:
            loss.backward()
            optimizer.step()
        
            if epoch > prune_epochs and need_pruning and not base:
                lens.utils.layer.prune_logic_layers(net[1].to(device), fan_in=9, device=device)
                need_pruning = False

        running_loss += loss.item()
        
        c_correct += torch.sum((c_preds > 0.5).eq(concepts_)).item()
        c_total += concepts_.size(0) * concepts_.size(1)
        if not base:
            y_correct += torch.sum((y_preds.argmax(dim=1)).eq(target_.argmax(dim=1))).item()
            y_total += target_.size(0)
            
        if (batch_idx) % 20 == 0 and train:
            print(f'Epoch [{epoch}/{n_epochs}], Step [{batch_idx}/{total_step}], Loss: {loss.item():.4f}')

    c_accuracy = c_correct / c_total
    if base:
        y_accuracy = 0
    else:
        y_accuracy = y_correct / y_total
    loss = running_loss / total_step

    return net, c_accuracy, y_accuracy, loss

# %%
net_base = resnet18(pretrained=False)
num_ftrs = net_base.fc.in_features
net_base.fc = torch.nn.Linear(num_ftrs, n_concepts)
net_top = torch.nn.Sequential(*[
    lens.nn.XLogic(n_concepts, 32, first=True),
    torch.nn.LeakyReLU(),
    torch.nn.Linear(32, 32),
    torch.nn.LeakyReLU(),
    torch.nn.Linear(32, 32),
    torch.nn.LeakyReLU(),
    torch.nn.Linear(32, n_outputs),
    lens.nn.XLogic(n_outputs, n_outputs, top=True),
])
net = torch.nn.Sequential(*[net_base, net_top]).to(device)

file_name = './models_ll/dsprites/trained_model_l1'

# %%
for base in [True, False]:
    print(base)
    net_suffix = 'base' if base else 'top'
    if os.path.isfile(f'{file_name}_{net_suffix}.pt'):
        # load trained model
        net.load_state_dict(torch.load(f'{file_name}_{net_suffix}.pt'))

    else:
        set_seed(0)
        need_pruning = True
        
        criterion = torch.nn.MSELoss()

        if base:
            n_epochs = 20
            optimizer = torch.optim.AdamW(net.parameters(), lr=0.0001)
        else:
            n_epochs = 50
            optimizer = torch.optim.AdamW(net.parameters(), lr=0.001)
            for param in net[0].parameters():
                param.requires_grad = False
                
        valid_loss_min = np.Inf
        c_train_accuracy = 0
        val_loss = []
        val_acc = []
        val_c_acc = []
        test_loss = []
        test_acc = []
        test_c_acc = []
        train_loss = []
        train_acc = []
        train_c_acc = []
        epoch = 1
        for epoch in range(1, n_epochs + 1):
            print(f'Epoch {epoch}\n')

            net, c_accuracy, y_accuracy, loss = cbm_learning(net, train_loader,
                                                             device, optimizer, criterion,
                                                             epoch, n_epochs, train=True,
                                                             base=base)
            c_train_accuracy = c_accuracy
            train_c_acc.append(c_accuracy)
            train_acc.append(y_accuracy)
            train_loss.append(loss)
            print(f'\ntrain-loss: {loss:.4f}, train-c-acc: {c_accuracy:.4f}, train-cy-acc: {y_accuracy:.4f}')

            with torch.no_grad():
                net.eval()

                net, c_accuracy, y_accuracy, loss = cbm_learning(net, valid_loader,
                                                                 device, optimizer, criterion,
                                                                 epoch, n_epochs, train=False, 
                                                                 base=base)
                val_c_acc.append(c_accuracy)
                val_acc.append(y_accuracy)
                val_loss.append(loss)
                print(f'validation loss: {loss:.4f}, validation-c-acc: {c_accuracy:.4f}, validation-y-acc: {y_accuracy:.4f}')

                if loss < valid_loss_min:
                    valid_loss_min = loss
                    torch.save(net.state_dict(), f'{file_name}_{net_suffix}.pt')
                    print('Improvement-Detected, save-model')

                net, c_accuracy, y_accuracy, loss = cbm_learning(net, test_loader,
                                                                 device, optimizer, criterion,
                                                                 epoch, n_epochs, train=False, 
                                                                 base=base)
                test_c_acc.append(c_accuracy)
                test_acc.append(y_accuracy)
                test_loss.append(loss)
                print(f'test loss: {loss:.4f}, test-c-acc: {c_accuracy:.4f}, test-y-acc: {y_accuracy:.4f}\n')

            net.train()

        results = pd.DataFrame({
            'test_acc': test_acc,
            'test_c_acc': test_c_acc,
            'test_loss': test_loss,
            'val_acc': val_acc,
            'val_c_acc': val_c_acc,
            'val_loss': val_loss,
            'train_acc': train_acc,
            'train_c_acc': train_c_acc,
            'train_loss': train_loss,
        })
# Out:
# True
# False
# Epoch 1
#
# Epoch [1/50], Step [0/83], Loss: 0.2497
# Epoch [1/50], Step [20/83], Loss: 0.2346
# Epoch [1/50], Step [40/83], Loss: 0.2015
# Epoch [1/50], Step [60/83], Loss: 0.0924
# Epoch [1/50], Step [80/83], Loss: 0.0545
#
# train-loss: 0.1670, train-c-acc: 0.9944, train-cy-acc: 0.0499
# validation loss: 0.0547, validation-c-acc: 0.9786, validation-y-acc: 0.0586
# Improvement-Detected, save-model
# test loss: 0.0547, test-c-acc: 0.9791, test-y-acc: 0.0530
#
# Epoch 2
#
# Epoch [2/50], Step [0/83], Loss: 0.0548
# Epoch [2/50], Step [20/83], Loss: 0.0547
# Epoch [2/50], Step [40/83], Loss: 0.0546
# Epoch [2/50], Step [60/83], Loss: 0.0541
# Epoch [2/50], Step [80/83], Loss: 0.0537
#
# train-loss: 0.0544, train-c-acc: 0.9944, train-cy-acc: 0.0547
# validation loss: 0.0538, validation-c-acc: 0.9786, validation-y-acc: 0.0586
# Improvement-Detected, save-model
# test loss: 0.0539, test-c-acc: 0.9791, test-y-acc: 0.0530
#
# Epoch 3
#
# Epoch [3/50], Step [0/83], Loss: 0.0539
# Epoch [3/50], Step [20/83], Loss: 0.0537
# Epoch [3/50], Step [40/83], Loss: 0.0538
# Epoch [3/50], Step [60/83], Loss: 0.0536
# Epoch [3/50], Step [80/83], Loss: 0.0534
#
# train-loss: 0.0537, train-c-acc: 0.9944, train-cy-acc: 0.0547
# validation loss: 0.0535, validation-c-acc: 0.9786, validation-y-acc: 0.0586
# Improvement-Detected, save-model
# test loss: 0.0535, test-c-acc: 0.9791, test-y-acc: 0.0530
#
# Epoch 4
#
# Epoch [4/50], Step [0/83], Loss: 0.0535
# Epoch [4/50], Step [20/83], Loss: 0.0535
# Epoch [4/50], Step [40/83], Loss: 0.0534
# Epoch [4/50], Step [60/83], Loss: 0.0534
# Epoch [4/50], Step [80/83], Loss: 0.0533
#
# train-loss: 0.0534, train-c-acc: 0.9944, train-cy-acc: 0.0596
# validation loss: 0.0534, validation-c-acc: 0.9786, validation-y-acc: 0.0743
# Improvement-Detected, save-model
# test loss: 0.0534, test-c-acc: 0.9791, test-y-acc: 0.0660
#
# Epoch 5
#
# Epoch [5/50], Step [0/83], Loss: 0.0534
# Epoch [5/50], Step [20/83], Loss: 0.0533
# Epoch [5/50], Step [40/83], Loss: 0.0533
# Epoch [5/50], Step [60/83], Loss: 0.0533
# Epoch [5/50], Step [80/83], Loss: 0.0532
#
# train-loss: 0.0533, train-c-acc: 0.9944, train-cy-acc: 0.0686
# validation loss: 0.0533, validation-c-acc: 0.9786, validation-y-acc: 0.1056
# Improvement-Detected, save-model
# test loss: 0.0533, test-c-acc: 0.9791, test-y-acc: 0.1014
#
# Epoch 6
#
# Epoch [6/50], Step [0/83], Loss: 0.0533
# Epoch [6/50], Step [20/83], Loss: 0.0532
# Epoch [6/50], Step [40/83], Loss: 0.0532
# Epoch [6/50], Step [60/83], Loss: 0.0532
# Epoch [6/50], Step [80/83], Loss: 0.0531
#
# train-loss: 0.0532, train-c-acc: 0.9944, train-cy-acc: 0.0764
# validation loss: 0.0532, validation-c-acc: 0.9786, validation-y-acc: 0.1160
# Improvement-Detected, save-model
# test loss: 0.0532, test-c-acc: 0.9791, test-y-acc: 0.1103
#
# Epoch 7
#
# Epoch [7/50], Step [0/83], Loss: 0.0531
# Epoch [7/50], Step [20/83], Loss: 0.0531
# Epoch [7/50], Step [40/83], Loss: 0.0531
# Epoch [7/50], Step [60/83], Loss: 0.0531
# Epoch [7/50], Step [80/83], Loss: 0.0530
#
# train-loss: 0.0531, train-c-acc: 0.9944, train-cy-acc: 0.0855
# validation loss: 0.0531, validation-c-acc: 0.9786, validation-y-acc: 0.1250
# Improvement-Detected, save-model
# test loss: 0.0531, test-c-acc: 0.9791, test-y-acc: 0.1193
#
# Epoch 8
#
# Epoch [8/50], Step [0/83], Loss: 0.0530
# Epoch [8/50], Step [20/83], Loss: 0.0530
# Epoch [8/50], Step [40/83], Loss: 0.0529
# Epoch [8/50], Step [60/83], Loss: 0.0529
# Epoch [8/50], Step [80/83], Loss: 0.0529
#
# train-loss: 0.0530, train-c-acc: 0.9944, train-cy-acc: 0.0990
# validation loss: 0.0529, validation-c-acc: 0.9786, validation-y-acc: 0.1569
# Improvement-Detected, save-model
# test loss: 0.0529, test-c-acc: 0.9791, test-y-acc: 0.1485
#
# Epoch 9
#
# Epoch [9/50], Step [0/83], Loss: 0.0529
# Epoch [9/50], Step [20/83], Loss: 0.0528
# Epoch [9/50], Step [40/83], Loss: 0.0528
# Epoch [9/50], Step [60/83], Loss: 0.0527
# Epoch [9/50], Step [80/83], Loss: 0.0525
#
# train-loss: 0.0528, train-c-acc: 0.9944, train-cy-acc: 0.1344
# validation loss: 0.0527, validation-c-acc: 0.9786, validation-y-acc: 0.1556
# Improvement-Detected, save-model
# test loss: 0.0527, test-c-acc: 0.9791, test-y-acc: 0.1519
#
# Epoch 10
#
# Epoch [10/50], Step [0/83], Loss: 0.0525
# Epoch [10/50], Step [20/83], Loss: 0.0525
# Epoch [10/50], Step [40/83], Loss: 0.0522
# Epoch [10/50], Step [60/83], Loss: 0.0516
# Epoch [10/50], Step [80/83], Loss: 0.0505
#
# train-loss: 0.0520, train-c-acc: 0.9944, train-cy-acc: 0.1427
# validation loss: 0.0511, validation-c-acc: 0.9786, validation-y-acc: 0.1240
# Improvement-Detected, save-model
# test loss: 0.0511, test-c-acc: 0.9791, test-y-acc: 0.1239
#
# Epoch 11
#
# Epoch [11/50], Step [0/83], Loss: 0.0503
# Epoch [11/50], Step [20/83], Loss: 0.0498
# Epoch [11/50], Step [40/83], Loss: 0.0489
# Epoch [11/50], Step [60/83], Loss: 0.0475
# Epoch [11/50], Step [80/83], Loss: 0.0466
#
# train-loss: 0.0487, train-c-acc: 0.9944, train-cy-acc: 0.1555
# validation loss: 0.0482, validation-c-acc: 0.9786, validation-y-acc: 0.2546
# Improvement-Detected, save-model
# test loss: 0.0482, test-c-acc: 0.9791, test-y-acc: 0.2488
#
# Epoch 12
#
# Epoch [12/50], Step [0/83], Loss: 0.0463
# Epoch [12/50], Step [20/83], Loss: 0.0467
# Epoch [12/50], Step [40/83], Loss: 0.0462
# Epoch [12/50], Step [60/83], Loss: 0.0441
# Epoch [12/50], Step [80/83], Loss: 0.0423
#
# train-loss: 0.0455, train-c-acc: 0.9944, train-cy-acc: 0.3127
# validation loss: 0.0449, validation-c-acc: 0.9786, validation-y-acc: 0.3403
# Improvement-Detected, save-model
# test loss: 0.0449, test-c-acc: 0.9791, test-y-acc: 0.3392
#
# Epoch 13
#
# Epoch [13/50], Step [0/83], Loss: 0.0416
# Epoch [13/50], Step [20/83], Loss: 0.0407
# Epoch [13/50], Step [40/83], Loss: 0.0367
# Epoch [13/50], Step [60/83], Loss: 0.0312
# Epoch [13/50], Step [80/83], Loss: 0.0288
#
# train-loss: 0.0362, train-c-acc: 0.9944, train-cy-acc: 0.5124
# validation loss: 0.0339, validation-c-acc: 0.9786, validation-y-acc: 0.6283
# Improvement-Detected, save-model
# test loss: 0.0336, test-c-acc: 0.9791, test-y-acc: 0.6259
#
# Epoch 14
#
# Epoch [14/50], Step [0/83], Loss: 0.0272
# Epoch [14/50], Step [20/83], Loss: 0.0257
# Epoch [14/50], Step [40/83], Loss: 0.0231
# Epoch [14/50], Step [60/83], Loss: 0.0205
# Epoch [14/50], Step [80/83], Loss: 0.0183
#
# train-loss: 0.0234, train-c-acc: 0.9944, train-cy-acc: 0.8081
# validation loss: 0.0269, validation-c-acc: 0.9786, validation-y-acc: 0.7741
# Improvement-Detected, save-model
# test loss: 0.0266, test-c-acc: 0.9791, test-y-acc: 0.7814
#
# Epoch 15
#
# Epoch [15/50], Step [0/83], Loss: 0.0173
# Epoch [15/50], Step [20/83], Loss: 0.0163
# Epoch [15/50], Step [40/83], Loss: 0.0149
# Epoch [15/50], Step [60/83], Loss: 0.0128
# Epoch [15/50], Step [80/83], Loss: 0.0105
#
# train-loss: 0.0148, train-c-acc: 0.9944, train-cy-acc: 0.9241
# validation loss: 0.0231, validation-c-acc: 0.9786, validation-y-acc: 0.7913
# Improvement-Detected, save-model
# test loss: 0.0229, test-c-acc: 0.9791, test-y-acc: 0.7980
#
# Epoch 16
#
# Epoch [16/50], Step [0/83], Loss: 0.0103
# Epoch [16/50], Step [20/83], Loss: 0.0096
# Epoch [16/50], Step [40/83], Loss: 0.0084
# Epoch [16/50], Step [60/83], Loss: 0.0080
# Epoch [16/50], Step [80/83], Loss: 0.0064
#
# train-loss: 0.0090, train-c-acc: 0.9944, train-cy-acc: 0.9623
# validation loss: 0.0218, validation-c-acc: 0.9786, validation-y-acc: 0.8073
# Improvement-Detected, save-model
# test loss: 0.0214, test-c-acc: 0.9791, test-y-acc: 0.8085
#
# Epoch 17
#
# Epoch [17/50], Step [0/83], Loss: 0.0061
# Epoch [17/50], Step [20/83], Loss: 0.0059
# Epoch [17/50], Step [40/83], Loss: 0.0052
# Epoch [17/50], Step [60/83], Loss: 0.0042
# Epoch [17/50], Step [80/83], Loss: 0.0031
#
# train-loss: 0.0053, train-c-acc: 0.9944, train-cy-acc: 0.9945
# validation loss: 0.0203, validation-c-acc: 0.9786, validation-y-acc: 0.8062
# Improvement-Detected, save-model
# test loss: 0.0199, test-c-acc: 0.9791, test-y-acc: 0.8107
#
# Epoch 18
#
# Epoch [18/50], Step [0/83], Loss: 0.0029
# Epoch [18/50], Step [20/83], Loss: 0.0032
# Epoch [18/50], Step [40/83], Loss: 0.0030
# Epoch [18/50], Step [60/83], Loss: 0.0025
# Epoch [18/50], Step [80/83], Loss: 0.0020
#
# train-loss: 0.0031, train-c-acc: 0.9944, train-cy-acc: 0.9958
# validation loss: 0.0192, validation-c-acc: 0.9786, validation-y-acc: 0.8138
# Improvement-Detected, save-model
# test loss: 0.0187, test-c-acc: 0.9791, test-y-acc: 0.8195
#
# Epoch 19
#
# Epoch [19/50], Step [0/83], Loss: 0.0020
# Epoch [19/50], Step [20/83], Loss: 0.0025
# Epoch [19/50], Step [40/83], Loss: 0.0024
# Epoch [19/50], Step [60/83], Loss: 0.0021
# Epoch [19/50], Step [80/83], Loss: 0.0017
#
# train-loss: 0.0025, train-c-acc: 0.9944, train-cy-acc: 0.9962
# validation loss: 0.0193, validation-c-acc: 0.9786, validation-y-acc: 0.8070
# test loss: 0.0187, test-c-acc: 0.9791, test-y-acc: 0.8166
#
# Epoch 20
#
# Epoch [20/50], Step [0/83], Loss: 0.0017
# Epoch [20/50], Step [20/83], Loss: 0.0022
# Epoch [20/50], Step [40/83], Loss: 0.0022
# Epoch [20/50], Step [60/83], Loss: 0.0018
# Epoch [20/50], Step [80/83], Loss: 0.0016
#
# train-loss: 0.0022, train-c-acc: 0.9944, train-cy-acc: 0.9966
# validation loss: 0.0194, validation-c-acc: 0.9786, validation-y-acc: 0.8029
# test loss: 0.0188, test-c-acc: 0.9791, test-y-acc: 0.8139
#
# Epoch 21
#
# Epoch [21/50], Step [0/83], Loss: 0.0016
# Epoch [21/50], Step [20/83], Loss: 0.0020
# Epoch [21/50], Step [40/83], Loss: 0.0020
# Epoch [21/50], Step [60/83], Loss: 0.0017
# Epoch [21/50], Step [80/83], Loss: 0.0015
#
# train-loss: 0.0021, train-c-acc: 0.9944, train-cy-acc: 0.9969
# validation loss: 0.0193, validation-c-acc: 0.9786, validation-y-acc: 0.8035
# test loss: 0.0187, test-c-acc: 0.9791, test-y-acc: 0.8145
#
# Epoch 22
#
# Epoch [22/50], Step [0/83], Loss: 0.0015
# Epoch [22/50], Step [20/83], Loss: 0.0019
# Epoch [22/50], Step [40/83], Loss: 0.0019
# Epoch [22/50], Step [60/83], Loss: 0.0016
# Epoch [22/50], Step [80/83], Loss: 0.0014
#
# train-loss: 0.0019, train-c-acc: 0.9944, train-cy-acc: 0.9968
# validation loss: 0.0190, validation-c-acc: 0.9786, validation-y-acc: 0.8040
# Improvement-Detected, save-model
# test loss: 0.0185, test-c-acc: 0.9791, test-y-acc: 0.8152
#
# Epoch 23
#
# Epoch [23/50], Step [0/83], Loss: 0.0014
# Epoch [23/50], Step [20/83], Loss: 0.0018
# Epoch [23/50], Step [40/83], Loss: 0.0018
# Epoch [23/50], Step [60/83], Loss: 0.0015
# Epoch [23/50], Step [80/83], Loss: 0.0013
#
# train-loss: 0.0018, train-c-acc: 0.9944, train-cy-acc: 0.9970
# validation loss: 0.0187, validation-c-acc: 0.9786, validation-y-acc: 0.8059
# Improvement-Detected, save-model
# test loss: 0.0182, test-c-acc: 0.9791, test-y-acc: 0.8168
#
# Epoch 24
#
# Epoch [24/50], Step [0/83], Loss: 0.0014
# Epoch [24/50], Step [20/83], Loss: 0.0017
# Epoch [24/50], Step [40/83], Loss: 0.0017
# Epoch [24/50], Step [60/83], Loss: 0.0014
# Epoch [24/50], Step [80/83], Loss: 0.0013
#
# train-loss: 0.0018, train-c-acc: 0.9944, train-cy-acc: 0.9971
# validation loss: 0.0185, validation-c-acc: 0.9786, validation-y-acc: 0.8079
# Improvement-Detected, save-model
# test loss: 0.0179, test-c-acc: 0.9791, test-y-acc: 0.8175
#
# Epoch 25
#
# Epoch [25/50], Step [0/83], Loss: 0.0013
# Epoch [25/50], Step [20/83], Loss: 0.0016
# Epoch [25/50], Step [40/83], Loss: 0.0016
# Epoch [25/50], Step [60/83], Loss: 0.0014
# Epoch [25/50], Step [80/83], Loss: 0.0012
#
# train-loss: 0.0017, train-c-acc: 0.9944, train-cy-acc: 0.9971
# validation loss: 0.0183, validation-c-acc: 0.9786, validation-y-acc: 0.8091
# Improvement-Detected, save-model
# test loss: 0.0178, test-c-acc: 0.9791, test-y-acc: 0.8179
#
# Epoch 26
#
# Epoch [26/50], Step [0/83], Loss: 0.0013
# Epoch [26/50], Step [20/83], Loss: 0.0016
# Epoch [26/50], Step [40/83], Loss: 0.0016
# Epoch [26/50], Step [60/83], Loss: 0.0013
# Epoch [26/50], Step [80/83], Loss: 0.0012
#
# train-loss: 0.0016, train-c-acc: 0.9944, train-cy-acc: 0.9973
# validation loss: 0.0183, validation-c-acc: 0.9786, validation-y-acc: 0.8086
# Improvement-Detected, save-model
# test loss: 0.0177, test-c-acc: 0.9791, test-y-acc: 0.8186
#
# Epoch 27
#
# Epoch [27/50], Step [0/83], Loss: 0.0012
# Epoch [27/50], Step [20/83], Loss: 0.0015
# Epoch [27/50], Step [40/83], Loss: 0.0015
# Epoch [27/50], Step [60/83], Loss: 0.0013
# Epoch [27/50], Step [80/83], Loss: 0.0011
#
# train-loss: 0.0016, train-c-acc: 0.9944, train-cy-acc: 0.9973
# validation loss: 0.0182, validation-c-acc: 0.9786, validation-y-acc: 0.8092
# Improvement-Detected, save-model
# test loss: 0.0176, test-c-acc: 0.9791, test-y-acc: 0.8174
#
# Epoch 28
#
# Epoch [28/50], Step [0/83], Loss: 0.0012
# Epoch [28/50], Step [20/83], Loss: 0.0015
# Epoch [28/50], Step [40/83], Loss: 0.0015
# Epoch [28/50], Step [60/83], Loss: 0.0013
# Epoch [28/50], Step [80/83], Loss: 0.0011
#
# train-loss: 0.0015, train-c-acc: 0.9944, train-cy-acc: 0.9974
# validation loss: 0.0181, validation-c-acc: 0.9786, validation-y-acc: 0.8095
# Improvement-Detected, save-model
# test loss: 0.0175, test-c-acc: 0.9791, test-y-acc: 0.8181
#
# Epoch 29
#
# Epoch [29/50], Step [0/83], Loss: 0.0012
# Epoch [29/50], Step [20/83], Loss: 0.0014
# Epoch [29/50], Step [40/83], Loss: 0.0014
# Epoch [29/50], Step [60/83], Loss: 0.0012
# Epoch [29/50], Step [80/83], Loss: 0.0011
#
# train-loss: 0.0015, train-c-acc: 0.9944, train-cy-acc: 0.9974
# validation loss: 0.0181, validation-c-acc: 0.9786, validation-y-acc: 0.8104
# Improvement-Detected, save-model
# test loss: 0.0174, test-c-acc: 0.9791, test-y-acc: 0.8190
#
# Epoch 30
#
# Epoch [30/50], Step [0/83], Loss: 0.0011
# Epoch [30/50], Step [20/83], Loss: 0.0014
# Epoch [30/50], Step [40/83], Loss: 0.0014
# Epoch [30/50], Step [60/83], Loss: 0.0012
# Epoch [30/50], Step [80/83], Loss: 0.0011
#
# train-loss: 0.0015, train-c-acc: 0.9944, train-cy-acc: 0.9975
# validation loss: 0.0180, validation-c-acc: 0.9786, validation-y-acc: 0.8096
# Improvement-Detected, save-model
# test loss: 0.0174, test-c-acc: 0.9791, test-y-acc: 0.8199
#
# Epoch 31
#
# Epoch [31/50], Step [0/83], Loss: 0.0011
# Epoch [31/50], Step [20/83], Loss: 0.0018
# Epoch [31/50], Step [40/83], Loss: 0.0018
# Epoch [31/50], Step [60/83], Loss: 0.0013
# Epoch [31/50], Step [80/83], Loss: 0.0011
#
# train-loss: 0.0018, train-c-acc: 0.9944, train-cy-acc: 0.9949
# validation loss: 0.0170, validation-c-acc: 0.9786, validation-y-acc: 0.8215
# Improvement-Detected, save-model
# test loss: 0.0162, test-c-acc: 0.9791, test-y-acc: 0.8300
#
# Epoch 32
#
# Epoch [32/50], Step [0/83], Loss: 0.0011
# Epoch [32/50], Step [20/83], Loss: 0.0014
# Epoch [32/50], Step [40/83], Loss: 0.0016
# Epoch [32/50], Step [60/83], Loss: 0.0012
# Epoch [32/50], Step [80/83], Loss: 0.0010
#
# train-loss: 0.0015, train-c-acc: 0.9944, train-cy-acc: 0.9959
# validation loss: 0.0168, validation-c-acc: 0.9786, validation-y-acc: 0.8257
# Improvement-Detected, save-model
# test loss: 0.0160, test-c-acc: 0.9791, test-y-acc: 0.8329
#
# Epoch 33
#
# Epoch [33/50], Step [0/83], Loss: 0.0010
# Epoch [33/50], Step [20/83], Loss: 0.0013
# Epoch [33/50], Step [40/83], Loss: 0.0015
# Epoch [33/50], Step [60/83], Loss: 0.0011
# Epoch [33/50], Step [80/83], Loss: 0.0009
#
# train-loss: 0.0015, train-c-acc: 0.9944, train-cy-acc: 0.9960
# validation loss: 0.0167, validation-c-acc: 0.9786, validation-y-acc: 0.8259
# Improvement-Detected, save-model
# test loss: 0.0159, test-c-acc: 0.9791, test-y-acc: 0.8336
#
# Epoch 34
#
# Epoch [34/50], Step [0/83], Loss: 0.0010
# Epoch [34/50], Step [20/83], Loss: 0.0012
# Epoch [34/50], Step [40/83], Loss: 0.0015
# Epoch [34/50], Step [60/83], Loss: 0.0011
# Epoch [34/50], Step [80/83], Loss: 0.0009
#
# train-loss: 0.0014, train-c-acc: 0.9944, train-cy-acc: 0.9960
# validation loss: 0.0166, validation-c-acc: 0.9786, validation-y-acc: 0.8267
# Improvement-Detected, save-model
# test loss: 0.0158, test-c-acc: 0.9791, test-y-acc: 0.8338
#
# Epoch 35
#
# Epoch [35/50], Step [0/83], Loss: 0.0010
# Epoch [35/50], Step [20/83], Loss: 0.0012
# Epoch [35/50], Step [40/83], Loss: 0.0014
# Epoch [35/50], Step [60/83], Loss: 0.0010
# Epoch [35/50], Step [80/83], Loss: 0.0009
#
# train-loss: 0.0014, train-c-acc: 0.9944, train-cy-acc: 0.9961
# validation loss: 0.0166, validation-c-acc: 0.9786, validation-y-acc: 0.8263
# test loss: 0.0159, test-c-acc: 0.9791, test-y-acc: 0.8335
#
# Epoch 36
#
# Epoch [36/50], Step [0/83], Loss: 0.0009
# Epoch [36/50], Step [20/83], Loss: 0.0011
# Epoch [36/50], Step [40/83], Loss: 0.0013
# Epoch [36/50], Step [60/83], Loss: 0.0010
# Epoch [36/50], Step [80/83], Loss: 0.0009
#
# train-loss: 0.0013, train-c-acc: 0.9944, train-cy-acc: 0.9961
# validation loss: 0.0166, validation-c-acc: 0.9786, validation-y-acc: 0.8266
# Improvement-Detected, save-model
# test loss: 0.0158, test-c-acc: 0.9791, test-y-acc: 0.8335
#
# Epoch 37
#
# Epoch [37/50], Step [0/83], Loss: 0.0009
# Epoch [37/50], Step [20/83], Loss: 0.0011
# Epoch [37/50], Step [40/83], Loss: 0.0013
# Epoch [37/50], Step [60/83], Loss: 0.0010
# Epoch [37/50], Step [80/83], Loss: 0.0008
#
# train-loss: 0.0013, train-c-acc: 0.9944, train-cy-acc: 0.9963
# validation loss: 0.0166, validation-c-acc: 0.9786, validation-y-acc: 0.8256
# Improvement-Detected, save-model
# test loss: 0.0158, test-c-acc: 0.9791, test-y-acc: 0.8325
#
# Epoch 38
#
# Epoch [38/50], Step [0/83], Loss: 0.0009
# Epoch [38/50], Step [20/83], Loss: 0.0011
# Epoch [38/50], Step [40/83], Loss: 0.0013
# Epoch [38/50], Step [60/83], Loss: 0.0010
# Epoch [38/50], Step [80/83], Loss: 0.0008
#
# train-loss: 0.0013, train-c-acc: 0.9944, train-cy-acc: 0.9964
# validation loss: 0.0166, validation-c-acc: 0.9786, validation-y-acc: 0.8254
# Improvement-Detected, save-model
# test loss: 0.0158, test-c-acc: 0.9791, test-y-acc: 0.8331
#
# Epoch 39
#
# Epoch [39/50], Step [0/83], Loss: 0.0009
# Epoch [39/50], Step [20/83], Loss: 0.0011
# Epoch [39/50], Step [40/83], Loss: 0.0012
# Epoch [39/50], Step [60/83], Loss: 0.0010
# Epoch [39/50], Step [80/83], Loss: 0.0008
#
# train-loss: 0.0012, train-c-acc: 0.9944, train-cy-acc: 0.9965
# validation loss: 0.0166, validation-c-acc: 0.9786, validation-y-acc: 0.8249
# Improvement-Detected, save-model
# test loss: 0.0158, test-c-acc: 0.9791, test-y-acc: 0.8329
#
# Epoch 40
#
# Epoch [40/50], Step [0/83], Loss: 0.0009
# Epoch [40/50], Step [20/83], Loss: 0.0010
# Epoch [40/50], Step [40/83], Loss: 0.0012
# Epoch [40/50], Step [60/83], Loss: 0.0009
# Epoch [40/50], Step [80/83], Loss: 0.0008
#
# train-loss: 0.0012, train-c-acc: 0.9944, train-cy-acc: 0.9965
# validation loss: 0.0165, validation-c-acc: 0.9786, validation-y-acc: 0.8252
# Improvement-Detected, save-model
# test loss: 0.0158, test-c-acc: 0.9791, test-y-acc: 0.8340
#
# Epoch 41
#
# Epoch [41/50], Step [0/83], Loss: 0.0008
# Epoch [41/50], Step [20/83], Loss: 0.0010
# Epoch [41/50], Step [40/83], Loss: 0.0012
# Epoch [41/50], Step [60/83], Loss: 0.0009
# Epoch [41/50], Step [80/83], Loss: 0.0008
#
# train-loss: 0.0012, train-c-acc: 0.9944, train-cy-acc: 0.9966
# validation loss: 0.0165, validation-c-acc: 0.9786, validation-y-acc: 0.8255
# Improvement-Detected, save-model
# test loss: 0.0158, test-c-acc: 0.9791, test-y-acc: 0.8342
#
# Epoch 42
#
# Epoch [42/50], Step [0/83], Loss: 0.0008
# Epoch [42/50], Step [20/83], Loss: 0.0010
# Epoch [42/50], Step [40/83], Loss: 0.0012
# Epoch [42/50], Step [60/83], Loss: 0.0009
# Epoch [42/50], Step [80/83], Loss: 0.0008
#
# train-loss: 0.0012, train-c-acc: 0.9944, train-cy-acc: 0.9967
# validation loss: 0.0164, validation-c-acc: 0.9786, validation-y-acc: 0.8261
# Improvement-Detected, save-model
# test loss: 0.0157, test-c-acc: 0.9791, test-y-acc: 0.8344
#
# Epoch 43
#
# Epoch [43/50], Step [0/83], Loss: 0.0008
# Epoch [43/50], Step [20/83], Loss: 0.0010
# Epoch [43/50], Step [40/83], Loss: 0.0011
# Epoch [43/50], Step [60/83], Loss: 0.0009
# Epoch [43/50], Step [80/83], Loss: 0.0008
#
# train-loss: 0.0011, train-c-acc: 0.9944, train-cy-acc: 0.9968
# validation loss: 0.0164, validation-c-acc: 0.9786, validation-y-acc: 0.8269
# Improvement-Detected, save-model
# test loss: 0.0156, test-c-acc: 0.9791, test-y-acc: 0.8353
#
# Epoch 44
#
# Epoch [44/50], Step [0/83], Loss: 0.0008
# Epoch [44/50], Step [20/83], Loss: 0.0009
# Epoch [44/50], Step [40/83], Loss: 0.0011
# Epoch [44/50], Step [60/83], Loss: 0.0009
# Epoch [44/50], Step [80/83], Loss: 0.0007
#
# train-loss: 0.0011, train-c-acc: 0.9944, train-cy-acc: 0.9968
# validation loss: 0.0163, validation-c-acc: 0.9786, validation-y-acc: 0.8269
# Improvement-Detected, save-model
# test loss: 0.0156, test-c-acc: 0.9791, test-y-acc: 0.8353
#
# Epoch 45
#
# Epoch [45/50], Step [0/83], Loss: 0.0008
# Epoch [45/50], Step [20/83], Loss: 0.0009
# Epoch [45/50], Step [40/83], Loss: 0.0011
# Epoch [45/50], Step [60/83], Loss: 0.0009
# Epoch [45/50], Step [80/83], Loss: 0.0007
#
# train-loss: 0.0011, train-c-acc: 0.9944, train-cy-acc: 0.9968
# validation loss: 0.0163, validation-c-acc: 0.9786, validation-y-acc: 0.8270
# Improvement-Detected, save-model
# test loss: 0.0156, test-c-acc: 0.9791, test-y-acc: 0.8363
#
# Epoch 46
#
# Epoch [46/50], Step [0/83], Loss: 0.0008
# Epoch [46/50], Step [20/83], Loss: 0.0009
# Epoch [46/50], Step [40/83], Loss: 0.0011
# Epoch [46/50], Step [60/83], Loss: 0.0008
# Epoch [46/50], Step [80/83], Loss: 0.0007
#
# train-loss: 0.0011, train-c-acc: 0.9944, train-cy-acc: 0.9969
# validation loss: 0.0163, validation-c-acc: 0.9786, validation-y-acc: 0.8271
# Improvement-Detected, save-model
# test loss: 0.0155, test-c-acc: 0.9791, test-y-acc: 0.8362
#
# Epoch 47
#
# Epoch [47/50], Step [0/83], Loss: 0.0007
# Epoch [47/50], Step [20/83], Loss: 0.0009
# Epoch [47/50], Step [40/83], Loss: 0.0010
# Epoch [47/50], Step [60/83], Loss: 0.0008
# Epoch [47/50], Step [80/83], Loss: 0.0007
#
# train-loss: 0.0011, train-c-acc: 0.9944, train-cy-acc: 0.9969
# validation loss: 0.0162, validation-c-acc: 0.9786, validation-y-acc: 0.8273
# Improvement-Detected, save-model
# test loss: 0.0155, test-c-acc: 0.9791, test-y-acc: 0.8360
#
# Epoch 48
#
# Epoch [48/50], Step [0/83], Loss: 0.0007
# Epoch [48/50], Step [20/83], Loss: 0.0009
# Epoch [48/50], Step [40/83], Loss: 0.0010
# Epoch [48/50], Step [60/83], Loss: 0.0008
# Epoch [48/50], Step [80/83], Loss: 0.0007
#
# train-loss: 0.0011, train-c-acc: 0.9944, train-cy-acc: 0.9970
# validation loss: 0.0162, validation-c-acc: 0.9786, validation-y-acc: 0.8267
# Improvement-Detected, save-model
# test loss: 0.0155, test-c-acc: 0.9791, test-y-acc: 0.8362
#
# Epoch 49
#
# Epoch [49/50], Step [0/83], Loss: 0.0007
# Epoch [49/50], Step [20/83], Loss: 0.0008
# Epoch [49/50], Step [40/83], Loss: 0.0010
# Epoch [49/50], Step [60/83], Loss: 0.0008
# Epoch [49/50], Step [80/83], Loss: 0.0007
#
# train-loss: 0.0010, train-c-acc: 0.9944, train-cy-acc: 0.9970
# validation loss: 0.0162, validation-c-acc: 0.9786, validation-y-acc: 0.8269
# Improvement-Detected, save-model
# test loss: 0.0154, test-c-acc: 0.9791, test-y-acc: 0.8369
#
# Epoch 50
#
# Epoch [50/50], Step [0/83], Loss: 0.0007
# Epoch [50/50], Step [20/83], Loss: 0.0008
# Epoch [50/50], Step [40/83], Loss: 0.0010
# Epoch [50/50], Step [60/83], Loss: 0.0008
# Epoch [50/50], Step [80/83], Loss: 0.0007
#
# train-loss: 0.0010, train-c-acc: 0.9944, train-cy-acc: 0.9971
# validation loss: 0.0161, validation-c-acc: 0.9786, validation-y-acc: 0.8271
# Improvement-Detected, save-model
# test loss: 0.0154, test-c-acc: 0.9791, test-y-acc: 0.8369

# %%
n = 1000
c_preds = net[0].cpu()(x_test[:n].cpu()).detach()
y_preds = net[1].cpu()(c_preds.cpu()).detach()
model_accuracy = accuracy_score(y_test[:n].cpu().detach().argmax(axis=1).numpy(), y_preds.argmax(axis=1).numpy())
print(f'Model\'s accuracy: {model_accuracy:.4f}')
# Out:
# Model's accuracy: 0.9500

# %%
# positive class
start = time.time()
class_explanation, class_explanations = lens.logic.explain_class(net[1].cpu(), 
                                                               c_preds.cpu(), 
                                                               y_val[:n].cpu(), 
                                                               binary=False, target_class=0,
                                                               topk_explanations=1)
elapsed_time = time.time() - start
explanation = logic.base.replace_names(class_explanation, concepts)
print(f'Class 1 - Global explanation: "{explanation}"')
# Out:
# Class 1 - Global explanation: "square & very small & ~ellipse & ~heart & ~small & ~s-medium & ~b-medium & ~big & ~very big"

# %%
if class_explanation:
    explanation = logic.base.replace_names(class_explanation, concepts)
    explanation_accuracy, y_formula = logic.base.test_explanation(class_explanation, 
                                                                  target_class=0, 
                                                                  x=c_test[:n], y=y_test[:n],
                                                                  metric=accuracy_score)
    
    c_preds = net[0].cpu()(x_test[:n].cpu()).detach()
    y_preds = net[1].cpu()(c_preds.cpu()).detach()
    explanation_fidelity = lens.logic.fidelity(y_formula, y_preds.argmax(axis=1).eq(0).numpy())
    explanation_complexity = lens.logic.complexity(class_explanation)

    print(f'Class 1 - Global explanation: "{explanation}" - Accuracy: {explanation_accuracy:.4f}')
    print(f'Fidelity: "{explanation_fidelity:.4f}" - Complexity: "{explanation_complexity}"')
    print(f'Elapsed time {elapsed_time}')
# Out:
# Class 1 - Global explanation: "square & very small & ~ellipse & ~heart & ~small & ~s-medium & ~b-medium & ~big & ~very big" - Accuracy: 1.0000
# Fidelity: "0.9980" - Complexity: "9"
# Elapsed time 0.2170257568359375
